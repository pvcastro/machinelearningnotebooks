# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data("Corpus/wiki.pt.text.zip")
print('Data size %d' % len(words))

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
print(data[:10])
print(count[:10])
print(dictionary.items()[:10])
print(reverse_dictionary.items()[:10])
# Out:
# [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]
# [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764), ('in', 372201), ('a', 325873), ('to', 316376), ('zero', 264975), ('nine', 250430)]
# [('fawn', 45848), ('homomorphism', 9648), ('nordisk', 39343), ('nunnery', 36075), ('chthonic', 33554), ('sowell', 40562), ('sonja', 38175), ('showa', 32906), ('woods', 6263), ('hsv', 44222)]
# [(0, 'UNK'), (1, 'the'), (2, 'of'), (3, 'and'), (4, 'one'), (5, 'in'), (6, 'a'), (7, 'to'), (8, 'zero'), (9, 'nine')]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'anarchism', 'originated', 'term', 'term', 'of', 'as', 'originated']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.429951
# Nearest to as: kristen, cjd, downloaded, hoff, avalon, sanitarium, reversible, agni,
# Nearest to known: exceptions, learner, ssris, affiliates, renewal, austerlitz, html, withstood,
# Nearest to first: clarence, caravaggio, florida, shootings, exempted, lewinsky, fante, plumage,
# Nearest to not: craftsman, verb, ulrich, styx, groot, beauharnais, keystrokes, tuition,
# Nearest to many: haight, deutsche, lake, photographing, trait, gomer, midair, zadar,
# Nearest to which: manichaeism, if, services, enlarged, lathe, additivity, illegality, lner,
# Nearest to they: hist, dancehall, beg, pershing, canberra, hornet, percussionist, pylons,
# Nearest to so: gigabytes, destructor, typewriters, report, samyaksam, gematria, mashiach, ipsec,
# Nearest to th: tilsit, asynchronous, lothair, predominance, mmu, jpl, polyatomic, edo,
# Nearest to united: zara, cker, brie, partake, ericales, animator, vorbis, principalities,
# Nearest to can: odor, iconography, gleichschaltung, terraces, unprofitable, valence, accusing, positioned,
# Nearest to time: settles, recommended, homelessness, bipeds, kaluza, speculators, mis, language,
# Nearest to over: kay, solved, kitchener, affidavit, cervantes, oceans, baleen, maratha,
# Nearest to between: flamsteed, oy, rights, rugova, ballads, billed, bitwise, swims,
# Nearest to at: mommsen, din, reputation, universe, crediting, forever, indulgence, grasshoppers,
# Nearest to four: musical, scenes, limnic, slanted, centerline, barefoot, drilled, collide,
# Average loss at step 2000: 4.301409
# Average loss at step 4000: 3.841201
# Average loss at step 6000: 3.746972
# Average loss at step 8000: 3.729780
# Average loss at step 10000: 3.668306
# Nearest to as: civitas, combine, in, into, reichsf, cyclopentadienyl, received, is,
# Nearest to known: such, learner, accelerations, subduction, singularly, lavishly, printable, withstood,
# Nearest to first: clarence, occasion, hyllus, shootings, bessie, holland, raising, after,
# Nearest to not: clientele, also, who, we, bashing, tuition, verb, ofcom,
# Nearest to many: some, cygwin, teatro, shadowed, lake, pln, reelected, trait,
# Nearest to which: that, also, this, services, manichaeism, it, lner, curtis,
# Nearest to they: there, he, often, we, beg, who, spearheaded, it,
# Nearest to so: faith, beg, report, destructor, newly, surroundings, hakim, patricio,
# Nearest to th: four, seven, three, lothair, five, tilsit, asynchronous, eight,
# Nearest to united: zara, appliances, brie, marvelous, cker, contraction, shield, dam,
# Nearest to can: will, always, must, lancaster, valence, derail, should, phonograph,
# Nearest to time: settles, bipeds, wark, cuvier, drenthe, necessities, mclaren, temporally,
# Nearest to over: seaport, oceans, affidavit, kay, straddles, shasta, monterey, compilations,
# Nearest to between: in, oy, diomedes, bacterial, previously, october, square, ballads,
# Nearest to at: in, replicated, mommsen, socialist, for, under, defeats, superstar,
# Nearest to four: five, three, six, seven, eight, two, nine, one,
# Average loss at step 12000: 3.671473
# Average loss at step 14000: 3.538775
# Average loss at step 16000: 3.431790
# Average loss at step 18000: 3.571729
# Average loss at step 20000: 3.532249
# Nearest to as: by, reichsf, fretless, frisia, callaghan, into, falsity, became,
# Nearest to known: such, lavishly, accelerations, used, singularly, possible, perennial, withstood,
# Nearest to first: third, occasion, electronica, last, shootings, bessie, best, clarence,
# Nearest to not: ofcom, that, clientele, generally, to, motorist, you, conses,
# Nearest to many: some, several, reelected, all, most, cygwin, teatro, other,
# Nearest to which: that, this, it, also, eplf, these, paddock, centum,
# Nearest to they: there, he, we, who, you, often, it, these,
# Nearest to so: justinian, beg, satrapy, ayers, severely, hakim, waterways, faith,
# Nearest to th: seven, five, tilsit, lothair, four, eight, asynchronous, predominance,
# Nearest to united: zara, marvelous, contraction, cker, brie, appliances, shield, original,
# Nearest to can: may, will, would, must, could, should, might, cannot,
# Nearest to time: settles, alexandria, bipeds, libi, ros, wark, drenthe, period,
# Nearest to over: digested, humanoids, through, oceans, baleen, tetra, copper, despair,
# Nearest to between: with, in, from, diomedes, around, oy, bacterial, through,
# Nearest to at: nuanced, on, tirelessly, valle, in, scotty, replicated, clavier,
# Nearest to four: five, seven, six, eight, three, nine, two, zero,
# Average loss at step 22000: 3.512557
# Average loss at step 24000: 3.523820
# Average loss at step 26000: 3.529188
# Average loss at step 28000: 3.472835
# Average loss at step 30000: 3.455665
# Nearest to as: reichsf, by, frisia, fretless, civitas, nau, efficacious, machines,
# Nearest to known: such, used, lavishly, possible, accelerations, printable, subduction, managed,
# Nearest to first: third, second, last, same, shootings, occasion, bessie, only,
# Nearest to not: it, figured, minimalism, calculated, they, you, motorist, we,
# Nearest to many: some, several, these, various, all, those, most, cygwin,
# Nearest to which: that, this, it, but, also, what, who, and,
# Nearest to they: there, we, he, you, it, she, who, i,
# Nearest to so: justinian, levitation, beg, newly, ayers, satrapy, assembling, brahmi,
# Nearest to th: six, seven, four, lothair, st, eight, nine, bc,
# Nearest to united: zara, contraction, marvelous, appliances, original, kapitan, connie, first,
# Nearest to can: may, will, could, would, should, must, cannot, might,
# Nearest to time: name, alexandria, day, settles, korea, drenthe, year, janis,
# Nearest to over: through, phenomenalism, humanoids, straightening, caucasian, monterey, axiomatization, oceans,
# Nearest to between: with, in, from, around, through, on, hospitaller, interim,
# Nearest to at: in, nuanced, during, for, clavier, on, tirelessly, within,
# Nearest to four: six, three, five, eight, seven, nine, zero, two,
# Average loss at step 32000: 3.176810
# Average loss at step 34000: 3.355282
# Average loss at step 36000: 3.442911
# Average loss at step 38000: 3.307597
# Average loss at step 40000: 3.410617
# Nearest to as: beard, vanilla, became, frisia, callaghan, personalized, anonymously, intermarriage,
# Nearest to known: such, used, lavishly, possible, printable, managed, seen, described,
# Nearest to first: last, second, third, same, only, next, bessie, supreme,
# Nearest to not: you, they, to, motorist, calculated, erecting, hedeby, haemophilia,
# Nearest to many: some, several, various, these, most, those, both, all,
# Nearest to which: that, this, also, what, but, who, however, cerebrum,
# Nearest to they: we, he, there, you, she, it, i, who,
# Nearest to so: beg, justinian, satrapy, spacetime, brahmi, too, thr, newly,
# Nearest to th: st, two, asynchronous, spilling, lothair, bc, tilsit, consultancy,
# Nearest to united: zara, contraction, shield, marvelous, appliances, connie, brie, walton,
# Nearest to can: will, may, could, would, cannot, should, might, must,
# Nearest to time: korea, year, day, alexandria, drenthe, name, way, trie,
# Nearest to over: through, phenomenalism, axiomatization, arteries, anmen, sefer, on, within,
# Nearest to between: with, in, around, from, on, jervis, hospitaller, interim,
# Nearest to at: in, on, nuanced, for, during, clavier, under, tirelessly,
# Nearest to four: seven, six, five, three, eight, two, nine, zero,
# Average loss at step 42000: 3.490694
# Average loss at step 44000: 3.439640
# Average loss at step 46000: 3.350291
# Average loss at step 48000: 3.305765
# Average loss at step 50000: 3.423551
# Nearest to as: scripts, bored, adolph, became, miscellaneous, capitulated, vanilla, inhabitant,
# Nearest to known: used, such, possible, lavishly, served, described, printable, managed,
# Nearest to first: last, second, third, next, best, herbie, bessie, same,
# Nearest to not: only, semimajor, erecting, dogmas, impede, minimalism, it, calculated,
# Nearest to many: some, several, various, these, both, those, other, most,
# Nearest to which: that, this, what, also, it, usually, often, who,
# Nearest to they: we, he, there, she, you, it, who, these,
# Nearest to so: satrapy, too, brahmi, justinian, waterways, thus, jhana, marginal,
# Nearest to th: wasps, st, spilling, tilsit, bc, rd, hp, lothair,
# Nearest to united: senate, zara, margin, baltic, eldridge, connie, biggest, recipes,
# Nearest to can: may, could, will, would, should, cannot, might, must,
# Nearest to time: year, day, alexandria, trie, way, scarcely, drenthe, fact,
# Nearest to over: through, into, phenomenalism, axiomatization, off, congratulate, rescue, amounted,
# Nearest to between: with, around, in, from, through, diomedes, within, etienne,
# Nearest to at: during, in, near, under, clavier, nuanced, gos, after,
# Nearest to four: seven, five, three, six, eight, nine, zero, two,
# Average loss at step 52000: 3.456917
# Average loss at step 54000: 3.458827
# Average loss at step 56000: 3.390827
# Average loss at step 58000: 3.353513
# Average loss at step 60000: 3.391801
# Nearest to as: when, frisia, after, scripts, fretless, elliot, adolph, vanilla,
# Nearest to known: used, such, possible, lavishly, recognized, served, described, printable,
# Nearest to first: last, second, third, next, final, supreme, same, cryptozoology,
# Nearest to not: never, physiologic, you, only, calculated, they, generally, pornography,
# Nearest to many: some, several, various, these, most, those, few, all,
# Nearest to which: that, this, who, also, where, often, usually, but,
# Nearest to they: we, he, there, she, you, it, i, who,
# Nearest to so: too, satrapy, brahmi, justinian, marginal, astonishingly, jhana, meddle,
# Nearest to th: bc, eight, hp, three, rd, st, six, wasps,
# Nearest to united: senate, baltic, zara, tirelessly, eldridge, biggest, connie, margin,
# Nearest to can: could, may, will, would, should, must, cannot, might,
# Nearest to time: year, way, day, trie, throws, scarcely, ime, plasticizers,
# Nearest to over: through, into, off, axiomatization, congratulate, paragraphs, almost, bandit,
# Nearest to between: with, around, through, within, etienne, batsmen, in, into,
# Nearest to at: clavier, during, after, in, under, on, gos, near,
# Nearest to four: three, five, seven, six, two, eight, nine, zero,
# Average loss at step 62000: 3.343516
# Average loss at step 64000: 3.363716
# Average loss at step 66000: 3.341356
# Average loss at step 68000: 3.310998
# Average loss at step 70000: 3.264302
# Nearest to as: became, anonymously, after, and, bored, when, pinnacle, apostate,
# Nearest to known: used, possible, such, recognized, lavishly, described, served, regarded,
# Nearest to first: last, second, next, third, final, herbie, best, supreme,
# Nearest to not: now, usually, hedeby, always, never, physiologic, still, dogmas,
# Nearest to many: several, some, various, both, these, those, all, most,
# Nearest to which: that, this, who, these, but, it, however, and,
# Nearest to they: we, there, he, she, you, who, these, it,
# Nearest to so: too, satrapy, justinian, thus, dispensationalism, sibilant, marginal, however,
# Nearest to th: rd, eight, st, bc, hp, wasps, nd, three,
# Nearest to united: senate, baltic, zara, tirelessly, eldridge, td, biggest, margin,
# Nearest to can: may, could, would, will, should, must, cannot, might,
# Nearest to time: year, trie, period, way, case, mentor, day, drenthe,
# Nearest to over: through, into, off, congratulate, digested, axiomatization, revenues, covens,
# Nearest to between: with, around, through, in, within, into, from, under,
# Nearest to at: in, during, near, before, clavier, on, scotty, tirelessly,
# Nearest to four: six, five, three, seven, eight, nine, two, zero,
# Average loss at step 72000: 3.289460
# Average loss at step 74000: 3.344993
# Average loss at step 76000: 3.342380
# Average loss at step 78000: 3.327067
# Average loss at step 80000: 3.336063
# Nearest to as: fretless, scripts, felines, when, frisia, macroevolution, cheap, beard,
# Nearest to known: used, such, possible, served, recognized, regarded, described, lavishly,
# Nearest to first: second, last, third, next, final, wise, best, bp,
# Nearest to not: always, generally, still, hedeby, you, tilt, kidding, nor,
# Nearest to many: several, some, these, various, all, those, both, few,
# Nearest to which: that, this, these, also, usually, who, but, often,
# Nearest to they: we, there, he, you, she, it, these, gleason,
# Nearest to so: too, justinian, satrapy, marginal, if, thus, very, dop,
# Nearest to th: rd, bc, wasps, nd, hp, nusa, st, eight,
# Nearest to united: senate, baltic, zara, biggest, connie, tirelessly, eldridge, asparagales,
# Nearest to can: may, could, will, would, should, might, must, cannot,
# Nearest to time: year, reason, trie, way, peckinpah, period, hairs, scarcely,
# Nearest to over: through, into, off, bandit, congratulate, covens, digested, within,
# Nearest to between: with, around, in, within, from, proliferation, etienne, loses,
# Nearest to at: during, under, scotty, in, within, near, before, around,
# Nearest to four: seven, eight, six, five, three, nine, two, zero,
# Average loss at step 82000: 3.333957
# Average loss at step 84000: 3.383226
# Average loss at step 86000: 3.355619
# Average loss at step 88000: 3.361292
# Average loss at step 90000: 3.306719
# Nearest to as: frisia, became, fatalities, intermarriage, beard, awaited, hildebrand, fretless,
# Nearest to known: used, such, possible, recognized, described, regarded, lavishly, served,
# Nearest to first: second, last, third, next, final, previous, best, wise,
# Nearest to not: never, always, generally, now, still, normally, haemophilia, nor,
# Nearest to many: some, several, various, these, few, most, those, both,
# Nearest to which: that, this, also, where, but, it, usually, paddock,
# Nearest to they: we, there, he, you, she, i, it, these,
# Nearest to so: too, justinian, marginal, very, satrapy, therefore, sibilant, criminalized,
# Nearest to th: bc, rd, eight, six, hp, wasps, st, nd,
# Nearest to united: baltic, senate, zara, biggest, british, nymph, asparagales, tirelessly,
# Nearest to can: will, could, may, must, would, should, might, cannot,
# Nearest to time: year, period, trie, day, way, plasticizers, scarcely, reason,
# Nearest to over: through, congratulate, into, around, parthian, mandolins, almost, permeable,
# Nearest to between: with, in, around, within, etienne, from, among, through,
# Nearest to at: during, near, on, within, in, throughout, tirelessly, enniskillen,
# Nearest to four: five, six, three, seven, eight, nine, two, zero,
# Average loss at step 92000: 3.189342
# Average loss at step 94000: 3.324418
# Average loss at step 96000: 3.345853
# Average loss at step 98000: 3.348105
# Average loss at step 100000: 3.347229
# Nearest to as: awaited, vanilla, intermarriage, beard, when, inhabitant, gore, became,
# Nearest to known: used, such, possible, recognized, regarded, described, classified, lavishly,
# Nearest to first: second, last, next, third, previous, final, catalogue, largest,
# Nearest to not: usually, never, generally, ye, typically, now, still, always,
# Nearest to many: some, several, various, both, those, these, few, all,
# Nearest to which: this, that, who, what, also, usually, often, it,
# Nearest to they: we, he, you, there, she, it, eventually, i,
# Nearest to so: too, very, justinian, marginal, criminalized, sibilant, therefore, astonishingly,
# Nearest to th: bc, rd, hp, second, three, nd, wasps, bce,
# Nearest to united: senate, baltic, zara, asparagales, biggest, pleasuredome, galley, eldridge,
# Nearest to can: could, will, may, should, must, would, might, cannot,
# Nearest to time: year, period, scarcely, day, trie, way, season, reason,
# Nearest to over: through, congratulate, into, around, off, mandolins, bandit, permeable,
# Nearest to between: with, around, etienne, mencius, in, within, among, through,
# Nearest to at: during, near, on, within, scotty, nuanced, compost, under,
# Nearest to four: five, six, three, eight, seven, nine, two, zero,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])
