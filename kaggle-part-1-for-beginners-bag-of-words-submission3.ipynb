# %%
# Import the pandas package, then use the "read_csv" function to read
# the labeled training data
import pandas as pd       
train = pd.read_csv("./Kaggle/Bag of Words/labeledTrainData.tsv", header=0, delimiter="\t", quoting=3)

# %%
train.shape
# Out:
# (25000, 3)

# %%
train.columns.values
# Out:
# array(['id', 'sentiment', 'review'], dtype=object)

# %%
from bs4 import BeautifulSoup
import re

# %%
import nltk
from nltk.corpus import stopwords
stopwords = set(stopwords.words("english"))

# %%
# defines a tokenizer and stemmer which returns the set of stems in the text that it is passed
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("english")
def tokenize_and_stem(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    stems = [stemmer.stem(t) for t in filtered_tokens]
    return stems

# %%
def preprocess_review( raw_review ):
    # Function to convert a raw review to a string of words
    # The input is a single string (a raw movie review), and 
    # the output is a single string (a preprocessed movie review)
    #
    # 1. Remove HTML
    review_text = BeautifulSoup(raw_review).get_text() 
    #
    # 2. Convert to lower case
    return review_text.lower()

# %%
print "Creating the bag of words...\n"
from sklearn.feature_extraction.text import CountVectorizer

# Initialize the "CountVectorizer" object, which is scikit-learn's
# bag of words tool.  
vectorizer = CountVectorizer(tokenizer = tokenize_and_stem,    \
                             preprocessor = preprocess_review, \
                             stop_words = stopwords,   \
                             max_features = 5000, \
                             ngram_range=(1,3)) 

# fit_transform() does two functions: First, it fits the model
# and learns the vocabulary; second, it transforms our training data
# into feature vectors. The input to fit_transform should be a list of 
# strings.
train_data_features = vectorizer.fit_transform(train['review'])

# Numpy arrays are easy to work with, so convert the result to an 
# array
train_data_features = train_data_features.toarray()
# Out:
# Creating the bag of words...

# %%
print train_data_features.shape
# Out:
# (25000, 5000)

# %%
# Take a look at the words in the vocabulary
vocab = vectorizer.get_feature_names()
print vocab
# Out:
# [u"'d", u"'d like", u"'d rather", u"'d say", u"'m", u"'m big", u"'m glad", u"'m go", u"'m sorri", u"'m still", u"'m sure", u"'s", u"'s 's", u"'s act", u"'s actual", u"'s almost", u"'s also", u"'s alway", u"'s amaz", u"'s anoth", u"'s bad", u"'s beauti", u"'s becaus", u"'s best", u"'s better", u"'s big", u"'s book", u"'s brother", u"'s career", u"'s charact", u"'s classic", u"'s daughter", u"'s death", u"'s definit", u"'s direct", u"'s done", u"'s easi", u"'s end", u"'s even", u"'s eye", u"'s face", u"'s famili", u"'s father", u"'s film", u"'s final", u"'s first", u"'s friend", u"'s fun", u"'s funni", u"'s get", u"'s go", u"'s good", u"'s got", u"'s great", u"'s greatest", u"'s hard", u"'s head", u"'s hous", u"'s interest", u"'s kind", u"'s last", u"'s life", u"'s like", u"'s littl", u"'s lot", u"'s love", u"'s made", u"'s make", u"'s mother", u"'s movi", u"'s much", u"'s music", u"'s name", u"'s never", u"'s new", u"'s nice", u"'s noth", u"'s novel", u"'s obvious", u"'s one", u"'s onli", u"'s origin", u"'s part", u"'s perform", u"'s play", u"'s plot", u"'s point", u"'s pretti", u"'s probabl", u"'s quit", u"'s real", u"'s realli", u"'s right", u"'s role", u"'s sad", u"'s say", u"'s shame", u"'s sister", u"'s someth", u"'s son", u"'s standard", u"'s still", u"'s stori", u"'s suppos", u"'s time", u"'s tri", u"'s true", u"'s veri", u"'s version", u"'s voic", u"'s way", u"'s well", u"'s whi", u"'s wife", u"'s wonder", u"'s work", u"'s worth", u'.and', u'.i', u'.it', u'.the', u'.this', u'1930s', u'1950s', u'1970s', u'1980s', u'1st', u'20th', u'20th centuri', u'2nd', u'3rd', u'50s', u'60s', u'70s', u'80s', u'90s', u'abandon', u'abc', u'abil', u'abl', u'abov', u'abrupt', u'absenc', u'absolut', u'absolut love', u'absolut noth', u'absorb', u'absurd', u'abus', u'abysm', u'academi', u'academi award', u'accent', u'accept', u'access', u'accid', u'accident', u'acclaim', u'accompani', u'accomplish', u'accord', u'account', u'accur', u'accus', u'achiev', u'acid', u'acknowledg', u'acquir', u'across', u'act', u'act bad', u'act direct', u'act good', u'act like', u'act movi', u"act n't", u'act terribl', u'act veri', u'action', u'action film', u'action movi', u'action scene', u'action sequenc', u'activ', u'actor', u"actor 's", u'actor actress', u'actor film', u'actor like', u'actor movi', u"actor n't", u'actor play', u'actress', u'actual', u'ad', u'adam', u'adapt', u'add', u'addict', u'addit', u'address', u'adequ', u'admir', u'admit', u'adolesc', u'adopt', u'ador', u'adult', u'advanc', u'advantag', u'adventur', u'advertis', u'advic', u'advis', u'affair', u'affect', u'afford', u'aforement', u'afraid', u'africa', u'african', u'afternoon', u'afterward', u'age', u'agent', u'aggress', u'ago', u'agre', u'ah', u'ahead', u'ai', u"ai n't", u'aid', u'aim', u'air', u'airplan', u'airport', u'aka', u'akshay', u'al', u'ala', u'alan', u'albeit', u'albert', u'album', u'alcohol', u'alex', u'alexand', u'alfr', u'alic', u'alien', u'alik', u'aliv', u'all-tim', u'alleg', u'allen', u'alli', u'allow', u'almost', u'almost everi', u'alon', u'along', u'along line', u'along way', u'alreadi', u'alright', u'also', u'also good', u'also great', u'also like', u'also one', u'also star', u'also veri', u'alter', u'altern', u'although', u'altman', u'altogeth', u'alway', u'amanda', u'amateur', u'amateurish', u'amaz', u'ambigu', u'ambit', u'ambiti', u'america', u"america 's", u'american', u'ami', u'among', u'amongst', u'amount', u'amus', u'ancient', u'and/or', u'anderson', u'andi', u'andrew', u'angel', u'anger', u'angl', u'angri', u'ani', u'ani charact', u'ani film', u'ani good', u'ani kind', u'ani movi', u'ani one', u'ani real', u'ani sens', u'ani way', u'anim', u'anim film', u'ann', u'anna', u'anni', u'announc', u'annoy', u'anoth', u'anoth film', u'anoth movi', u'anoth one', u'answer', u'ant', u'anthoni', u'antic', u'anticip', u'anybodi', u'anymor', u'anyon', u"anyon 's", u'anyon els', u'anyth', u'anyth els', u'anyway', u'anywher', u'apart', u'ape', u'apolog', u'appal', u'appar', u'ap ...

# %%
import numpy as np

# Sum up the counts of each vocabulary word
dist = np.sum(train_data_features, axis=0)

# For each, print the vocabulary word and the number of times it 
# appears in the training set
for tag, count in zip(vocab, dist):
    print count, tag
# Out:
# 2337 'd
# 201 'd like
# 93 'd rather
# 145 'd say
# 4755 'm
# 97 'm big
# 167 'm glad
# 207 'm go
# 136 'm sorri
# 108 'm still
# 715 'm sure
# 62067 's
# 247 's 's
# 167 's act
# 164 's actual
# 192 's almost
# 473 's also
# 160 's alway
# 101 's amaz
# 126 's anoth
# 433 's bad
# 107 's beauti
# 156 's becaus
# 410 's best
# 121 's better
# 92 's big
# 113 's book
# 106 's brother
# 91 's career
# 907 's charact
# 95 's classic
# 122 's daughter
# 182 's death
# 114 's definit
# 142 's direct
# 130 's done
# 115 's easi
# 103 's end
# 277 's even
# 108 's eye
# 231 's face
# 114 's famili
# 195 's father
# 518 's film
# 97 's final
# 285 's first
# 116 's friend
# 108 's fun
# 217 's funni
# 130 's get
# 336 's go
# 518 's good
# 258 's got
# 403 's great
# 96 's greatest
# 389 's hard
# 131 's head
# 109 's hous
# 157 's interest
# 172 's kind
# 126 's last
# 331 's life
# 473 's like
# 162 's littl
# 190 's lot
# 179 's love
# 94 's made
# 104 's make
# 130 's mother
# 429 's movi
# 255 's much
# 109 's music
# 171 's name
# 128 's never
# 119 's new
# 110 's nice
# 266 's noth
# 107 's novel
# 163 's obvious
# 447 's one
# 440 's onli
# 144 's origin
# 96 's part
# 388 's perform
# 106 's play
# 109 's plot
# 112 's point
# 265 's pretti
# 141 's probabl
# 160 's quit
# 196 's real
# 497 's realli
# 154 's right
# 101 's role
# 95 's sad
# 182 's say
# 159 's shame
# 93 's sister
# 179 's someth
# 103 's son
# 94 's standard
# 297 's still
# 280 's stori
# 200 's suppos
# 181 's time
# 110 's tri
# 130 's true
# 517 's veri
# 116 's version
# 116 's voic
# 183 's way
# 109 's well
# 163 's whi
# 210 's wife
# 134 's wonder
# 283 's work
# 248 's worth
# 103 .and
# 233 .i
# 110 .it
# 358 .the
# 105 .this
# 110 1930s
# 142 1950s
# 122 1970s
# 114 1980s
# 132 1st
# 117 20th
# 105 20th centuri
# 106 2nd
# 98 3rd
# 99 50s
# 152 60s
# 268 70s
# 259 80s
# 93 90s
# 283 abandon
# 118 abc
# 547 abil
# 1241 abl
# 781 abov
# 135 abrupt
# 117 absenc
# 1838 absolut
# 92 absolut love
# 150 absolut noth
# 125 absorb
# 408 absurd
# 390 abus
# 106 abysm
# 289 academi
# 162 academi award
# 675 accent
# 763 accept
# 162 access
# 324 accid
# 238 accident
# 109 acclaim
# 194 accompani
# 261 accomplish
# 307 accord
# 289 account
# 344 accur
# 196 accus
# 561 achiev
# 91 acid
# 109 acknowledg
# 97 acquir
# 963 across
# 8407 act
# 202 act bad
# 93 act direct
# 124 act good
# 253 act like
# 98 act movi
# 128 act n't
# 97 act terribl
# 115 act veri
# 3341 action
# 180 action film
# 274 action movi
# 226 action scene
# 174 action sequenc
# 261 activ
# 6578 actor
# 140 actor 's
# 122 actor actress
# 111 actor film
# 107 actor like
# 97 actor movi
# 106 actor n't
# 248 actor play
# 1483 actress
# 5024 actual
# 740 ad
# 405 adam
# 800 adapt
# 1116 add
# 232 addict
# 490 addit
# 179 address
# 141 adequ
# 430 admir
# 862 admit
# 103 adolesc
# 160 adopt
# 226 ador
# 850 adult
# 264 advanc
# 167 advantag
# 693 adventur
# 222 advertis
# 254 advic
# 179 advis
# 392 affair
# 424 affect
# 138 afford
# 126 aforement
# 334 afraid
# 206 africa
# 206 african
# 186 afternoon
# 169 afterward
# 1487 age
# 428 agent
# 95 aggress
# 994 ago
# 771 agre
# 98 ah
# 365 ahead
# 183 ai
# 169 ai n't
# 262 aid
# 276 aim
# 762 air
# 97 airplan
# 91 airport
# 195 aka
# 117 akshay
# 344 al
# 194 ala
# 342 alan
# 157 albeit
# 257 albert
# 112 album
# 209 alcohol
# 224 alex
# 117 alexand
# 97 alfr
# 183 alic
# 639 alien
# 120 alik
# 415 aliv
# 110 all-tim
# 95 alleg
# 388 allen
# 131 alli
# 1016 allow
# 3098 almost
# 156 almost everi
# 991 alon
# 1726 along
# 91 along line
# 163 along way
# 1354 alreadi
# 173 alright
# 8928 also
# 95 also good
# 95 also great
# 120 also like
# 93 also one
# 118 also star
# 235 also veri
# 141 alter
# 239 altern
# 2401 although
# 106 altman
# 103 altogeth
# 3205 alway
# 95 amanda
# 237 amateur
# 224 amateurish
# 1696 amaz
# 137 ambigu
# 114 ambit
# 123 ambiti
# 703 america
# 92 america 's
# 2371 american
# 109 ami
# 774 among
# 159 amongst
# 594 amount
# 713 amus
# 234 ancient
# 177 and/or
# 220 anderson
# 329 andi
# 289 andrew
# 451 angel
# 220 anger
# 381 angl
# 329 angri
# 7617 ani
# 138 ani charact
# 190 ani film
# 102 ani good
# 154 ani kind
# 221 ani movi
# 91 ani one
# 105 ani real
# 166 ani sens
# 201 ani way
# 2348 anim
# 108 anim film
# 472 ann
# 230 anna
# 120 anni
# 147 announc
# 1259 annoy
# 4139 anoth
# 110 anoth film
# 139 anoth movi
# 118 anoth one
# 611 answer
# 94 ant
# 256 anthoni
# 108 antic
# 166 anticip
# 305 anybodi
# 304 anymor
# 2576 anyon
# 102 anyon 's
# 169 anyon els
# 2897 anyth
# 260 anyth els
# 1025 anyway
# 288 anywher
# 932 apart
# 189 ape
# 101 apolog
# 182 appal
# 1200 appar
# 735 appeal
# 2530 appear
# 101 applaud
# 168 appli
# 817 appreci
# 541 approach
# 304 appropri
# 93 april
# 96 arab
# 430 area
# 208 argu
# 94 arguabl
# 172 argument
# 398 arm
# 445 armi
# 141 arnold
# 3543 around
# 140 arrang
# 207 arrest
# 502 arriv
# 152 arrog
# 1452 art
# 113 art film
# 345 arthur
# 120 artifici
# 838 artist
# 157 asham
# 236 asian
# 449 asid
# 1488 ask
# 206 asleep
# 837 aspect
# 111 aspect film
# 156 aspir
# 199 ass
# 214 assassin
# 128 assault
# 98 assembl
# 163 assign
# 267 assist
# 252 associ
# 420 assum
# 134 assur
# 117 astair
# 148 astonish
# 876 atmospher
# 203 atroci
# 189 attach
# 827 attack
# 1919 attempt
# 276 attend
# 896 attent
# 313 attitud
# 728 attract
# 2569 audienc
# 106 audio
# 105 audit
# 200 aunt
# 122 australia
# 216 australian
# 221 authent
# 472 author
# 116 automat
# 408 avail
# 99 aveng
# 683 averag
# 913 avoid
# 91 avoid cost
# 1719 aw
# 112 aw movi
# 105 await
# 108 awak
# 114 awaken
# 304 awar
# 660 award
# 2671 away
# 102 awe
# 493 awesom
# 284 awkward
# 460 b
# 96 b movi
# 230 b-movi
# 99 b.
# 126 babe
# 681 babi
# 4887 back
# 102 back forth
# 95 back time
# 139 backdrop
# 696 background
# 91 backward
# 9575 bad
# 272 bad 's
# 401 bad act
# 118 bad bad
# 309 bad film
# 548 bad guy
# 651 bad movi
# 116 bad n't
# 114 bad one
# 106 bad script
# 160 bad thing
# 170 bag
# 156 baker
# 129 bakshi
# 234 balanc
# 334 ball
# 95 ballet
# 137 ban
# 595 band
# 124 bang
# 296 bank
# 438 bar
# 234 barbara
# 597 bare
# 97 bargain
# 143 barri
# 1540 base
# 92 base true
# 207 basebal
# 127 basement
# 106 bash
# 167 basi
# 1413 basic
# 187 bat
# 151 bath
# 110 bathroom
# 403 batman
# 775 battl
# 166 bbc
# 197 beach
# 413 bear
# 187 beast
# 586 beat
# 116 beaten
# 111 beatti
# 3192 beauti
# 117 beauti film
# 696 becam
# 8994 becaus
# 560 becaus 's
# 128 becaus film
# 149 becaus movi
# 249 becaus n't
# 103 becaus one
# 3254 becom
# 389 bed
# 104 bedroom
# 156 beer
# 4210 befor
# 100 befor watch
# 109 befriend
# 181 beg
# 312 began
# 2835 begin
# 190 begin end
# 116 begin film
# 109 begin movi
# 185 behav
# 285 behavior
# 1225 behind
# 262 belief
# 3815 believ
# 99 believ 's
# 97 believ movi
# 172 bell
# 283 belong
# 173 belov
# 594 ben
# 102 beneath
# 171 benefit
# 93 bergman
# 93 berlin
# 436 besid
# 6253 best
# 130 best actor
# 278 best film
# 240 best friend
# 269 best movi
# 191 best part
# 184 best perform
# 92 best pictur
# 180 best thing
# 92 best work
# 281 bet
# 178 betray
# 153 bett
# 95 bett davi
# 5575 better
# 192 better film
# 192 better movi
# 245 betti
# 843 beyond
# 118 bias
# 127 bibl
# 3312 big
# 103 big budget
# 200 big fan
# 194 big screen
# 259 bigger
# 512 biggest
# 743 bill
# 392 billi
# 109 bin
# 93 biographi
# 194 bird
# 193 birth
# 135 birthday
# 3298 bit
# 193 bite
# 185 bitter
# 519 bizarr
# 1961 black
# 326 black white
# 109 blade
# 176 blah
# 97 blah blah
# 164 blair
# 107 blake
# 387 blame
# 337 bland
# 136 blank
# 125 blast
# 171 blatant
# 125 bleak
# 199 blend
# 120 bless
# 100 blew
# 335 blind
# 107 blob
# 155 block
# 211 blockbust
# 370 blond
# 1060 blood
# 308 bloodi
# 383 blow
# 166 blown
# 451 blue
# 114 blunt
# 154 bo
# 317 board
# 114 boast
# 250 boat
# 272 bob
# 144 bobbi
# 1134 bodi
# 125 bold
# 140 boll
# 162 bollywood
# 329 bomb
# 401 bond
# 159 bone
# 98 bonus
# 2792 book
# 133 boot
# 196 border
# 2445 bore
# 129 boredom
# 358 born
# 183 borrow
# 435 boss
# 641 bother
# 109 bottl
# 367 bottom
# 94 bottom line
# 454 bought
# 170 bound
# 184 bourn
# 98 bowl
# 726 box
# 173 box offic
# 1977 boy
# 387 boyfriend
# 167 brad
# 96 brad pitt
# 106 bradi
# 507 brain
# 176 branagh
# 140 brand
# 152 brando
# 226 brave
# 111 brazil
# 1018 break
# 171 breast
# 277 breath
# 179 breathtak
# 332 brian
# 165 bride
# 216 bridg
# 397 brief
# 128 briefli
# 290 bright
# 124 brillianc
# 1385 brilliant
# 1708 bring
# 160 bring back
# 141 britain
# 880 british
# 129 broad
# 156 broadcast
# 222 broadway
# 146 broke
# 260 broken
# 225 brook
# 101 brooklyn
# 123 brosnan
# 1593 brother
# 734 brought
# 279 brown
# 378 bruce
# 472 brutal
# 288 buck
# 122 bud
# 332 buddi
# 1524 budget
# 96 budget film
# 190 buff
# 266 bug
# 877 build
# 219 built
# 211 bullet
# 152 bulli
# 96 bumbl
# 806 bunch
# 189 buri
# 519 burn
# 131 burst
# 161 burt
# 143 burton
# 176 bus
# 137 bush
# 746 busi
# 97 bust
# 125 butcher
# 123 butt
# 122 button
# 983 buy
# 99 c
# 130 c.
# 3533 ca
# 3514 ca n't
# 252 ca n't believ
# 140 ca n't even
# 139 ca n't get
# 224 ca n't help
# 100 ca n't realli
# 144 ca n't say
# 114 ca n't wait
# 169 cabin
# 270 cabl
# 315 cage
# 118 cagney
# 260 cain
# 93 cake
# 178 california
# 2589 call
# 107 calm
# 1667 came
# 95 came across
# 389 cameo
# 1689 camera
# 107 camera angl
# 243 camera work
# 109 camera-work
# 118 cameron
# 510 camp
# 96 campbel
# 181 campi
# 132 canada
# 227 canadian
# 152 cancel
# 252 candi
# 108 candid
# 147 cannib
# 203 cant
# 276 capabl
# 167 capit
# 324 captain
# 242 captiv
# 841 captur
# 1443 car
# 117 car chase
# 230 card
# 130 cardboard
# 2062 care
# 1049 career
# 102 cari
# 141 caricatur
# 107 carl
# 162 carol
# 163 carpent
# 96 carradin
# 127 carrey
# 904 carri
# 126 carter
# 715 cartoon
# 1644 case
# 230 cash
# 4433 cast
# 113 cast includ
# 142 cast member
# 338 castl
# 102 casual
# 588 cat
# 620 catch
# 239 categori
# 139 catherin
# 156 cathol
# 548 caught
# 1015 caus
# 116 cave
# 359 celebr
# 203 cell
# 98 celluloid
# 390 center
# 91 center around
# 100 centr
# 412 central
# 515 centuri
# 2203 certain
# 103 certain n't
# 93 cg
# 309 cgi
# 159 chain
# 171 chair
# 412 challeng
# 199 chan
# 1172 chanc
# 100 chanc see
# 1996 chang
# 518 channel
# 105 chao
# 148 chaplin
# 113 chapter
# 13836 charact
# 421 charact 's
# 176 charact actor
# 368 charact develop
# 94 charact even
# 166 charact film
# 99 charact like
# 92 charact make
# 198 charact movi
# 182 charact n't
# 94 charact one
# 165 charact play
# 91 charact realli
# 138 charact seem
# 129 charact veri
# 93 charact well
# 198 character
# 106 characterist
# 295 charg
# 135 charisma
# 133 charismat
# 399 charl
# 425 charli
# 93 charlott
# 953 charm
# 784 chase
# 199 che
# 866 cheap
# 250 cheat
# 966 check
# 226 cheer
# 140 chees
# 650 cheesi
# 475 chemistri
# 93 chess
# 98 chest
# 112 chew
# 293 chick
# 228 chief
# 1209 child
# 350 childhood
# 129 childish
# 1466 children
# 180 children 's
# 298 chill
# 178 china
# 320 chines
# 663 choic
# 373 choos
# 156 chop
# 129 choreograph
# 108 choreographi
# 94 chorus
# 202 chose
# 224 chosen
# 405 chris
# 147 christ
# 152 christi
# 506 christian
# 573 christma
# 413 christoph
# 145 chuck
# 143 chuckl
# 408 church
# 119 cia
# 202 cinderella
# 1459 cinema
# 422 cinemat
# 145 cinematograph
# 964 cinematographi
# 160 circl
# 236 circumst
# 1182 citi
# 194 citizen
# 257 civil
# 92 civil war
# 582 claim
# 187 clair
# 269 clark
# 847 class
# 2063 classic
# 93 claus
# 310 clean
# 1677 clear
# 625 clever
# 188 clich
# 612 cliché
# 176 clichéd
# 118 cliff
# 417 climax
# 145 climb
# 104 clint
# 250 clip
# 1532 close
# 145 close-up
# 200 closer
# 92 closest
# 113 closet
# 474 cloth
# 118 clown
# 405 club
# 337 clue
# 108 clumsi
# 158 co-star
# 123 coach
# 186 code
# 100 coffe
# 146 coher
# 122 coincid
# 510 cold
# 128 cole
# 113 collabor
# 106 collaps
# 101 colleagu
# 538 collect
# 486 colleg
# 102 colonel
# 109 coloni
# 789 color
# 236 colour
# 189 columbo
# 120 combat
# 620 combin
# 6607 come
# 359 come across
# 328 come back
# 139 come close
# 100 come mind
# 94 come togeth
# 308 comed
# 3405 comedi
# 228 comedian
# 250 comfort
# 1134 comic
# 160 comic book
# 119 comic relief
# 278 command
# 98 commend
# 1653 comment
# 334 commentari
# 369 commerci
# 482 commit
# 100 commit suicid
# 522 common
# 179 communic
# 112 communist
# 301 communiti
# 573 compani
# 129 companion
# 1051 compar
# 297 comparison
# 93 compass
# 493 compel
# 92 compens
# 284 compet
# 162 competit
# 265 complain
# 210 complaint
# 3001 complet
# 103 complet differ
# 97 complet wast
# 537 complex
# 265 complic
# 91 compliment
# 230 compos
# 92 composit
# 512 comput
# 190 con
# 129 conceiv
# 188 concentr
# 599 concept
# 602 concern
# 164 concert
# 148 conclud
# 489 conclus
# 233 condit
# 179 confess
# 173 confid
# 97 confin
# 112 confirm
# 409 conflict
# 286 confront
# 932 confus
# 628 connect
# 91 conneri
# 210 consequ
# 103 conserv
# 1562 consid
# 230 consider
# 487 consist
# 135 conspiraci
# 702 constant
# 236 construct
# 100 consum
# 192 contact
# 743 contain
# 96 contempl
# 229 contemporari
# 397 content
# 191 contest
# 250 context
# 1141 continu
# 153 contract
# 110 contrari
# 300 contrast
# 254 contribut
# 260 contriv
# 643 control
# 204 controversi
# 128 conveni
# 279 convent
# 350 convers
# 340 convey
# 217 convict
# 1080 convinc
# 127 convolut
# 237 cook
# 923 cool
# 197 cooper
# 856 cop
# 105 cope
# 727 copi
# 179 core
# 186 corner
# 253 corni
# 184 corpor
# 184 corps
# 363 correct
# 259 corrupt
# 443 cost
# 667 costum
# 9356 could
# 121 could better
# 187 could done
# 163 could easili
# 96 could find
# 153 could get
# 172 could go
# 155 could made
# 130 could make
# 1496 could n't
# 95 could never
# 92 could onli
# 124 could possibl
# 154 could see
# 111 could use
# 476 count
# 135 countless
# 1016 countri
# 99 countrysid
# 1852 coupl
# 189 courag
# 2486 cours
# 211 court
# 175 cousin
# 887 cover
# 93 coward
# 198 cowboy
# 127 cox
# 217 crack
# 262 craft
# 118 craig
# 957 crap
# 243 crappi
# 334 crash
# 121 craven
# 653 crazi
# 1641 creat
# 162 creation
# 457 creativ
# 206 creator
# 505 creatur
# 299 credibl
# 1248 credit
# 141 creep
# 654 creepi
# 565 crew
# 739 cri
# 804 crime
# 511 crimin
# 146 cring
# 142 crisi
# 1030 critic
# 96 crocodil
# 112 crook
# 384 cross
# 280 crowd
# 202 crude
# 177 cruel
# 141 cruis
# 178 crush
# 104 cuba
# 127 cube
# 99 cue
# 452 cult
# 689 cultur
# 133 cup
# 125 cure
# 121 curios
# 304 curious
# 372 current
# 222 curs
# 138 curti
# 139 cusack
# 114 custom
# 1334 cut
# 569 cute
# 225 cynic
# 481 dad
# 91 daddi
# 166 daili
# 96 dalton
# 196 damag
# 426 damn
# 284 dan
# 1303 danc
# 242 dancer
# 145 dane
# 555 danger
# 298 daniel
# 340 danni
# 305 dare
# 1530 dark
# 116 darker
# 123 dash
# 810 date
# 1243 daughter
# 118 dave
# 470 davi
# 988 david
# 97 david lynch
# 143 dawn
# 130 dawson
# 3586 day
# 93 dazzl
# 697 de
# 99 de niro
# 105 de palma
# 1825 dead
# 105 dead\
# 1232 deal
# 137 dealt
# 185 dean
# 155 dear
# 1979 death
# 92 death scene
# 122 debat
# 284 debut
# 451 decad
# 1145 decent
# 1840 decid
# 95 decid go
# 91 decid watch
# 334 decis
# 125 declar
# 94 declin
# 109 decor
# 152 dedic
# 91 deed
# 617 deep
# 171 deeper
# 319 deepli
# 212 defeat
# 191 defend
# 91 defens
# 108 defi
# 227 defin
# 1818 definit
# 120 definit one
# 125 definit worth
# 244 degre
# 168 deliber
# 111 delici
# 549 delight
# 1010 deliv
# 184 deliveri
# 283 demand
# 386 demon
# 248 demonstr
# 208 deni
# 188 denni
# 148 dentist
# 135 denzel
# 93 denzel washington
# 260 depart
# 245 depend
# 659 depict
# 475 depress
# 533 depth
# 154 derek
# 134 deriv
# 105 descend
# 724 describ
# 201 descript
# 334 desert
# 1229 deserv
# 709 design
# 480 desir
# 597 desper
# 1264 despit
# 95 despit fact
# 115 destin
# 97 destini
# 558 destroy
# 165 destruct
# 858 detail
# 520 detect
# 270 determin
# 114 detract
# 108 devast
# 1510 develop
# 247 devic
# 305 devil
# 104 devoid
# 176 devot
# 882 dialog
# 1606 dialogu
# 145 diamond
# 99 dian
# 97 diana
# 276 dick
# 97 dicken
# 1842 die
# 2930 differ
# 689 difficult
# 146 difficulti
# 205 dig
# 150 digit
# 112 digniti
# 103 dimens
# 93 dimension
# 150 dinner
# 195 dinosaur
# 122 dire
# 3772 direct
# 107 direct film
# 4622 director
# 273 director 's
# 125 directori
# 314 dirti
# 100 disabl
# 146 disagre
# 343 disappear
# 1806 disappoint
# 326 disast
# 159 disbelief
# 122 disc
# 836 discov
# 117 discoveri
# 387 discuss
# 141 diseas
# 92 disgrac
# 151 disguis
# 360 disgust
# 103 disjoint
# 252 dislik
# 100 dismiss
# 718 disney
# 92 disney 's
# 456 display
# 91 dispos
# 133 distanc
# 118 distant
# 218 distinct
# 297 distract
# 154 distribut
# 620 disturb
# 93 dive
# 127 divers
# 158 divorc
# 92 dixon
# 129 doc
# 671 doctor
# 138 document
# 1001 documentari
# 10422 doe
# 95 doe get
# 133 doe good
# 94 doe great
# 127 doe make
# 4532 doe n't
# 214 doe n't even
# 107 doe n't get
# 160 doe n't know
# 214 doe n't make
# 106 doe n't mean
# 167 doe n't realli
# 185 doe n't seem
# 96 doe n't take
# 99 doe n't want
# 139 doe n't work
# 839 dog
# 180 doll
# 343 dollar
# 104 domest
# 256 domin
# 183 donald
# 2925 done
# 99 done better
# 107 donna
# 181 doom
# 507 door
# 136 dorothi
# 120 dose
# 338 doubl
# 873 doubt
# 306 dougla
# 187 downright
# 282 dozen
# 98 dr
# 549 dr.
# 102 dracula
# 510 drag
# 215 dragon
# 93 drain
# 1409 drama
# 748 dramat
# 464 draw
# 378 drawn
# 361 dread
# 1060 dream
# 582 dress
# 241 drew
# 247 dri
# 370 drink
# 767 drive
# 112 drivel
# 174 driven
# 209 driver
# 477 drop
# 136 drown
# 695 drug
# 283 drunk
# 126 drunken
# 454 dub
# 93 dud
# 196 dude
# 909 due
# 178 duke
# 805 dull
# 620 dumb
# 139 dump
# 123 duo
# 2111 dure
# 104 dure film
# 101 dutch
# 140 duti
# 93 duval
# 2216 dvd
# 105 dvd releas
# 165 dynam
# 96 e.g
# 137 eager
# 169 ear
# 1546 earli
# 193 earli 's
# 646 earlier
# 223 earn
# 805 earth
# 103 eas
# 772 easi
# 130 easier
# 875 easili
# 146 east
# 132 eastwood
# 562 eat
# 117 eccentr
# 107 echo
# 298 ed
# 106 ed wood
# 326 eddi
# 97 eddi murphi
# 445 edg
# 92 edgar
# 107 edi
# 1172 edit
# 134 editor
# 257 educ
# 222 edward
# 149 eeri
# 3417 effect
# 999 effort
# 116 ego
# 180 eight
# 110 eighti
# 1764 either
# 143 elabor
# 170 elder
# 116 elect
# 134 electr
# 135 eleg
# 1161 element
# 128 eleph
# 164 elev
# 103 elimin
# 168 elizabeth
# 102 ellen
# 1934 els
# 106 els 's
# 129 elsewher
# 149 elvi
# 143 elvira
# 116 em
# 569 embarrass
# 104 embrac
# 231 emerg
# 121 emili
# 181 emma
# 1676 emot
# 98 emphasi
# 107 empir
# 208 employ
# 294 empti
# 111 enchant
# 371 encount
# 185 encourag
# 9197 end
# 136 end 's
# 113 end credit
# 346 end film
# 410 end movi
# 114 end n't
# 168 endear
# 293 endless
# 213 endur
# 280 enemi
# 310 energi
# 562 engag
# 137 engin
# 293 england
# 931 english
# 166 enhanc
# 4260 enjoy
# 289 enjoy film
# 324 enjoy movi
# 178 enjoy watch
# 149 enorm
# 3389 enough
# 124 enough make
# 147 ensembl
# 149 ensu
# 99 ensur
# 435 enter
# 98 enterpris
# 2685 entertain
# 91 entertain valu
# 121 enthusiast
# 1986 entir
# 205 entir film
# 232 entir movi
# 183 entri
# 185 environ
# 351 epic
# 2552 episod
# 621 equal
# 95 equip
# 551 era
# 255 eric
# 185 erot
# 160 error
# 861 escap
# 2517 especi
# 135 essenc
# 411 essenti
# 322 establish
# 132 estat
# 101 et
# 988 etc
# 140 etern
# 211 europ
# 321 european
# 132 eva
# 107 eve
# 12689 even
# 144 even better
# 163 even get
# 104 even know
# 91 even make
# 105 even n't
# 97 even one
# 91 even think
# 999 even though
# 97 even tri
# 230 even wors
# 1253 event
# 765 eventu
# 5831 ever
# 520 ever made
# 138 ever see
# 1252 ever seen
# 106 ever sinc
# 101 ever watch
# 3934 everi
# 99 everi charact
# 212 everi scene
# 187 everi singl
# 360 everi time
# 398 everybodi
# 164 everyday
# 2183 everyon
# 104 everyon 's
# 226 everyon els
# 93 everyon involv
# 2241 everyth
# 178 everyth els
# 180 everywher
# 409 evid
# 1371 evil
# 123 evok
# 111 evolv
# 105 ex
# 1189 exact
# 192 exagger
# 182 examin
# 1527 exampl
# 2201 excel
# 106 excel film
# 1816 except
# 207 excess
# 129 exchang
# 969 excit
# 108 excruci
# 499 excus
# 652 execut
# 142 exercis
# 111 exhibit
# 860 exist
# 93 exit
# 106 exot
# 2950 expect
# 91 expect movi
# 146 expect much
# 94 expect see
# 201 expens
# 1457 experi
# 244 experienc
# 94 experiment
# 260 expert
# 1018 explain
# 98 explain whi
# 314 explan
# 139 explicit
# 170 explod
# 468 exploit
# 471 explor
# 278 explos
# 231 expos
# 687 express
# 165 extend
# 93 extens
# 165 extent
# 499 extra
# 173 extraordinari
# 1446 extrem
# 1852 eye
# 106 f
# 185 fabul
# 2050 face
# 184 facial
# 117 facial express
# 3688 fact
# 167 fact 's
# 100 fact film
# 255 factor
# 140 factori
# 174 fade
# 1467 fail
# 101 fail miser
# 270 failur
# 1066 fair
# 189 fairi
# 495 faith
# 510 fake
# 118 falk
# 1976 fall
# 106 fall flat
# 438 fall love
# 163 fallen
# 207 fals
# 263 fame
# 3287 famili
# 103 famili 's
# 95 famili film
# 557 familiar
# 768 famous
# 3256 fan
# 103 fanat
# 138 fanci
# 653 fantasi
# 826 fantast
# 2845 far
# 106 far away
# 134 far better
# 119 farc
# 231 fare
# 121 farm
# 96 farmer
# 96 farrel
# 567 fascin
# 470 fashion
# 708 fast
# 131 fast forward
# 92 faster
# 269 fat
# 211 fatal
# 297 fate
# 2073 father
# 187 father 's
# 332 fault
# 320 favor
# 1398 favorit
# 135 favorit movi
# 121 favour
# 369 favourit
# 161 fay
# 149 fbi
# 704 fear
# 1829 featur
# 162 featur film
# 167 feed
# 5158 feel
# 95 feel good
# 618 feel like
# 126 feel sorri
# 227 feet
# 119 felix
# 357 fell
# 396 fellow
# 1515 felt
# 283 felt like
# 990 femal
# 102 femal lead
# 451 festiv
# 98 fever
# 124 fiancé
# 605 fiction
# 350 field
# 126 fifteen
# 125 fifti
# 1950 fight
# 293 fight scene
# 133 fighter
# 1152 figur
# 856 fill
# 46447 film
# 1738 film 's
# 98 film act
# 168 film actual
# 107 film almost
# 333 film also
# 142 film ani
# 183 film bad
# 135 film base
# 250 film becaus
# 99 film befor
# 117 film begin
# 95 film certain
# 95 film charact
# 137 film come
# 302 film could
# 111 film direct
# 125 film director
# 462 film doe
# 188 film doe n't
# 167 film end
# 253 film even
# 566 film ever
# 148 film ever made
# 201 film ever seen
# 122 film feel
# 251 film festiv
# 201 film film
# 167 film first
# 165 film get
# 109 film give
# 113 film go
# 229 film good
# 202 film great
# 123 film howev
# 92 film industri
# 645 film like
# 91 film littl
# 220 film look
# 99 film lot
# 470 film made
# 362 film make
# 214 film maker
# 135 film mani
# 108 film may
# 107 film might
# 145 film movi
# 162 film much
# 561 film n't
# 178 film never
# 179 film noir
# 92 film noth
# 478 film one
# 308 film onli
# 100 film open
# 108 film play
# 98 film pretti
# 94 film probabl
# 103 film quit
# 330 film realli
# 98 film releas
# 174 film see
# 255 film seem
# 264 film seen
# 134 film set
# 105 film shot
# 183 film show
# 96 film simpli
# 128 film star
# 147 film start
# 149 film still
# 109 film stori
# 177 film take
# 144 film think
# 213 film time
# 148 film tri
# 95 film two
# 381 film veri
# 106 film version
# 221 film watch
# 99 film way
# 207 film well
# 94 film without
# 117 film work
# 96 film worth
# 437 film would
# 122 film year
# 357 film-mak
# 118 film.th
# 122 film\
# 937 filmmak
# 2992 final
# 176 final scene
# 139 financi
# 5427 find
# 120 find movi
# 108 find themselv
# 119 find way
# 1334 fine
# 270 finest
# 171 finger
# 775 finish
# 791 fire
# 148 firm
# 8800 first
# 127 first episod
# 355 first film
# 236 first half
# 280 first minut
# 341 first movi
# 245 first one
# 100 first part
# 204 first place
# 248 first saw
# 113 first scene
# 101 first season
# 100 first thing
# 685 first time
# 175 first two
# 209 fish
# 120 fisher
# 97 fist
# 858 fit
# 829 five
# 210 five minut
# 120 five year
# 157 fix
# 101 flame
# 234 flash
# 395 flashback
# 560 flat
# 632 flaw
# 144 flawless
# 266 flesh
# 651 fli
# 1501 flick
# 170 flight
# 106 flip
# 145 float
# 296 floor
# 137 flop
# 102 florida
# 249 flow
# 116 flower
# 141 flynn
# 967 focus
# 438 folk
# 2172 follow
# 152 fond
# 106 fonda
# 306 food
# 366 fool
# 91 foolish
# 220 foot
# 640 footag
# 217 footbal
# 119 forbidden
# 1462 forc
# 299 ford
# 265 foreign
# 196 forest
# 358 forev
# 795 forget
# 189 forgett
# 245 forgiv
# 173 forgot
# 326 forgotten
# 925 form
# 200 format
# 530 former
# 353 formula
# 179 forth
# 120 forti
# 342 fortun
# 632 forward
# 197 foster
# 93 foul
# 2587 found
# 98 found film
# 114 found movi
# 850 four
# 171 fourth
# 333 fox
# 381 frame
# 280 franc
# 155 franchis
# 118 francisco
# 93 franco
# 724 frank
# 255 freak
# 298 fred
# 297 freddi
# 632 free
# 226 freedom
# 184 freeman
# 758 french
# 255 frequent
# 395 fresh
# 91 fri
# 190 friday
# 3238 friend
# 106 friend 's
# 307 friendship
# 308 frighten
# 592 front
# 352 frustrat
# 195 fu
# 108 fulci
# 149 fulfil
# 1628 full
# 413 fulli
# 2552 fun
# 105 fun movi
# 273 fun watch
# 144 function
# 118 fund
# 101 funer
# 4070 funni
# 92 funni 's
# 102 funni moment
# 112 funni movi
# 168 funnier
# 353 funniest
# 92 furthermor
# 852 futur
# 116 futurist
# 110 fx
# 101 gabriel
# 122 gadget
# 394 gag
# 263 gain
# 92 gambl
# 1523 game
# 105 gandhi
# 424 gang
# 341 gangster
# 94 gap
# 428 garbag
# 100 garbo
# 164 garden
# 255 gari
# 109 garner
# 181 gas
# 119 gate
# 187 gather
# 1216 gave
# 616 gay
# 104 gear
# 409 gem
# 272 gene
# 1234 general
# 476 generat
# 110 generic
# 126 generous
# 454 genius
# 1252 genr
# 158 gentl
# 504 genuin
# 906 georg
# 581 german
# 213 germani
# 14028 get
# 121 get ani
# 183 get away
# 221 get back
# 164 get better
# 133 get chanc
# 104 get feel
# 96 get good
# 124 get involv
# 138 get kill
# 96 get know
# 105 get movi
# 229 get see
# 187 get wrong
# 664 ghost
# 109 ghost stori
# 111 giallo
# 419 giant
# 237 gift
# 91 giggl
# 92 gimmick
# 103 ginger
# 3788 girl
# 163 girl 's
# 613 girlfriend
# 5760 give
# 116 give away
# 222 give film
# 252 give movi
# 131 give one
# 258 give us
# 1814 given
# 477 glad
# 102 glamor
# 219 glass
# 120 glenn
# 213 glimps
# 110 global
# 132 glori
# 124 glorious
# 141 glover
# 123 glow
# 9005 go
# 262 go back
# 148 go get
# 106 go happen
# 120 go movi
# 397 go see
# 142 go watch
# 104 go wrong
# 182 goal
# 1131 god
# 110 god 's
# 110 godfath
# 94 godzilla
# 2424 goe
# 249 gold
# 120 goldberg
# 251 golden
# 242 gon
# 241 gon na
# 731 gone
# 14702 good
# 149 good 's
# 219 good act
# 226 good actor
# 147 good bad
# 153 good enough
# 449 good film
# 196 good guy
# 176 good idea
# 337 good job
# 121 good laugh
# 172 good look
# 729 good movi
# 107 good old
# 226 good one
# 197 good perform
# 128 good reason
# 217 good stori
# 384 good thing
# 173 good time
# 102 good way
# 112 good\
# 161 goofi
# 230 gordon
# 963 gore
# 380 gorgeous
# 231 gori
# 3702 got
# 129 got ta
# 123 gothic
# 285 gotten
# 441 govern
# 262 grab
# 401 grace
# 354 grade
# 134 gradual
# 111 graduat
# 92 graham
# 303 grand
# 96 grandfath
# 128 grandmoth
# 462 grant
# 429 graphic
# 126 grasp
# 142 grate
# 240 gratuit
# 199 grave
# 117 gray
# 9125 great
# 143 great act
# 185 great actor
# 110 great cast
# 140 great deal
# 365 great film
# 225 great job
# 488 great movi
# 185 great perform
# 151 great stori
# 173 greater
# 744 greatest
# 116 greek
# 428 green
# 249 grew
# 153 grey
# 114 griffith
# 187 grim
# 92 grinch
# 242 grip
# 191 gritti
# 201 gross
# 421 ground
# 1124 group
# 646 grow
# 213 grown
# 178 gruesom
# 171 guarante
# 251 guard
# 1534 guess
# 103 guess 's
# 200 guest
# 196 guid
# 131 guilt
# 188 guilti
# 779 gun
# 97 gundam
# 196 gut
# 4139 guy
# 128 guy 's
# 103 guy get
# 155 ha
# 129 hack
# 506 hair
# 102 hal
# 1715 half
# 241 half hour
# 107 half movi
# 172 halfway
# 216 hall
# 207 halloween
# 115 ham
# 124 hamilton
# 116 hamlet
# 141 hammer
# 1942 hand
# 500 handl
# 230 handsom
# 433 hang
# 241 hank
# 3500 happen
# 1049 happi
# 151 happi end
# 146 happili
# 3003 hard
# 156 hard believ
# 93 hard time
# 99 hardcor
# 111 harder
# 173 hardi
# 115 harm
# 702 harri
# 224 harsh
# 105 hart
# 100 hartley
# 103 harvey
# 241 hat
# 1232 hate
# 98 hate movi
# 108 hatr
# 512 haunt
# 135 hawk
# 102 hbo
# 1899 head
# 126 health
# 1037 hear
# 1093 heard
# 1324 heart
# 103 heartbreak
# 137 heat
# 344 heaven
# 394 heavi
# 178 heavili
# 212 heck
# 146 height
# 336 held
# 143 helen
# 121 helicopt
# 959 hell
# 2773 help
# 153 henc
# 413 henri
# 1202 hero
# 123 heroic
# 329 heroin
# 101 hesit
# 135 heston
# 384 hey
# 333 hidden
# 411 hide
# 128 hideous
# 2987 high
# 443 high recommend
# 511 high school
# 279 higher
# 103 highest
# 351 highlight
# 1044 hilari
# 353 hill
# 312 hint
# 134 hip
# 141 hippi
# 394 hire
# 551 histor
# 1253 histori
# 1332 hit
# 94 hit-man
# 203 hitchcock
# 292 hitler
# 182 hoffman
# 1035 hold
# 475 hole
# 115 holi
# 170 holiday
# 96 holli
# 104 hollow
# 1818 hollywood
# 115 hollywood 's
# 185 holm
# 146 homag
# 1846 home
# 93 home video
# 143 homeless
# 107 homer
# 104 homicid
# 163 homosexu
# 891 honest
# 95 honesti
# 187 hong
# 170 hong kong
# 233 honor
# 174 hood
# 265 hook
# 2479 hope
# 99 hope would
# 170 hopeless
# 95 hopper
# 152 horrend
# 1385 horribl
# 119 horrid
# 165 horrif
# 154 horrifi
# 3375 horror
# 126 horror fan
# 691 horror film
# 144 horror flick
# 725 horror movi
# 404 hors
# 368 hospit
# 200 host
# 630 hot
# 383 hotel
# 2004 hour
# 159 hour half
# 2110 hous
# 256 howard
# 3298 howev
# 138 hudson
# 1002 huge
# 121 huge fan
# 181 hugh
# 124 huh
# 2156 human
# 104 humbl
# 109 humili
# 1525 humor
# 435 humour
# 291 hundr
# 97 hung
# 386 hunt
# 292 hunter
# 503 hurt
# 1039 husband
# 180 hype
# 176 hyster
# 202 i.e
# 128 ian
# 251 ice
# 191 icon
# 2581 idea
# 196 ideal
# 343 ident
# 204 identifi
# 439 idiot
# 558 ignor
# 309 ii
# 117 iii
# 256 ill
# 101 illeg
# 105 illog
# 155 illustr
# 834 imag
# 179 imageri
# 1470 imagin
# 638 imdb
# 204 imit
# 534 immedi
# 159 immens
# 107 immigr
# 95 immort
# 374 impact
# 107 imperson
# 134 implaus
# 153 impli
# 1183 import
# 519 imposs
# 1430 impress
# 363 improv
# 103 inan
# 102 inappropri
# 166 incid
# 103 incident
# 2004 includ
# 148 incoher
# 122 incompet
# 96 incomprehens
# 123 inconsist
# 252 increas
# 1182 incred
# 693 inde
# 385 independ
# 97 independ film
# 197 indi
# 166 india
# 497 indian
# 229 indic
# 394 individu
# 102 indulg
# 423 industri
# 204 inept
# 222 inevit
# 140 inexplic
# 151 infam
# 101 infect
# 98 inferior
# 355 influenc
# 581 inform
# 132 ingredi
# 175 inhabit
# 109 inherit
# 420 initi
# 91 inject
# 190 inner
# 581 innoc
# 147 innov
# 324 insan
# 125 insert
# 604 insid
# 313 insight
# 209 insist
# 162 inspector
# 751 inspir
# 189 instal
# 337 instanc
# 232 instant
# 2131 instead
# 135 instinct
# 101 institut
# 436 insult
# 172 integr
# 233 intellectu
# 875 intellig
# 472 intend
# 562 intens
# 571 intent
# 284 interact
# 4815 interest
# 106 interest charact
# 123 interest film
# 103 interest movi
# 141 interest see
# 361 intern
# 150 internet
# 283 interpret
# 106 interrupt
# 408 interview
# 99 intim
# 542 intrigu
# 541 introduc
# 169 introduct
# 93 invas
# 320 invent
# 135 invest
# 434 investig
# 214 invis
# 249 invit
# 1939 involv
# 105 ireland
# 188 irish
# 393 iron
# 153 ironi
# 343 irrit
# 545 island
# 161 isol
# 685 issu
# 116 it.i
# 132 it.th
# 105 it\
# 146 itali
# 520 italian
# 136 item
# 129 j.
# 887 jack
# 234 jacki
# 106 jacki chan
# 337 jackson
# 181 jail
# 156 jake
# 1043 jame
# 99 jame bond
# 92 jame stewart
# 124 jami
# 635 jane
# 275 japan
# 683 japanes
# 119 jar
# 318 jason
# 132 jaw
# 151 jay
# 102 jazz
# 120 jealous
# 285 jean
# 297 jeff
# 106 jeffrey
# 102 jenni
# 254 jennif
# 136 jeremi
# 153 jerk
# 361 jerri
# 199 jess
# 160 jessica
# 269 jesus
# 127 jet
# 100 jew
# 152 jewish
# 448 jim
# 274 jimmi
# 296 joan
# 2375 job
# 660 joe
# 115 joey
# 2155 john
# 315 johnni
# 191 johnson
# 373 join
# 1557 joke
# 177 jon
# 97 jonathan
# 353 jone
# 224 joseph
# 140 journalist
# 436 journey
# 326 joy
# 228 jr.
# 458 judg
# 120 judi
# 222 juli
# 180 julia
# 642 jump
# 185 jungl
# 182 junk
# 375 justic
# 215 justifi
# 97 justin
# 110 juvenil
# 106 kane
# 110 kapoor
# 115 karen
# 133 karloff
# 272 kate
# 111 kay
# 295 keaton
# 2505 keep
# 410 kelli
# 121 ken
# 110 kennedi
# 110 kenneth
# 746 kept
# 277 kevin
# 414 key
# 98 khan
# 530 kick
# 3003 kid
# 120 kid 's
# 93 kid movi
# 273 kidnap
# 3580 kill
# 150 kill peopl
# 1604 killer
# 200 kim
# 2991 kind
# 106 kind film
# 191 kind movi
# 273 kinda
# 997 king
# 94 king 's
# 111 kirk
# 284 kiss
# 120 kitchen
# 894 knew
# 143 knife
# 137 knight
# 278 knock
# 7385 know
# 347 know 's
# 91 know go
# 117 know movi
# 91 know peopl
# 243 know whi
# 290 knowledg
# 952 known
# 252 kong
# 137 korean
# 123 kubrick
# 113 kudo
# 165 kung
# 155 kung fu
# 145 kurt
# 95 kyle
# 505 la
# 130 lab
# 130 label
# 1803 lack
# 139 lack ani
# 1080 ladi
# 133 laid
# 236 lake
# 717 lame
# 555 land
# 196 landscap
# 161 lane
# 530 languag
# 769 larg
# 122 larger
# 170 larri
# 3143 last
# 170 last minut
# 187 last night
# 93 last scene
# 92 last time
# 204 last year
# 1209 late
# 131 late 's
# 142 late night
# 2099 later
# 95 later film
# 201 latest
# 340 latter
# 2778 laugh
# 143 laugh loud
# 488 laughabl
# 231 laughter
# 116 launch
# 156 laura
# 122 laurel
# 478 law
# 109 lawrenc
# 239 lawyer
# 174 lay
# 125 layer
# 184 lazi
# 123 le
# 2631 lead
# 123 lead actor
# 173 lead charact
# 93 lead ladi
# 102 lead man
# 145 lead role
# 299 leader
# 191 leagu
# 115 lean
# 112 leap
# 1360 learn
# 3081 least
# 142 least one
# 2236 leav
# 325 led
# 790 lee
# 92 lee 's
# 2078 left
# 265 leg
# 114 legal
# 340 legend
# 186 legendari
# 106 lemmon
# 96 lena
# 120 lend
# 280 length
# 97 leo
# 98 leon
# 108 leonard
# 254 lesbian
# 169 lesli
# 1859 less
# 150 lesser
# 388 lesson
# 2698 let
# 634 let 's
# 125 let alon
# 119 let go
# 216 letter
# 1116 level
# 211 lewi
# 98 li
# 204 liber
# 139 librari
# 604 lie
# 5992 life
# 125 life 's
# 101 life\
# 120 lifestyl
# 171 lifetim
# 190 lift
# 1427 light
# 384 likabl
# 22146 like
# 312 like 's
# 112 like ani
# 94 like bad
# 98 like charact
# 399 like film
# 106 like first
# 109 like good
# 155 like mani
# 638 like movi
# 148 like n't
# 365 like one
# 92 like real
# 107 like said
# 126 like say
# 239 like see
# 102 like someth
# 297 like watch
# 98 like would
# 158 lili
# 523 limit
# 163 lincoln
# 105 linda
# 3202 line
# 92 linger
# 191 link
# 193 lion
# 145 lip
# 175 lisa
# 719 list
# 598 listen
# 540 liter
# 6367 littl
# 298 littl bit
# 106 littl boy
# 114 littl film
# 213 littl girl
# 109 littl kid
# 4242 live
# 138 lloyd
# 297 load
# 1028 local
# 685 locat
# 321 lock
# 376 logic
# 92 lol
# 447 london
# 271 lone
# 3260 long
# 389 long time
# 465 longer
# 9668 look
# 108 look film
# 262 look forward
# 223 look good
# 119 look great
# 1785 look like
# 99 look movi
# 108 look veri
# 426 loos
# 358 lord
# 122 los
# 93 los angel
# 819 lose
# 208 loser
# 292 loss
# 1460 lost
# 4719 lot
# 148 lot better
# 150 lot fun
# 172 lot peopl
# 115 lou
# 416 loud
# 213 loui
# 216 lousi
# 152 lovabl
# 8672 love
# 93 love 's
# 174 love film
# 166 love interest
# 408 love movi
# 124 love one
# 103 love scene
# 106 love see
# 352 love stori
# 618 lover
# 1329 low
# 597 low budget
# 279 low-budget
# 249 lower
# 99 loyal
# 144 luca
# 142 luci
# 244 luck
# 233 lucki
# 122 luckili
# 193 ludicr
# 180 lugosi
# 240 luke
# 95 lumet
# 92 lundgren
# 139 lust
# 284 lynch
# 157 lyric
# 404 machin
# 100 maci
# 648 mad
# 7992 made
# 250 made film
# 112 made laugh
# 293 made movi
# 99 made sens
# 116 made tv
# 105 madonna
# 120 mafia
# 171 magazin
# 104 maggi
# 677 magic
# 294 magnific
# 2651 main
# 921 main charact
# 189 mainstream
# 210 maintain
# 1179 major
# 14511 make
# 211 make ani
# 164 make feel
# 639 make film
# 149 make fun
# 212 make good
# 141 make great
# 150 make laugh
# 154 make look
# 92 make mistak
# 832 make movi
# 112 make much
# 193 make one
# 423 make sens
# 209 make sure
# 134 make think
# 163 make us
# 105 make veri
# 123 make want
# 93 make wonder
# 193 make-up
# 505 maker
# 200 makeup
# 686 male
# 102 mall
# 5473 man
# 385 man 's
# 168 man\
# 1518 manag
# 91 manag get
# 110 manhattan
# 6607 mani
# 167 mani film
# 133 mani movi
# 431 mani peopl
# 126 mani scene
# 123 mani thing
# 354 mani time
# 155 mani way
# 206 mani year
# 123 maniac
# 259 manipul
# 108 mann
# 531 manner
# 164 mansion
# 133 mar
# 145 march
# 113 margaret
# 732 mari
# 171 maria
# 101 marin
# 95 mario
# 804 mark
# 331 market
# 903 marri
# 431 marriag
# 106 marshal
# 94 marti
# 317 martial
# 263 martial art
# 366 martin
# 303 marvel
# 326 mask
# 229 mass
# 142 massacr
# 209 massiv
# 696 master
# 639 masterpiec
# 753 match
# 165 mate
# 794 materi
# 163 matrix
# 240 matt
# 1308 matter
# 153 matthau
# 126 matthew
# 239 matur
# 209 max
# 3355 may
# 99 may seem
# 2242 mayb
# 174 mayb 's
# 100 mayor
# 91 me\
# 2845 mean
# 91 meander
# 143 meaning
# 111 meaningless
# 607 meant
# 207 meanwhil
# 159 measur
# 116 meat
# 171 mechan
# 288 media
# 187 medic
# 390 mediocr
# 137 medium
# 1581 meet
# 118 mel
# 201 melodrama
# 129 melodramat
# 159 melt
# 853 member
# 696 memor
# 577 memori
# 1785 men
# 230 menac
# 527 mental
# 1514 mention
# 106 merci
# 539 mere
# 196 merit
# 94 mesmer
# 761 mess
# 925 messag
# 284 met
# 182 metal
# 137 metaphor
# 199 method
# 182 mexican
# 177 mexico
# 187 mgm
# 1315 michael
# 163 michell
# 103 mickey
# 116 mid
# 796 middl
# 167 midnight
# 2906 might
# 113 might well
# 129 miik
# 277 mike
# 287 mild
# 112 mildr
# 359 mile
# 429 militari
# 102 milk
# 121 mill
# 159 miller
# 500 million
# 123 million dollar
# 108 min
# 2037 mind
# 166 mindless
# 329 mine
# 94 mini
# 142 minim
# 478 minor
# 3492 minut
# 177 minut film
# 169 minut movi
# 112 miracl
# 230 mirror
# 167 miscast
# 229 miser
# 92 mislead
# 2090 miss
# 278 mission
# 595 mistak
# 125 mistaken
# 118 mitchel
# 720 mix
# 103 mixtur
# 157 mob
# 104 mock
# 377 model
# 870 modern
# 118 modesti
# 367 mom
# 2687 moment
# 118 moment film
# 2276 money
# 120 monk
# 186 monkey
# 837 monster
# 136 montag
# 94 montana
# 405 month
# 438 mood
# 108 moodi
# 242 moon
# 238 moor
# 641 moral
# 261 morgan
# 262 morn
# 185 moron
# 93 morri
# 1504 mother
# 115 mother 's
# 416 motion
# 161 motion pictur
# 450 motiv
# 294 mountain
# 142 mous
# 372 mouth
# 2338 move
# 305 movement
# 49698 movi
# 140 movi 'm
# 1177 movi 's
# 93 movi absolut
# 93 movi act
# 194 movi actual
# 93 movi almost
# 261 movi also
# 109 movi ani
# 345 movi bad
# 173 movi base
# 407 movi becaus
# 117 movi befor
# 94 movi came
# 96 movi charact
# 152 movi come
# 117 movi complet
# 376 movi could
# 117 movi definit
# 506 movi doe
# 251 movi doe n't
# 249 movi end
# 97 movi enjoy
# 359 movi even
# 963 movi ever
# 190 movi ever made
# 398 movi ever seen
# 95 movi expect
# 92 movi fail
# 104 movi fan
# 116 movi feel
# 129 movi film
# 223 movi first
# 241 movi get
# 123 movi give
# 186 movi go
# 297 movi good
# 120 movi got
# 281 movi great
# 107 movi howev
# 109 movi know
# 903 movi like
# 98 movi littl
# 189 movi look
# 137 movi lot
# 120 movi love
# 507 movi made
# 409 movi make
# 118 movi mani
# 120 movi may
# 104 movi might
# 319 movi movi
# 185 movi much
# 106 movi must
# 841 movi n't
# 196 movi never
# 137 movi noth
# 581 movi one
# 330 movi onli
# 110 movi peopl
# 105 movi play
# 111 movi plot
# 122 movi pretti
# 122 movi probabl
# 93 movi quit
# 459 movi realli
# 100 movi saw
# 199 movi see
# 246 movi seem
# 321 movi seen
# 109 movi set
# 195 movi show
# 91 movi sinc
# 183 movi star
# 243 movi start
# 160 movi still
# 107 movi stori
# 95 movi suck
# 108 movi suppos
# 189 movi take
# 105 movi terribl
# 121 movi theater
# 196 movi think
# 102 movi thought
# 246 movi time
# 163 movi tri
# 429 movi veri
# 141 movi want
# 360 movi watch
# 114 movi way
# 193 movi well
# 124 movi without
# 115 movi worth
# 532 movi would
# 130 movi year
# 101 movie.i
# 142 movie.th
# 192 movie\
# 330 mr
# 1044 mr.
# 188 mrs.
# 283 ms.
# 134 mst3k
# 9565 much
# 714 much better
# 137 much film
# 104 much fun
# 122 much less
# 315 much like
# 114 much movi
# 92 much much
# 165 much time
# 192 multipl
# 102 mummi
# 91 mundan
# 140 muppet
# 1994 murder
# 209 murphi
# 101 museum
# 4083 music
# 137 music number
# 229 music score
# 117 music video
# 150 musician
# 131 muslim
# 3105 must
# 116 must admit
# 217 must say
# 293 must see
# 120 must-se
# 95 mutant
# 98 myer
# 1314 mysteri
# 110 mystic
# 33365 n't
# 105 n't act
# 106 n't alway
# 263 n't ani
# 145 n't anyth
# 398 n't bad
# 500 n't believ
# 220 n't bother
# 425 n't care
# 134 n't come
# 108 n't disappoint
# 164 n't enough
# 1364 n't even
# 124 n't exact
# 341 n't expect
# 151 n't feel
# 216 n't find
# 127 n't funni
# 984 n't get
# 163 n't get wrong
# 225 n't give
# 411 n't go
# 205 n't good
# 120 n't great
# 459 n't help
# 93 n't imagin
# 1417 n't know
# 119 n't know whi
# 191 n't let
# 653 n't like
# 186 n't look
# 618 n't make
# 113 n't matter
# 170 n't mean
# 150 n't mind
# 158 n't miss
# 338 n't much
# 205 n't need
# 141 n't one
# 231 n't quit
# 132 n't read
# 887 n't realli
# 135 n't recommend
# 208 n't rememb
# 311 n't say
# 532 n't see
# 414 n't seem
# 453 n't seen
# 94 n't show
# 130 n't stand
# 138 n't stop
# 259 n't take
# 138 n't tell
# 887 n't think
# 136 n't tri
# 321 n't understand
# 92 n't understand whi
# 182 n't veri
# 177 n't wait
# 550 n't want
# 313 n't wast
# 219 n't wast time
# 376 n't watch
# 311 n't work
# 385 na
# 179 nail
# 225 naiv
# 422 nake
# 2794 name
# 221 nanci
# 840 narrat
# 359 nasti
# 108 natali
# 503 nation
# 294 nativ
# 1436 natur
# 155 navi
# 264 nazi
# 1578 near
# 158 near end
# 106 nearbi
# 210 neat
# 308 necessari
# 178 necessarili
# 152 neck
# 179 ned
# 3359 need
# 184 needless
# 106 needless say
# 407 negat
# 107 neglect
# 232 neighbor
# 151 neighborhood
# 118 neil
# 526 neither
# 146 nelson
# 95 nephew
# 102 nerd
# 107 nerv
# 109 nervous
# 219 network
# 6416 never
# 257 never get
# 95 never got
# 173 never heard
# 108 never know
# 113 never made
# 261 never realli
# 118 never see
# 91 never seem
# 391 never seen
# 216 nevertheless
# 4215 new
# 712 new york
# 158 new york citi
# 312 news
# 137 newspap
# 1641 next
# 120 next time
# 2242 nice
# 121 nice see
# 110 nicholson
# 293 nick
# 2117 night
# 391 nightmar
# 139 nine
# 108 ninja
# 100 niro
# 150 nobl
# 445 nobodi
# 117 nod
# 373 noir
# 197 nois
# 392 nomin
# 115 non
# 136 non-exist
# 977 none
# 140 nonetheless
# 327 nonsens
# 712 normal
# 123 norman
# 196 north
# 157 nose
# 93 nostalg
# 287 notabl
# 134 notch
# 936 note
# 4174 noth
# 179 noth els
# 102 noth happen
# 110 noth like
# 123 noth new
# 766 notic
# 135 notion
# 186 notori
# 1098 novel
# 158 nowaday
# 424 nowher
# 131 nuanc
# 124 nuclear
# 197 nude
# 573 nuditi
# 1346 number
# 274 numer
# 153 nurs
# 140 nut
# 357 object
# 173 obnoxi
# 176 obscur
# 267 observ
# 449 obsess
# 102 obtain
# 2183 obvious
# 171 occas
# 445 occasion
# 377 occur
# 116 ocean
# 800 odd
# 207 offend
# 254 offens
# 1029 offer
# 905 offic
# 181 offici
# 1564 often
# 1273 oh
# 105 oh yeah
# 143 oil
# 815 ok
# 100 ok.
# 650 okay
# 4076 old
# 216 old man
# 643 older
# 238 oliv
# 104 olivi
# 95 olli
# 92 on-screen
# 2234 onc
# 26433 one
# 440 one 's
# 176 one anoth
# 861 one best
# 144 one better
# 99 one big
# 159 one charact
# 187 one could
# 298 one day
# 132 one doe
# 311 one favorit
# 336 one film
# 154 one first
# 103 one funniest
# 109 one get
# 130 one good
# 143 one great
# 183 one greatest
# 91 one last
# 105 one like
# 109 one man
# 118 one mani
# 113 one might
# 332 one movi
# 164 one n't
# 164 one night
# 206 one one
# 185 one onli
# 118 one person
# 290 one point
# 149 one realli
# 100 one reason
# 291 one scene
# 91 one see
# 483 one thing
# 222 one time
# 236 one two
# 153 one veri
# 102 one watch
# 92 one wonder
# 480 one worst
# 169 one worst movi
# 234 one would
# 98 one-dimension
# 156 one-lin
# 11823 onli
# 176 onli becaus
# 93 onli film
# 96 onli find
# 101 onli get
# 177 onli good
# 104 onli minut
# 119 onli movi
# 606 onli one
# 316 onli reason
# 537 onli thing
# 101 onli time
# 129 onli two
# 131 onli way
# 328 onto
# 2031 open
# 129 open credit
# 193 open scene
# 91 open sequenc
# 262 oper
# 376 opera
# 1023 opinion
# 473 opportun
# 164 oppos
# 315 opposit
# 94 oppress
# 106 option
# 1125 order
# 264 ordinari
# 243 organ
# 97 orient
# 3949 origin
# 160 origin film
# 142 origin movi
# 99 origin stori
# 95 orson
# 880 oscar
# 640 otherwis
# 114 ought
# 136 ourselv
# 129 outcom
# 101 outer
# 172 outfit
# 226 outrag
# 638 outsid
# 417 outstand
# 198 over-the-top
# 164 overact
# 1131 overal
# 192 overcom
# 114 overdon
# 233 overlook
# 112 overr
# 188 overwhelm
# 142 owe
# 97 owen
# 310 owner
# 1019 pace
# 198 pacino
# 331 pack
# 112 packag
# 132 pad
# 412 page
# 347 paid
# 1094 pain
# 101 pain watch
# 517 paint
# 339 pair
# 115 pal
# 108 palma
# 94 paltrow
# 160 pan
# 105 panic
# 93 pant
# 250 paper
# 152 par
# 149 parallel
# 873 parent
# 376 pari
# 449 park
# 234 parker
# 288 parodi
# 5220 part
# 256 part film
# 350 part movi
# 622 parti
# 97 partial
# 192 particip
# 1797 particular
# 334 partner
# 932 pass
# 92 passeng
# 434 passion
# 1287 past
# 147 pat
# 234 path
# 468 pathet
# 257 patient
# 214 patrick
# 91 patriot
# 94 pattern
# 852 paul
# 119 pauli
# 102 paus
# 885 pay
# 135 pay attent
# 246 peac
# 125 peak
# 97 pearl
# 94 pen
# 9169 peopl
# 237 peopl 's
# 117 peopl get
# 247 peopl like
# 95 peopl live
# 264 peopl n't
# 118 peopl say
# 119 peopl think
# 121 peopl watch
# 132 peopl would
# 129 per
# 93 percept
# 2314 perfect
# 5390 perform
# 1610 perhap
# 779 period
# 118 perri
# 3151 person
# 138 persona
# 292 perspect
# 93 pervert
# 192 pet
# 831 peter
# 174 philip
# 142 phillip
# 130 philosoph
# 109 philosophi
# 380 phone
# 170 photo
# 382 photograph
# 396 photographi
# 106 phrase
# 525 physic
# 118 piano
# 1043 pick
# 1884 pictur
# 129 pie
# 1899 piec
# 129 piec crap
# 111 pierc
# 118 pig
# 239 pile
# 339 pilot
# 103 pin
# 115 pirat
# 121 pit
# 168 pitch
# 300 piti
# 192 pitt
# 2907 place
# 187 plagu
# 594 plain
# 827 plan
# 363 plane
# 505 planet
# 163 plant
# 145 plastic
# 120 plausibl
# 8558 play
# 113 play charact
# 112 play like
# 144 play part
# 212 play role
# 552 player
# 1165 pleas
# 132 pleas n't
# 358 pleasant
# 138 pleasant surpris
# 356 pleasur
# 637 plenti
# 91 plight
# 91 plod
# 6573 plot
# 161 plot hole
# 197 plot line
# 105 plot movi
# 98 plot point
# 166 plot twist
# 609 plus
# 92 poem
# 103 poetic
# 161 poignant
# 4037 point
# 155 point film
# 148 point movi
# 222 point view
# 515 pointless
# 132 poison
# 103 poke
# 99 polanski
# 1077 polic
# 96 polic offic
# 142 polish
# 925 polit
# 111 politician
# 154 pool
# 2530 poor
# 120 poor act
# 103 poor written
# 451 pop
# 104 popcorn
# 191 popul
# 627 popular
# 338 porn
# 94 porno
# 142 portion
# 164 portrait
# 1879 portray
# 181 pose
# 834 posit
# 301 possess
# 1836 possibl
# 336 post
# 189 poster
# 691 potenti
# 144 pound
# 96 pour
# 122 poverti
# 206 powel
# 1810 power
# 463 practic
# 274 prais
# 112 pray
# 92 preach
# 119 precious
# 150 precis
# 104 predecessor
# 1066 predict
# 367 prefer
# 171 pregnant
# 99 prejudic
# 149 premier
# 728 premis
# 362 prepar
# 407 presenc
# 1459 present
# 274 presid
# 192 press
# 124 pressur
# 205 presum
# 263 pretend
# 284 pretenti
# 3630 pretti
# 162 pretti bad
# 535 pretti good
# 569 pretti much
# 105 pretti well
# 218 prevent
# 166 preview
# 829 previous
# 95 previous film
# 305 price
# 149 pride
# 260 priest
# 105 primari
# 103 primarili
# 199 prime
# 306 princ
# 196 princess
# 170 princip
# 103 principl
# 246 print
# 189 prior
# 645 prison
# 287 privat
# 113 prize
# 2856 probabl
# 138 probabl best
# 113 probabl one
# 101 probabl would
# 2272 problem
# 107 problem film
# 117 problem movi
# 272 proceed
# 316 process
# 1719 produc
# 2153 product
# 309 product valu
# 402 profession
# 216 professor
# 176 profound
# 367 program
# 93 programm
# 342 progress
# 672 project
# 113 prom
# 103 promin
# 598 promis
# 246 promot
# 100 prompt
# 144 proof
# 149 prop
# 192 propaganda
# 385 proper
# 94 properti
# 182 prostitut
# 377 protagonist
# 298 protect
# 104 protest
# 216 proud
# 930 prove
# 993 provid
# 147 provok
# 121 psychiatrist
# 92 psychic
# 198 psycho
# 364 psycholog
# 96 psychopath
# 117 psychot
# 660 public
# 114 publish
# 908 pull
# 110 pulp
# 106 pun
# 264 punch
# 163 punish
# 115 punk
# 135 puppet
# 214 purchas
# 723 pure
# 97 purpl
# 542 purpos
# 180 pursu
# 94 pursuit
# 411 push
# 3073 put
# 208 put togeth
# 137 puzzl
# 129 qualifi
# 1426 qualiti
# 95 qualiti film
# 349 queen
# 178 quest
# 1289 question
# 940 quick
# 362 quiet
# 175 quirki
# 3809 quit
# 228 quit good
# 108 quit well
# 286 quot
# 163 r
# 94 rabbit
# 459 race
# 183 rachel
# 105 racial
# 144 racism
# 167 racist
# 93 radic
# 283 radio
# 158 rage
# 285 rain
# 492 rais
# 142 ralph
# 97 rambl
# 97 rambo
# 110 ramon
# 234 ran
# 447 random
# 316 rang
# 106 ranger
# 270 rank
# 141 rap
# 520 rape
# 105 rapid
# 92 rapist
# 744 rare
# 167 rat
# 1950 rate
# 139 rate movi
# 2717 rather
# 98 ration
# 130 rave
# 175 raw
# 354 ray
# 546 reach
# 158 react
# 368 reaction
# 2703 read
# 411 read book
# 96 read comment
# 136 read review
# 134 reader
# 329 readi
# 4446 real
# 445 real life
# 105 real peopl
# 104 real world
# 123 real-lif
# 273 realis
# 240 realism
# 780 realist
# 981 realiti
# 1255 realiz
# 11659 realli
# 393 realli bad
# 109 realli care
# 172 realli doe
# 241 realli enjoy
# 92 realli funni
# 124 realli get
# 410 realli good
# 133 realli great
# 93 realli happen
# 345 realli like
# 111 realli love
# 130 realli make
# 406 realli n't
# 143 realli need
# 197 realli realli
# 109 realli think
# 242 realli want
# 3125 reason
# 123 reason watch
# 285 reason whi
# 150 rebel
# 277 recal
# 522 receiv
# 1073 recent
# 345 recogn
# 2239 recommend
# 153 recommend anyon
# 206 recommend film
# 237 recommend movi
# 550 record
# 120 recov
# 127 recreat
# 99 recruit
# 94 recycl
# 758 red
# 460 redeem
# 119 redeem qualiti
# 146 redempt
# 160 reduc
# 164 reed
# 122 reel
# 129 reev
# 670 refer
# 362 reflect
# 238 refresh
# 343 refus
# 461 regard
# 114 regardless
# 96 region
# 253 regret
# 337 regular
# 203 reject
# 1121 relat
# 1299 relationship
# 159 relax
# 1816 releas
# 116 relentless
# 179 relev
# 262 reli
# 232 relief
# 300 religi
# 252 religion
# 125 reluct
# 836 remain
# 663 remak
# 557 remark
# 2030 rememb
# 909 remind
# 212 reminisc
# 354 remot
# 225 remov
# 174 render
# 102 rendit
# 1196 rent
# 175 rent movi
# 210 rental
# 574 repeat
# 149 repetit
# 341 replac
# 94 repli
# 478 report
# 411 repres
# 95 repress
# 98 repuls
# 215 reput
# 441 requir
# 321 rescu
# 306 research
# 387 resembl
# 107 reserv
# 214 resid
# 173 resist
# 141 resolut
# 122 resolv
# 144 resort
# 127 resourc
# 855 respect
# 111 respond
# 524 respons
# 1830 rest
# 266 rest cast
# 149 rest film
# 195 rest movi
# 128 restaur
# 160 restor
# 1019 result
# 96 resurrect
# 104 retain
# 175 retard
# 151 retir
# 1130 return
# 139 reunion
# 112 reunit
# 735 reveal
# 205 revel
# 497 reveng
# 123 revers
# 2128 review
# 102 review movi
# 117 reviv
# 95 revolt
# 175 revolut
# 103 revolutionari
# 284 revolv
# 205 revolv around
# 181 reward
# 129 reynold
# 635 rich
# 899 richard
# 91 richardson
# 99 rick
# 122 rid
# 598 ride
# 1111 ridicul
# 99 rifl
# 3442 right
# 483 ring
# 91 riot
# 409 rip
# 140 rip-off
# 379 rise
# 205 risk
# 133 ritter
# 206 rival
# 322 river
# 113 rivet
# 443 road
# 341 rob
# 95 robberi
# 1065 robert
# 236 robin
# 100 robinson
# 350 robot
# 150 rochest
# 961 rock
# 134 rocket
# 361 roger
# 4145 role
# 93 role play
# 589 roll
# 114 roman
# 701 romanc
# 849 romant
# 234 romant comedi
# 114 romero
# 180 ron
# 965 room
# 108 roommat
# 286 root
# 249 rose
# 91 rotten
# 231 rough
# 334 round
# 262 routin
# 140 row
# 197 roy
# 113 royal
# 255 rubbish
# 550 ruin
# 455 rule
# 2544 run
# 161 run around
# 151 run away
# 181 run time
# 108 rural
# 315 rush
# 235 russel
# 330 russian
# 119 ruth
# 125 ruthless
# 215 ryan
# 152 sacrific
# 1604 sad
# 133 sadist
# 254 safe
# 104 saga
# 2169 said
# 100 saint
# 247 sake
# 97 sale
# 127 salli
# 436 sam
# 118 samurai
# 203 san
# 102 san francisco
# 168 sandler
# 95 sandra
# 268 santa
# 96 sappi
# 182 sarah
# 289 sat
# 158 satan
# 379 satir
# 403 satisfi
# 212 saturday
# 115 saturday night
# 159 savag
# 1677 save
# 97 save grace
# 3144 saw
# 283 saw film
# 486 saw movi
# 7395 say
# 253 say 's
# 98 say anyth
# 195 say film
# 123 say least
# 239 say movi
# 99 say much
# 185 say n't
# 127 say one
# 147 say someth
# 198 scale
# 710 scare
# 137 scarecrow
# 941 scari
# 126 scari movi
# 223 scenario
# 10261 scene
# 151 scene 's
# 191 scene film
# 193 scene movi
# 109 scene n't
# 103 scene one
# 397 sceneri
# 179 scheme
# 1601 school
# 537 sci-fi
# 497 scienc
# 206 scienc fiction
# 110 scientif
# 448 scientist
# 94 scope
# 1162 score
# 569 scott
# 92 scottish
# 124 scratch
# 650 scream
# 2473 screen
# 182 screen time
# 712 screenplay
# 208 screenwrit
# 170 screw
# 3228 script
# 92 scroog
# 243 sea
# 156 seagal
# 258 sean
# 506 search
# 1022 season
# 267 seat
# 2234 second
# 164 second half
# 136 second time
# 792 secret
# 137 secretari
# 231 section
# 249 secur
# 121 seduc
# 100 seduct
# 13795 see
# 180 see 's
# 101 see ani
# 588 see film
# 101 see good
# 931 see movi
# 94 see n't
# 183 see one
# 91 see peopl
# 116 see someth
# 185 see whi
# 103 seed
# 405 seek
# 7536 seem
# 754 seem like
# 104 seem littl
# 129 seem veri
# 6549 seen
# 159 seen befor
# 248 seen film
# 122 seen mani
# 350 seen movi
# 100 seen one
# 97 seen year
# 380 segment
# 195 select
# 407 self
# 129 selfish
# 383 sell
# 115 seller
# 415 send
# 2327 sens
# 121 sens humor
# 109 senseless
# 137 sensibl
# 228 sensit
# 393 sent
# 177 sentenc
# 318 sentiment
# 282 separ
# 994 sequel
# 1571 sequenc
# 3221 seri
# 435 serial
# 254 serial killer
# 1915 serious
# 589 serv
# 130 servant
# 266 servic
# 3864 set
# 197 settl
# 312 seven
# 109 seventi
# 1644 sever
# 183 sever time
# 91 sever year
# 1590 sex
# 265 sex scene
# 423 sexi
# 957 sexual
# 109 shade
# 291 shadow
# 183 shake
# 285 shakespear
# 132 shall
# 268 shallow
# 709 shame
# 229 shape
# 570 share
# 154 shark
# 204 sharp
# 99 shaw
# 98 shed
# 247 sheer
# 98 shelf
# 93 shelley
# 239 sheriff
# 134 shi
# 135 shift
# 364 shine
# 420 ship
# 99 shirley
# 111 shirt
# 963 shock
# 151 shoe
# 1030 shoot
# 342 shop
# 2034 short
# 171 short film
# 96 short stori
# 2872 shot
# 141 shoulder
# 153 shout
# 9590 show
# 240 show 's
# 110 show like
# 108 show n't
# 244 show us
# 161 showcas
# 172 shower
# 987 shown
# 182 shut
# 95 sibl
# 524 sick
# 1339 side
# 121 sidekick
# 169 sidney
# 365 sight
# 490 sign
# 298 signific
# 145 silenc
# 464 silent
# 96 silent film
# 931 silli
# 151 silver
# 1074 similar
# 290 simon
# 991 simpl
# 1953 simpli
# 116 simpli becaus
# 101 simplist
# 133 simpson
# 197 sin
# 230 sinatra
# 2841 sinc
# 136 sinc 's
# 191 sincer
# 903 sing
# 312 singer
# 910 singl
# 162 sinist
# 183 sink
# 175 sir
# 959 sister
# 1234 sit
# 200 sitcom
# 275 site
# 1146 situat
# 341 six
# 103 sixti
# 148 size
# 126 sketch
# 535 skill
# 225 skin
# 374 skip
# 130 skit
# 307 sky
# 202 slap
# 170 slapstick
# 503 slasher
# 95 slasher flick
# 134 slaughter
# 146 slave
# 163 sleazi
# 520 sleep
# 111 slice
# 101 slick
# 93 slide
# 671 slight
# 120 slightest
# 142 slip
# 123 sloppi
# 1060 slow
# 94 slow motion
# 104 slow pace
# 406 slowli
# 1573 small
# 92 small role
# 195 small town
# 101 smaller
# 400 smart
# 123 smash
# 447 smile
# 462 smith
# 245 smoke
# 156 smooth
# 161 snake
# 138 sneak
# 96 snl
# 144 snow
# 162 so-cal
# 272 soap
# 159 soap opera
# 97 soccer
# 599 social
# 664 societi
# 220 soft
# 157 sold
# 736 soldier
# 250 sole
# 523 solid
# 102 solo
# 97 solut
# 227 solv
# 293 somebodi
# 745 somehow
# 2327 someon
# 117 someon 's
# 168 someon els
# 4958 someth
# 178 someth els
# 297 someth like
# 92 someth n't
# 1257 sometim
# 955 somewhat
# 466 somewher
# 1412 son
# 1842 song
# 1152 soon
# 164 sophist
# 111 soprano
# 105 sore
# 738 sorri
# 1665 sort
# 516 soul
# 2153 sound
# 116 sound effect
# 381 sound like
# 753 soundtrack
# 257 sourc
# 450 south
# 169 southern
# 113 soviet
# 698 space
# 91 span
# 262 spanish
# 149 spare
# 142 spark
# 1061 speak
# 2167 special
# 1077 special effect
# 256 specif
# 274 spectacular
# 256 speech
# 278 speed
# 239 spell
# 825 spend
# 148 spend time
# 528 spent
# 262 spi
# 146 spielberg
# 146 spike
# 163 spin
# 674 spirit
# 156 spiritu
# 106 spit
# 189 spite
# 111 splatter
# 141 splendid
# 164 split
# 386 spoil
# 647 spoiler
# 152 spoken
# 228 spoof
# 124 spooki
# 368 sport
# 522 spot
# 135 spread
# 149 spring
# 123 squar
# 178 stab
# 97 stack
# 106 staff
# 881 stage
# 170 stalk
# 138 stan
# 1323 stand
# 762 standard
# 161 stanley
# 159 stanwyck
# 4019 star
# 175 star trek
# 178 star war
# 204 stare
# 4092 start
# 142 start finish
# 133 start watch
# 95 startl
# 1006 state
# 233 statement
# 358 station
# 167 status
# 1234 stay
# 152 stay away
# 588 steal
# 97 steam
# 155 steel
# 100 stellar
# 534 step
# 334 stephen
# 129 stephen king
# 592 stereotyp
# 467 steve
# 320 steven
# 446 stewart
# 613 stick
# 129 stiff
# 5546 still
# 102 still good
# 123 still n't
# 113 still veri
# 117 stiller
# 93 stilt
# 146 stink
# 111 stinker
# 96 stir
# 274 stock
# 115 stole
# 185 stolen
# 166 stomach
# 422 stone
# 133 stood
# 116 stoog
# 1406 stop
# 558 store
# 12579 stori
# 204 stori 's
# 110 stori charact
# 126 stori film
# 484 stori line
# 100 stori movi
# 150 stori n't
# 120 stori one
# 122 stori told
# 140 stori veri
# 176 storm
# 97 story\
# 790 storylin
# 196 storytel
# 753 straight
# 101 strain
# 95 strand
# 1085 strang
# 229 stranger
# 102 streep
# 838 street
# 148 streisand
# 302 strength
# 142 stress
# 287 stretch
# 181 strict
# 430 strike
# 179 string
# 190 strip
# 1280 strong
# 133 stronger
# 121 struck
# 269 structur
# 694 struggl
# 338 stuck
# 726 student
# 434 studi
# 668 studio
# 1123 stuff
# 224 stumbl
# 552 stun
# 272 stunt
# 1819 stupid
# 1550 style
# 167 stylish
# 104 sub
# 909 subject
# 181 subject matter
# 207 subplot
# 165 subsequ
# 215 substanc
# 235 subtitl
# 423 subtl
# 132 subtleti
# 430 succeed
# 1299 success
# 701 suck
# 771 sudden
# 763 suffer
# 768 suggest
# 329 suicid
# 528 suit
# 162 suitabl
# 151 sullivan
# 283 sum
# 175 summari
# 356 summer
# 157 sun
# 181 sunday
# 92 sunshin
# 325 super
# 645 superb
# 122 superbl
# 136 superfici
# 130 superhero
# 354 superior
# 280 superman
# 199 supernatur
# 121 suppli
# 1486 support
# 112 support actor
# 348 support cast
# 94 support charact
# 146 support role
# 2259 suppos
# 3018 sure
# 127 sure 's
# 139 surf
# 201 surfac
# 91 surpass
# 2412 surpris
# 231 surreal
# 388 surround
# 588 surviv
# 163 survivor
# 174 susan
# 507 suspect
# 127 suspend
# 936 suspens
# 108 suspici
# 158 sutherland
# 177 swear
# 110 swedish
# 590 sweet
# 175 swim
# 140 swing
# 227 switch
# 196 sword
# 318 symbol
# 97 sympath
# 231 sympathet
# 210 sympathi
# 97 synopsi
# 392 system
# 106 t.v
# 141 ta
# 206 tabl
# 94 tackl
# 97 tad
# 115 tag
# 6517 take
# 126 take away
# 102 take care
# 609 take place
# 133 take serious
# 136 take time
# 978 taken
# 94 taken serious
# 899 tale
# 1705 talent
# 2062 talk
# 109 tall
# 125 tame
# 114 tank
# 140 tap
# 341 tape
# 303 target
# 279 tarzan
# 207 task
# 559 tast
# 94 taught
# 300 taylor
# 122 tea
# 314 teach
# 377 teacher
# 887 team
# 451 tear
# 469 technic
# 270 techniqu
# 271 technolog
# 191 ted
# 222 tedious
# 462 teen
# 749 teenag
# 176 teeth
# 883 televis
# 3131 tell
# 366 tell stori
# 167 tell us
# 120 templ
# 100 tempt
# 791 ten
# 151 ten minut
# 137 ten year
# 352 tend
# 135 tender
# 153 tens
# 545 tension
# 595 term
# 105 termin
# 111 terri
# 1863 terribl
# 93 terribl movi
# 439 terrif
# 223 terrifi
# 139 territori
# 278 terror
# 177 terrorist
# 325 test
# 204 texa
# 159 text
# 1077 thank
# 91 thank god
# 1019 theater
# 342 theatr
# 254 theatric
# 1221 theme
# 101 theme song
# 1144 themselv
# 239 theori
# 337 therefor
# 106 thick
# 142 thief
# 347 thin
# 7991 thing
# 131 thing 's
# 168 thing film
# 98 thing get
# 153 thing go
# 169 thing happen
# 211 thing like
# 98 thing make
# 291 thing movi
# 184 thing n't
# 99 thing realli
# 123 thing say
# 8813 think
# 507 think 's
# 114 think could
# 150 think film
# 286 think movi
# 106 think one
# 194 think would
# 718 third
# 169 thirti
# 234 thoma
# 364 thorough
# 4446 though
# 181 though 's
# 111 though n't
# 3622 thought
# 140 thought movi
# 210 thought would
# 283 thousand
# 116 thread
# 142 threat
# 270 threaten
# 2172 three
# 99 three time
# 112 threw
# 437 thrill
# 876 thriller
# 146 throat
# 1308 throughout
# 235 throughout film
# 207 throughout movi
# 714 throw
# 404 thrown
# 93 thru
# 142 thug
# 165 thumb
# 403 thus
# 169 ticket
# 346 tie
# 99 tiger
# 204 tight
# 208 till
# 299 tim
# 15125 time
# 309 time 's
# 95 time around
# 132 time befor
# 108 time even
# 175 time film
# 112 time get
# 94 time make
# 154 time money
# 220 time movi
# 147 time n't
# 157 time one
# 92 time period
# 120 time saw
# 184 time see
# 170 time time
# 346 time watch
# 125 timeless
# 107 timon
# 117 timothi
# 209 tini
# 97 tip
# 452 tire
# 93 tiresom
# 160 titan
# 1656 titl
# 1230 today
# 283 today 's
# 107 todd
# 2137 togeth
# 136 toilet
# 1033 told
# 181 toler
# 740 tom
# 94 tom hank
# 101 tomato
# 105 tommi
# 196 ton
# 573 tone
# 108 tongu
# 563 toni
# 1097 took
# 93 took place
# 100 tool
# 1577 top
# 99 top notch
# 227 topic
# 101 topless
# 118 torment
# 140 torn
# 473 tortur
# 128 toss
# 1928 total
# 1244 touch
# 459 tough
# 162 tour
# 915 toward
# 243 toward end
# 136 tower
# 1239 town
# 257 toy
# 104 trace
# 158 traci
# 569 track
# 174 trade
# 102 trademark
# 478 tradit
# 369 tragedi
# 366 tragic
# 99 trail
# 464 trailer
# 724 train
# 164 transfer
# 316 transform
# 139 transit
# 269 translat
# 116 transport
# 367 trap
# 503 trash
# 98 trashi
# 545 travel
# 223 treasur
# 703 treat
# 237 treatment
# 254 tree
# 236 trek
# 183 tremend
# 6293 tri
# 163 tri find
# 288 tri get
# 182 tri hard
# 95 tri kill
# 364 tri make
# 210 trial
# 104 tribe
# 139 tribut
# 332 trick
# 205 trilog
# 114 trio
# 513 trip
# 149 trite
# 144 triumph
# 105 troop
# 745 troubl
# 182 truck
# 2213 true
# 215 true stori
# 1726 truli
# 366 trust
# 744 truth
# 319 tune
# 176 turkey
# 3757 turn
# 120 turner
# 2510 tv
# 247 tv movi
# 237 tv seri
# 282 tv show
# 106 twelv
# 253 twenti
# 369 twice
# 200 twin
# 1187 twist
# 118 twist end
# 121 twist turn
# 6579 two
# 92 two charact
# 146 two film
# 271 two hour
# 134 two lead
# 120 two main
# 98 two men
# 97 two movi
# 139 two peopl
# 125 two year
# 1262 type
# 104 type film
# 136 type movi
# 892 typic
# 145 u
# 210 u.s.
# 340 ugli
# 216 uk
# 739 ultim
# 247 unabl
# 137 unbear
# 540 unbeliev
# 335 uncl
# 167 uncomfort
# 191 unconvinc
# 169 underground
# 229 underr
# 92 underst
# 2104 understand
# 268 understand whi
# 172 understood
# 114 undoubt
# 115 uneven
# 323 unexpect
# 111 unfair
# 240 unfold
# 146 unforgett
# 1449 unfortun
# 261 unfunni
# 99 unhappi
# 176 uniform
# 158 uninspir
# 236 unintent
# 206 uninterest
# 136 union
# 666 uniqu
# 329 unit
# 136 unit state
# 568 univers
# 299 unknown
# 642 unless
# 884 unlik
# 293 unnecessari
# 120 unpleas
# 92 unreal
# 235 unrealist
# 91 unrel
# 107 unsettl
# 353 unusu
# 113 unwatch
# 118 updat
# 826 upon
# 110 upper
# 199 upset
# 195 urban
# 139 urg
# 3698 us
# 148 usa
# 5046 use
# 130 useless
# 149 user
# 1921 usual
# 97 util
# 756 utter
# 102 uwe
# 151 vacat
# 209 vagu
# 963 valu
# 94 valuabl
# 638 vampir
# 494 van
# 94 vanish
# 131 vari
# 191 varieti
# 605 various
# 165 vast
# 140 vega
# 284 vehicl
# 110 ventur
# 115 verhoeven
# 13975 veri
# 252 veri bad
# 149 veri differ
# 137 veri disappoint
# 135 veri end
# 134 veri entertain
# 98 veri first
# 325 veri funni
# 1160 veri good
# 139 veri hard
# 238 veri interest
# 357 veri littl
# 116 veri long
# 453 veri much
# 134 veri nice
# 153 veri poor
# 95 veri similar
# 310 veri veri
# 738 veri well
# 94 veri well done
# 100 veri young
# 2350 version
# 99 versus
# 240 veteran
# 270 vhs
# 166 via
# 128 vicious
# 776 victim
# 230 victor
# 218 victoria
# 1679 video
# 138 video game
# 182 video store
# 174 vietnam
# 2068 view
# 97 view film
# 2001 viewer
# 291 villag
# 888 villain
# 167 vincent
# 1027 violenc
# 540 violent
# 212 virgin
# 92 virginia
# 263 virtual
# 137 virus
# 105 visibl
# 348 vision
# 490 visit
# 1028 visual
# 168 vivid
# 92 vocal
# 1311 voic
# 115 voice-ov
# 111 voight
# 91 volum
# 179 von
# 368 vote
# 103 voyag
# 175 vs.
# 107 vulgar
# 127 vulner
# 91 wacki
# 1369 wait
# 98 wait see
# 255 wake
# 1320 walk
# 110 walk around
# 106 walk away
# 139 walken
# 114 walker
# 431 wall
# 111 wallac
# 239 walter
# 150 wan
# 132 wan na
# 243 wander
# 116 wannab
# 6592 want
# 141 want get
# 151 want go
# 160 want know
# 164 want make
# 723 want see
# 233 want watch
# 2108 war
# 103 war ii
# 133 ward
# 311 warm
# 671 warn
# 197 warner
# 113 warren
# 181 warrior
# 123 wash
# 263 washington
# 2191 wast
# 169 wast money
# 878 wast time
# 101 wast time money
# 13575 watch
# 125 watch 's
# 124 watch becaus
# 743 watch film
# 147 watch first
# 1468 watch movi
# 105 watch n't
# 189 watch one
# 172 watch show
# 286 watchabl
# 638 water
# 271 wave
# 8479 way
# 135 way 's
# 144 way film
# 122 way make
# 121 way movi
# 239 wayn
# 891 weak
# 99 weakest
# 107 wealth
# 151 wealthi
# 303 weapon
# 652 wear
# 113 web
# 124 websit
# 320 wed
# 657 week
# 200 weekend
# 139 weight
# 704 weird
# 247 welcom
# 9659 well
# 225 well 's
# 129 well act
# 411 well done
# 109 well film
# 147 well known
# 173 well made
# 105 well n't
# 93 well one
# 233 well worth
# 140 well written
# 93 wendi
# 1459 went
# 116 went see
# 258 werewolf
# 119 wes
# 438 west
# 736 western
# 94 wet
# 130 whale
# 679 whatev
# 294 whatsoev
# 92 wheel
# 266 whenev
# 147 wherea
# 839 whether
# 5170 whi
# 93 whi 's
# 177 whi doe
# 101 whi film
# 130 whi movi
# 281 whi n't
# 117 whi peopl
# 190 whi would
# 272 whilst
# 92 whine
# 1407 white
# 189 whoever
# 3048 whole
# 227 whole film
# 136 whole lot
# 383 whole movi
# 344 whole thing
# 94 whoopi
# 986 whose
# 150 wick
# 312 wide
# 150 widmark
# 190 widow
# 2031 wife
# 101 wife 's
# 533 wild
# 140 wilder
# 216 willi
# 909 william
# 195 wilson
# 923 win
# 353 wind
# 306 window
# 193 wing
# 252 winner
# 233 winter
# 122 wipe
# 93 wire
# 304 wise
# 1276 wish
# 154 wish could
# 676 wit
# 384 witch
# 802 within
# 3233 without
# 273 without ani
# 150 without doubt
# 270 witti
# 108 wizard
# 1198 wo
# 1191 wo n't
# 115 wolf
# 2739 woman
# 172 woman 's
# 1759 women
# 3586 wonder
# 95 wonder film
# 93 wonder movi
# 250 wonder whi
# 101 wont
# 91 woo
# 649 wood
# 329 wooden
# 233 woodi
# 126 woodi allen
# 1732 word
# 96 wore
# 6742 work
# 102 work film
# 196 work well
# 216 worker
# 3695 world
# 166 world 's
# 277 world war
# 97 world war ii
# 324 worri
# 1395 wors
# 2678 worst
# 320 worst film
# 171 worst film ever
# 588 worst movi
# 373 worst movi ever
# 2239 worth
# 98 worth look
# 238 worth see
# 109 worth time
# 455 worth watch
# 307 worthi
# 124 worthless
# 179 worthwhil
# 13372 would
# 201 would better
# 160 would expect
# 129 would get
# 113 would give
# 144 would go
# 110 would good
# 488 would like
# 177 would love
# 145 would made
# 246 would make
# 98 would much
# 1053 would n't
# 224 would never
# 144 would probabl
# 101 would rather
# 235 would recommend
# 242 would say
# 98 would take
# 155 would think
# 128 would want
# 230 wound
# 406 wow
# 209 wrap
# 156 wreck
# 113 wrestl
# 2023 write
# 1440 writer
# 121 writer director
# 132 writer/director
# 1448 written
# 94 written direct
# 1801 wrong
# 527 wrote
# 139 wwii
# 131 x
# 92 ya
# 96 yard
# 440 yeah
# 6294 year
# 141 year 's
# 641 year ago
# 153 year befor
# 114 year earlier
# 467 year later
# 868 year old
# 188 yell
# 95 yellow
# 1407 yes
# 104 yes 's
# 108 yesterday
# 2665 yet
# 237 yet anoth
# 786 york
# 158 york citi
# 3614 young
# 129 young boy
# 195 young girl
# 231 young man
# 231 young woman
# 496 younger
# 344 youth
# 346 zero
# 1212 zombi
# 124 zone

# %%
print "Training the random forest..."
from sklearn.ensemble import RandomForestClassifier

# Initialize a Random Forest classifier with 100 trees
forest = RandomForestClassifier(n_estimators = 100) 

# Fit the forest to the training set, using the bag of words as 
# features and the sentiment labels as the response variable
#
# This may take a few minutes to run
forest = forest.fit( train_data_features, train["sentiment"] )
# Out:
# Training the random forest...

# %%
# Read the test data
test = pd.read_csv("Kaggle/Bag of Words/testData.tsv", header=0, delimiter="\t", \
                   quoting=3 )

# Verify that there are 25,000 rows and 2 columns
print test.shape

# Get a bag of words for the test set, and convert to a numpy array
test_data_features = vectorizer.transform(test["review"])
test_data_features = test_data_features.toarray()

# Use the random forest to make sentiment label predictions
result = forest.predict(test_data_features)

# Copy the results to a pandas dataframe with an "id" column and
# a "sentiment" column
output = pd.DataFrame( data={"id":test["id"], "sentiment":result} )

# Use pandas to write the comma-separated output file
output.to_csv( "Kaggle/Bag of Words/Bag_of_Words_model_submission3.csv", index=False, quoting=3 )
# Out:
# (25000, 2)
