# %%
import gensim
import multiprocessing
from gensim.corpora.csvcorpus import CsvCorpus
from gensim import utils
from gensim.models.word2vec import LineSentence, Word2Vec
from gensim.corpora import Dictionary, MmCorpus
from gensim.models import LsiModel
from gensim.similarities import MatrixSimilarity

# %%
texts = gensim.models.word2vec.LineSentence('Corpus/dump_mp.csv')

# %%
# %time word2vec_model = Word2Vec(texts, size=400, window=5, min_count=5, workers=multiprocessing.cpu_count())
# Out:
# CPU times: user 24min 8s, sys: 6.43 s, total: 24min 14s
# Wall time: 8min 27s

# %%
word2vec_model.init_sims(replace=True)
word2vec_model.save('Corpus/mp.word2vec.model')

# %%
dictionary = Dictionary(texts)

# %%
dictionary.save('Corpus/mp.dict')
dictionary = Dictionary.load('Corpus/mp.dict')

# %%
corpus = [dictionary.doc2bow(text) for text in texts]
MmCorpus.serialize('Corpus/mp.mm', corpus)
# %time corpus = MmCorpus('Corpus/mp.mm')
# Out:
# CPU times: user 1.2 s, sys: 116 ms, total: 1.31 s
# Wall time: 1.31 s

# %%
# %time lsi = LsiModel(corpus, id2word=dictionary, num_topics=5)
# Out:
# CPU times: user 2min 46s, sys: 11.4 s, total: 2min 57s
# Wall time: 2min 9s

# %%
lsi.save('Corpus/mp.lsi.model')

# %%
doc = "ativo financeiro"
vec_bow = dictionary.doc2bow(doc.lower().split())
vec_lsi = lsi[vec_bow] # convert the query to LSI space

# %%
# %time index = MatrixSimilarity(lsi[corpus]) # transform corpus to LSI space and index it
# Out:
# WARNING:gensim.similarities.docsim:scanning corpus to determine the number of features (consider setting `num_features` explicitly)
# CPU times: user 2min 55s, sys: 938 ms, total: 2min 56s
# Wall time: 2min 56s

# %%
index.save('Corpus/mp.index')
index = MatrixSimilarity.load('Corpus/mp.index')

# %%
sims = index[vec_lsi] # perform a similarity query against the corpus
#print(list(enumerate(sims))) # print (document_number, document_similarity) 2-tuples

# %%
sims = sorted(enumerate(sims), key=lambda item: -item[1])
print(sims) # print sorted (document number, similarity score) 2-tuples
# Out:
# [(18855, 0.99951351), (17670, 0.99915648), (34119, 0.99877572), (32597, 0.99873018), (11325, 0.99869323), (11198, 0.99867618), (34116, 0.99855161), (23986, 0.99852705), (32594, 0.99844927), (35039, 0.99835002), (32637, 0.998299), (24500, 0.99825704), (36882, 0.9982214), (34612, 0.99820912), (13119, 0.99820638), (23991, 0.99820578), (13238, 0.99819767), (34649, 0.99814475), (38260, 0.99808776), (32640, 0.99807382), (24501, 0.99804366), (37686, 0.99802703), (24974, 0.99796546), (37684, 0.99786294), (11332, 0.99776691), (36883, 0.99773747), (20490, 0.99773169), (33709, 0.99768662), (5427, 0.99766016), (11327, 0.99763429), (20492, 0.9975338), (24499, 0.9975031), (1001, 0.99742746), (23989, 0.99742377), (36488, 0.99726772), (34654, 0.99724233), (11333, 0.99720281), (25247, 0.99716699), (34618, 0.99716181), (16456, 0.99706686), (20472, 0.99702251), (19218, 0.99700713), (25250, 0.99700439), (34623, 0.99692059), (13241, 0.99680924), (32642, 0.99680531), (37663, 0.99666393), (35034, 0.99666131), (23988, 0.99646425), (7318, 0.99640596), (377, 0.99637747), (16455, 0.99631023), (24278, 0.99628007), (20475, 0.99621731), (18066, 0.99619937), (1848, 0.99617255), (18137, 0.99614751), (11208, 0.9960773), (37690, 0.99603248), (36136, 0.99595737), (36892, 0.99595249), (18943, 0.99588209), (4774, 0.99567437), (35630, 0.99561799), (6651, 0.99552751), (2618, 0.99549288), (32591, 0.99548101), (5426, 0.99541068), (10671, 0.99530947), (18685, 0.99528849), (9600, 0.9952687), (32603, 0.99523091), (5312, 0.99517262), (11206, 0.99514794), (5156, 0.99513566), (34652, 0.99508166), (6423, 0.9950732), (6708, 0.99506605), (18245, 0.99506134), (9235, 0.99501842), (1027, 0.99501109), (3141, 0.99498522), (34615, 0.99492502), (23993, 0.99481082), (13125, 0.99481034), (269, 0.99480915), (19232, 0.99474764), (6898, 0.99467891), (15191, 0.99464566), (8474, 0.9946264), (8337, 0.99457741), (8414, 0.99457216), (1597, 0.9945181), (5650, 0.99443817), (1119, 0.99442446), (10315, 0.99440873), (34656, 0.99432242), (3258, 0.99431849), (2477, 0.99429482), (18528, 0.99416649), (8687, 0.99412894), (7971, 0.99412137), (9815, 0.99406028), (4874, 0.99402928), (9747, 0.99402523), (19264, 0.9939779), (6509, 0.99393535), (14738, 0.99389857), (34607, 0.99386138), (4994, 0.99384445), (20470, 0.99382782), (15674, 0.99378717), (9214, 0.99375308), (24759, 0.99375254), (18325, 0.99375015), (1250, 0.99373049), (9789, 0.99368089), (19055, 0.99366403), (5948, 0.99366337), (2267, 0.99366248), (10041, 0.99364698), (17276, 0.99363792), (36489, 0.99361748), (7178, 0.99361694), (38262, 0.993613), (9805, 0.99360991), (4730, 0.99360287), (19673, 0.99359453), (37692, 0.99359131), (17344, 0.99359077), (4772, 0.99358857), (14519, 0.99355829), (4191, 0.99355459), (18583, 0.99352694), (5578, 0.99351007), (8468, 0.993487), (4909, 0.99346161), (5602, 0.99337673), (7605, 0.99336827), (36485, 0.99334514), (18269, 0.99333608), (18459, 0.99332428), (7280, 0.99331439), (1162, 0.99329901), (8703, 0.99329221), (4142, 0.99328315), (5480, 0.99327636), (20880, 0.99325013), (14637, 0.99321651), (3336, 0.99316156), (6499, 0.99313259), (5093, 0.99311638), (11331, 0.99306643), (14409, 0.99302566), (2334, 0.99299514), (13128, 0.99299395), (13127, 0.992966), (9347, 0.99295366), (10370, 0.99290001), (32604, 0.9928714), (2152, 0.99276835), (9592, 0.99276769), (3189, 0.99275315), (1351, 0.99275059), (725, 0.99270159), (18586, 0.99269772), (6604, 0.9926765), (19141, 0.99267435), (1391, 0.9926157), (8157, 0.99260056), (6945, 0.99258912), (6259, 0.99256605), (2597, 0.99256063), (5577, 0.99255979), (8204, 0.99254143), (34128, 0.99253947), (8258, 0.99253303), (5412, 0.99250841), (18891, 0.99249506), (4637, 0.99246961), (3304, 0.99244958), (993, 0.99244416), (13234, 0.9924382), (14512, 0.99243236), (19170, 0.99240756), (6773, 0.99234307), (5067, 0.99233758), (3262, 0.99233687), (8654, 0.99233234), (37662, 0.99232376), (10539, 0.99232209), (16538, 0.99231493), (8630, 0.99230361), (599, 0.99229628), (10096, 0.99229485), (16930, 0.992 ...

# %%
lsi.num_topics
# Out:
# 5

# %%
lsi.print_topics(5)
# Out:
# [(0,
#   u'0.445*"rg" + 0.362*"sao" + 0.278*"paulo" + 0.251*"partir" + 0.249*"dias" + 0.196*"ee" + 0.173*"art" + 0.140*"sp" + 0.138*"lei" + 0.133*"efp"'),
#  (1,
#   u'-0.556*"rg" + 0.469*"sao" + 0.352*"paulo" + -0.275*"ee" + 0.149*"efp" + 0.148*"art" + 0.112*"ltda" + 0.112*"dias" + -0.110*"peb" + -0.102*"sqc"'),
#  (2,
#   u'0.395*"ltda" + -0.293*"partir" + -0.272*"efp" + -0.261*"dias" + 0.252*"sp" + -0.239*"art" + 0.207*"valor" + 0.164*"item" + 0.137*"municipal" + 0.129*"processo"'),
#  (3,
#   u'-0.505*"sao" + -0.363*"paulo" + 0.341*"dias" + 0.318*"partir" + 0.299*"art" + 0.279*"efp" + 0.179*"ltda" + 0.146*"lei" + -0.138*"rg" + -0.130*"ee"'),
#  (4,
#   u'-0.627*"merc" + -0.573*"panamericanoarr" + -0.519*"sa" + -0.061*"panamericano" + -0.033*"arr" + -0.031*"banco" + -0.020*"aarr" + -0.019*"leas" + -0.019*"dibens" + 0.012*"ltda"')]
