# %%
import pandas as pd
import sklearn 
import numpy as np
import nltk
import json
import re
import time
import codecs
import ijson
from sklearn.metrics import pairwise_distances

# %%
#nome_arquivo = 'arquivo_subset.json'
#nome_arquivo = 'arquivo.json'
nome_arquivo = 'acervo_mp_subset.json'

# %%
data = []
with open(nome_arquivo, 'r') as f:
    objects = ijson.items(f, 'item')
    for row in objects:
        data.append(row)

# %%
arquivos = pd.DataFrame(data)

# %%
arquivos
# Out:
#                                         api_Arquivo_bn  \
# 0    ﻿\r\nGOVERNO DE SERGIPE\r\nPROJETO DE LEI\r\nD...
# 1    ﻿\r\nGOVERNO DE SERGIPE\r\nPROJETO DE LEI COMP...
# 2    72 – São Paulo, 121 (72) Diário Oﬁcial Empresa...
# 3    terça-feira, 19 de abril de 2011 Diário Oﬁcial...
# 4    terça-feira, 19 de abril de 2011 Diário Oﬁcial...
# 5    ﻿5\r\n      \r\nGOVERNO DE SERGIPE\r\nPROJETO ...
# 6    Diário Oficial\nEstado de São Paulo\nVolume 12...
# 7    ﻿5\r\n      \r\nGOVERNO DE SERGIPE\r\nPROJETO ...
# 8
# 9    ﻿3\r\n      \r\nGOVERNO DE SERGIPE\r\nPROJETO ...
# 10   ﻿4\r\n      \r\nGOVERNO DE SERGIPE\r\nPROJETO ...
# 11   ﻿2\r\n      \r\nGOVERNO DE SERGIPE\r\nPROJETO ...
# 12   ﻿20\r\n      \r\nGOVERNO DE SERGIPE\r\nPROJETO...
# 13   ﻿5\r\n      \r\nGOVERNO DE SERGIPE\r\nPROJETO ...
# 14   ﻿4\r\n\r\nAltera o § 4º e acrescenta § 6º, do ...
# 15   ﻿3\r\n    \r\n\r\n\r\n\r\nAltera o art. 738, o...
# 16   ﻿2\r\n      \r\nGOVERNO DE SERGIPE\r\nPROJETO ...
# 17                                                   ﻿
# 18   ﻿2\r\n\r\nAltera o § 3º do art. 684, e as Tabe...
# 19   ﻿2\r\n      \r\nGOVERNO DE SERGIPE\r\nPROJETO ...
# 20   ﻿2\r\n\r\nESTADO DE SERGIPE\r\nASSEMBLÉIA LEGI...
# 21   ﻿\r\nAltera o inciso I e acrescenta o inciso V...
# 22   ﻿1\r\n\r\n\r\nAltera o inciso IV do “caput” e ...
# 23   ﻿6\r\n      \r\nGOVERNO DE SERGIPE\r\nPROJETO ...
# 24   ﻿10\r\n\r\nESTADO DE SERGIPE\r\nASSEMBLÉIA LEG...
# 25   ﻿4\r\n      \r\nGOVERNO DE SERGIPE\r\nPROJETO ...
# 26   ﻿\r\n\r\n\r\n\r\n\r\n\r\nGOVERNO DE SERGIPE\r\...
# 27   ﻿2\r\n      \r\nGOVERNO DE SERGIPE\r\nPROJETO ...
# 28   ﻿8\r\n      \r\nGOVERNO DE SERGIPE\r\nPROJETO ...
# 29   ﻿16\r\n\r\nGOVERNO DE SERGIPE\r\nPROJETO DE LE...
# ..                                                 ...
# 970  quinta-feira, 28 de abril de 2011 Diário Oﬁcia...
# 971  ﻿2\r\n\r\nGOVERNO DE SERGIPE\r\nDECRETO Nº\r\n...
# 972  quinta-feira, 28 de abril de 2011 Diário Oﬁcia...
# 973  sábado, 8 de janeiro de 2011 Diário Oﬁcial Emp...
# 974  6 – São Paulo, 121 (5) Diário Oﬁcial Empresari...
# 975  sábado, 8 de janeiro de 2011 Diário Oﬁcial Emp...
# 976  12 – São Paulo, 121 (5) Diário Oﬁcial Empresar...
# 977  sábado, 8 de janeiro de 2011 Diário Oﬁcial Emp...
# 978  ﻿2\r\n\r\nGOVERNO DE SERGIPE\r\nDECRETO Nº\r\n...
# 979  24 – São Paulo, 121 (77) Diário Oﬁcial Empresa...
# 980  6 – São Paulo, 121 (29) Diário Oﬁcial Empresar...
# 981  8 – São Paulo, 121 (29) Diário Oﬁcial Empresar...
# 982  ﻿2\r\n\r\nGOVERNO DE SERGIPE\r\nDECRETO Nº\r\n...
# 983  Diário Oficial\nEstado de São Paulo\nVolume 12...
# 984  ﻿2\r\n\r\nGOVERNO DE SERGIPE\r\nDECRETO Nº\r\n...
# 985  terça-feira, 15 de fevereiro de 2011 Diário Oﬁ...
# 986  quinta-feira, 28 de abril de 2011 Diário Oﬁcia...
# 987  ﻿2\r\n\r\nGOVERNO DE SERGIPE\r\nDECRETO Nº\r\n...
# 988  ﻿2\r\n\r\nGOVERNO DE SERGIPE\r\nDECRETO Nº\r\n...
# 989  36 – São Paulo, 121 (77) Diário Oﬁcial Empresa...
# 990  18 – São Paulo, 121 (29) Diário Oﬁcial Empresa...
# 991  38 – São Paulo, 121 (77) Diário Oﬁcial Empresa...
# 992  22 – São Paulo, 121 (29) Diário Oﬁcial Empresa...
# 993  42 – São Paulo, 121 (77) Diário Oﬁcial Empresa...
# 994  quinta-feira, 28 de abril de 2011 Diário Oﬁcia...
# 995  ﻿2\r\n\r\nGOVERNO DE SERGIPE\r\nDECRETO Nº\r\n...
# 996  26 – São Paulo, 121 (29) Diário Oﬁcial Empresa...
# 997  quinta-feira, 28 de abril de 2011 Diário Oﬁcia...
# 998  50 – São Paulo, 121 (77) Diário Oﬁcial Empresa...
# 999  32 – São Paulo, 121 (29) Diário Oﬁcial Empresa...
#
#                        api_Nome_do_arquivo_tg  \
# 0     DISPÕE072007 ANEXOS II-III-X-XI-XII.doc
# 1                            DISPÕE082007.doc
# 2    pag_0072_4GFCEJK188M3UeBLV4P6ERLU6HU.pdf
# 3    pag_0075_7R531MSMH29F9eAJI7HC9VDLCIH.pdf
# 4    pag_0077_4J3MJ1949J5P0e7MEJC6EEMQEE0.pdf
# 5                            DISPÕE182006.doc
# 6    pag_0080_DB805TODNNLLOeC30VGO3LO1SOU.pdf
# 7                            DISPÕE232006.doc
# 8                                   Thumbs.db
# 9                         DISPÕE152007 FE.doc
# 10                           DISPÕE252006.doc
# 11                           DISPÕE272006.doc
# 12                      DISPÕE162007B SES.doc
# 13                           DISPÕE282006.doc
# 14                           ALTERA032005.doc
# 15                           ALTERA042005.doc
# 16                           DISPÕE352006.doc
# 17                      ACRESCENTA012005A.doc
# 18                           ALTERA072005.doc
# 19                           DISPÕE362006.doc
# 20                        EMENDA M 052006.doc
# 21                           ALTERA142005.doc
# 22                           ALTERA162005.doc
# 23                       DISPÕE232007 PPA.doc
# 24                        EMENDA S 032006.doc
# 25                       DISPÕE222007 OES.doc
# 26                     DISPÕE292007 ANEXO.doc
# 27                   DISPÕE302007 DEGRASE.doc
# 28                     DISPÕE312007 ANEXO.doc
# 29   ESTRUTURA IPESAÚDE-2006-Substitutivo.doc
# ..                                        ...
# 970  pag_0003_FJA5JNEFS2PV7e08B66OJ49NI9H.pdf
# 971                   HOMOLOGA312007ADEMA.doc
# 972  pag_0009_5M8V5S0UJSRJGe2DRPOF6JO1E87.pdf
# 973  pag_0005_DKG87OAGELSJ4e84C9HMMDU7ACF.pdf
# 974  pag_0006_70CSD1HQAF34BeB4VEAT3CM7UBM.pdf
# 975  pag_0009_DL685PQ8FVKLSeFSR8RM5SUDP7S.pdf
# 976  pag_0012_2T9AKV5O7865Ce97C7OUG0GSEKN.pdf
# 977  pag_0013_42EB70OU7U2PKe0IEQSEK674U6U.pdf
# 978                 HOMOLOGA452007SEAD OK.doc
# 979  pag_0024_4LAC3AMFIOCL8eA3MJ52UGM0BUI.pdf
# 980  pag_0006_CE270UOMO7RGMe57NNE0II4QMTM.pdf
# 981  pag_0008_2T5I3UEP7MFENe0PB772VV8DTT0.pdf
# 982                  HOMOLOGA532007SES OK.doc
# 983  pag_0016_4FNDRS80NNB7VeECNIFSDABEO2P.pdf
# 984                 HOMOLOGA542007SEAD OK.doc
# 985  pag_0013_6QBPUPR6CLPEUe4B4GHTAK4UR6R.pdf
# 986  pag_0033_7BSHLBFFSTUE4e1NEQGDEK8750B.pdf
# 987                HOMOLOGA582007ADEMA OK.doc
# 988                   HOMOLOGA592007ADEMA.doc
# 989  pag_0036_FK2ROL612NS23eD7TEU1MK12CSF.pdf
# 990  pag_0018_6GGA36HAAB2QJe68BURLJQD9VOF.pdf
# 991  pag_0038_6UNNE3RRUGA6PeD5RP5UQDUKDTH.pdf
# 992  pag_0022_92VAOBNOI7EFPe8MIAS04LMIRV5.pdf
# 993  pag_0042_AD3GB3L2LJP3Fe76NI0H3CNO21C.pdf
# 994  pag_0043_DK0AF8D4I3490eAO21OGLT5T1IQ.pdf
# 995                  HOMOLOGA672007DETRAN.doc
# 996  pag_0026_5RVTG1EMBEUGKe3H6CA9J99A5RI.pdf
# 997  pag_0049_A2LKALDP5U2B1e99TLL1P9V7C3J.pdf
# 998  pag_0050_AHK0RKQNLPJ2Ne63ACC6SGQJ6Q6.pdf
# 999  pag_0032_4DE6ULGNTFP9He9KQQJQOEB1DSU.pdf
#
#                                        ctr_id
# 0    419b67b5ccfec49f6bee5bde1eceb38803e477b9
# 1    b43f78e83d18728845ccf31995f0965b92f746e8
# 2    f12e4d6b9b787e06517554a914e0a9873ecde426
# 3    eb09ad8a3c992b3fc4f7dadaa4bfa6878715bde2
# 4    c093d2dc574f782258249eeb586b1220c41ddad7
# 5    1c9835fc525f95986b7706033590a0e393e8c64d
# 6    e62616888a06fbf1a5154b5473f446d18ddaca79
# 7    68b522184aa445db4f6ce9ceffe0a19195e56de9
# 8    a338723d0544fd040f01a3eeb34951e902903c14
# 9    fc5ee49228a378ff6cd69c827766fc3dca4a12b1
# 10   8b4b219867633d1631ed9561ae6a3270b57e8fc7
# 11   3f402f401e3c92ca7843a8208158f87dd6a35a64
# 12   0e241fe815d8c4011d98bf149e10532a1f7e5703
# 13   61d2591a1b231b02d8e81cd08b6ff3aad358728b
# 14   f18856bc8e29cb5919e432582d508ce7e98ee58e
# 15   281458aa62710e5bd101858f68b9a0bc688e3a55
# 16   ad2beb1371f59aa04ba18c116dca93787815a46b
# 17   f811dae48abb200910f1cbfef5a1336f285171d7
# 18   fc5e023cb201d0308ddef005e7bef050569fc164
# 19   778dbe45d8ca40aceea0e00c86f1d20edd0cf9a4
# 20   9e8430dc6fe21288d96b4bee0d39ae9ba884ddb1
# 21   554e5938860fd8c1c6cf3c31a80c34e394cc200e
# 22   fa34d20ec061160b88e07d21bdd4926cd9c5daf2
# 23   674048bf6f26568bebf029098c615778ec742dc0
# 24   7a11e3a064ee76363137a5ed54db6389bfc22836
# 25   8758bf29a534ad28826523ce5b95e591d13120e1
# 26   cfd464895eed667fd30558407752921dc642a3d1
# 27   d46c08f91f01cfef1c6201002787a78c55242f33
# 28   abdc6d95e0fdbfe052cb3695f35f997e9839f987
# 29   b72298b31f9aaab1cf24b2b39deb71c4f8bd23f1
# ..                                        ...
# 970  a488ef4bc1dd2136c751bc73fc783b32a754543a
# 971  852cf61867ebc54a22b1544faa9693efb3104211
# 972  f46fcdca75bf917ee8fea1cedc9501f00723a152
# 973  8ae27eddd03a59cb15a764e71cf44cf853740f1d
# 974  ba94342ddde482a2e6dc7af31634ac0371d4cdd6
# 975  b2fff428ee7b7b61499e463b08c8865bcbe44d5d
# 976  9650436eec7b7bf03218833c89455b4379576c30
# 977  b2ae528812bac170194b6085a2e734f67cf0c572
# 978  3b17a4e63b28f48a31804f3436a15add7f9fc32f
# 979  5d10a5258b4b42a567c41e5765e9a386bc8a9919
# 980  8f5ce9172e0aa7015ed735f011245d4ea3c93e4b
# 981  195e2e8c2496bc3da8394266386ec402a7ddbd08
# 982  14a34f914bbcea70a1d789883db997e4e534b2f9
# 983  a13ead32f47ae9fc28d3cf1a59c98ca1bc6836f8
# 984  e5608000803fb7de5a3642d88f12a3660b5ad250
# 985  a2647f3d105606b3910c141bf3db50fbf2f0b1e1
# 986  6ae280610330a10c467f832b0347afd43a80bb04
# 987  f9701d59ac593c85b314eb27c471627ae22bb4c2
# 988  e659d44cfdbfcb145c139684fd0c888c884ca988
# 989  9225bf7fe5f9694c869fed7c983f2c8f1274790e
# 990  a28ca14575751344cd8224f2538a728a9e22f4bd
# 991  884d6386e219d17d1d7491e67f2e85ccde87c64f
# 992  583c737b635e264b81dc3b31539e0329b0bbe4a4
# 993  4c24779ed53f80c45526ae4be3f0f346cc1523be
# 994  540c47bf01b923264f3be5678e83ee314ae73033
# 995  c18c60c87155fcaa720dd9b7cdd1a7698d9382f0
# 996  87ff0ba25eaed0456a288342e81391361c2981f4
# 997  9a3326a53e6e01a082d34a04951e91ec0614a45e
# 998  c49400cddd6aa3e6469dc6ac118e9ce060146ed4
# 999  7be3d2571f728b66c4d6af8c84bdd304d231632d
#
# [1000 rows x 3 columns]

# %%
def clean_text(text):
    list_of_cleaning_signs = ['\x0c', '\n']
    for sign in list_of_cleaning_signs:
        text = text.replace(sign, ' ')
    return text.lower()

# %%
arquivos['arquivo_clean'] = arquivos['api_Arquivo_bn'].apply(lambda x: clean_text(x))

# %%
# defines a tokenizer and stemmer which returns the set of stems in the text that it is passed
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("portuguese")
def tokenize_and_stem(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    stems = [stemmer.stem(t) for t in filtered_tokens]
    return stems

# %%
# load nltk's portuguese stopwords as variable called 'stopwords'
stopwords = nltk.corpus.stopwords.words('portuguese')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# Producing tf_idf matrix separately based on text
tfidf_vectorizer_text = TfidfVectorizer(max_df=0.9, max_features=20000,
                                 min_df=0.1, stop_words=stopwords,
                                 use_idf=True, tokenizer=tokenize_and_stem, ngram_range=(1,3))
# %time tfidf_matrix_text = tfidf_vectorizer_text.fit_transform(arquivos['arquivo_clean'])
# Out:
# CPU times: user 1min 11s, sys: 555 ms, total: 1min 11s
# Wall time: 1min 11s

# %%
tfidf_matrix_text.shape
# Out:
# (1000, 1408)

# %%
terms_text = tfidf_vectorizer_text.get_feature_names()

# %%
terms_text
# Out:
# [u'a.',
#  u'abaix',
#  u'abert',
#  u'abertur',
#  u'abrang',
#  u'abrangent',
#  u'abril',
#  u'abril conform',
#  u'abril di\xe1ri',
#  u'abril di\xe1ri o\ufb01cial',
#  u'acess',
#  u'acim',
#  u'acion',
#  u'acompanh',
#  u'acord',
#  u'acord dispost',
#  u'acord dispost lei',
#  u'acord norm',
#  u'acord pr\xe1tic',
#  u'acord pr\xe1tic cont\xe1b',
#  u'acresc',
#  u'acumul',
#  u'acumul total',
#  u'adequ',
#  u'adiant',
#  u'adicion',
#  u'adicional',
#  u'administr',
#  u'administr companh',
#  u'administr demonstr',
#  u'adot',
#  u'adot brasil',
#  u'ado\xe7\xe3',
#  u'adquir',
#  u'afet',
#  u'agost',
#  u'ag\xeanc',
#  u'aind',
#  u'ajust',
#  u'ajust valor',
#  u'alien',
#  u'alter',
#  u'alves',
#  u'alves filh',
#  u'alves filh govern',
#  u'al\xe9m',
#  u'al\xedquot',
#  u'ambient',
#  u'amortiz',
#  u'andament',
#  u'andar',
#  u'anex',
#  u'ano',
#  u'anos',
#  u'antecip',
#  u'anterior',
#  u'antes',
#  u'antes impost',
#  u'antes impost rend',
#  u'antoni',
#  u'anu',
#  u'anual',
#  u'an\xe1lis',
#  u'apen',
#  u'aplic',
#  u'aplic financeir',
#  u'apoi',
#  u'aprec',
#  u'apresent',
#  u'apresent demonstr',
#  u'apresent demonstr financeir',
#  u'apropri',
#  u'aprov',
#  u'aprov pel',
#  u'aprov sancion',
#  u'aprov sancion seguint',
#  u'aproxim',
#  u'apur',
#  u'ap\xf3s',
#  u'aquel',
#  u'aquisi\xe7\xe3',
#  u'aquisi\xe7\xf5',
#  u'aracaju',
#  u'aracaju independent',
#  u'aracaju independent rep\xfabl',
#  u'art',
#  u'art decret',
#  u'art decret entra',
#  u'art dest',
#  u'art dest decret',
#  u'art fic',
#  u'art incis',
#  u'art incis v',
#  u'art lei',
#  u'art lei entra',
#  u'art lei n\xba',
#  u'art revogam-s',
#  u'art revogam-s disposi\xe7\xf5',
#  u'artig',
#  u'artig dev',
#  u'artig lei',
#  u'aspect',
#  u'assegur',
#  u'assembl',
#  u'assembl geral',
#  u'assembl geral extraordin\xe1r',
#  u'assembl geral ordin\xe1r',
#  u'assembl legisl',
#  u'assembl legisl estad',
#  u'assessor',
#  u'assim',
#  u'assin',
#  u'assinatur',
#  u'assistent',
#  u'assoc',
#  u'assum',
#  u'assunt',
#  u'ata',
#  u'atend',
#  u'ativ',
#  u'ativ circul',
#  u'ativ financ',
#  u'ativ financeir',
#  u'ativ imobiliz',
#  u'ativ invest',
#  u'ativ n\xe3',
#  u'ativ n\xe3 circul',
#  u'ativ operacion',
#  u'ativ passiv',
#  u'ato',
#  u'atos',
#  u'atrav\xe9s',
#  u'atribui\xe7\xf5',
#  u'atribui\xe7\xf5 s\xe3',
#  u'atribui\xe7\xf5 s\xe3 confer',
#  u'atribu\xedd',
#  u'atu',
#  u'atual',
#  u'atualiz',
#  u'atua\xe7\xe3',
#  u'auditor',
#  u'auditor independent',
#  u'august',
#  u'aument',
#  u'aument capital',
#  u'autor',
#  u'autoriz',
#  u'av',
#  u'avali',
#  u'aven',
#  u'avis',
#  u'a\xe7\xe3',
#  u'a\xe7\xf5',
#  u'a\xe7\xf5 ordin\xe1r',
#  u'a\xe7\xf5 ordin\xe1r nomin',
#  u'b',
#  u'baix',
#  u'balanc',
#  u'balanc patrimoni',
#  u'balanc patrimonial',
#  u'banc',
#  u'banc\xe1ri',
#  u'barbos',
#  u'bas',
#  u'bas c\xe1lcul',
#  u'bem',
#  u'benef\xedci',
#  u'bens',
#  u'brasil',
#  u'brasileir',
#  u'brut',
#  u'b\xe1sic',
#  u'c',
#  u'c r',
#  u'c r t',
#  u'cab',
#  u'cad',
#  u'caix',
#  u'caix ativ',
#  u'caix caix',
#  u'caix equivalent',
#  u'caix equivalent caix',
#  u'caix l\xedqu',
#  u'caix par',
#  u'caix par exerc\xedci',
#  u'calcul',
#  u'camp',
#  u'cancel',
#  u'capac',
#  u'capital',
#  u'capital pr\xf3pri',
#  u'capital reserv',
#  u'capital social',
#  u'capital social reserv',
#  u'capitaliz',
#  u'cap\xedtul',
#  u'caracter\xedst',
#  u'carg',
#  u'carl',
#  u'carvalh',
#  u'cas',
#  u'categor',
#  u'caus',
#  u'celebr',
#  u'cent',
#  u'centr',
#  u'central',
#  u'cep',
#  u'cert',
#  u'certific',
#  u'chag',
#  u'cia',
#  u'cidad',
#  u'cinc',
#  u'circul',
#  u'circul caix',
#  u'circul mercador',
#  u'circul n\xe3',
#  u'circul n\xe3 circul',
#  u'circul realiz',
#  u'circul realiz long',
#  u'circunst\xe2nc',
#  u'civ',
#  u'civ estad',
#  u'civ estad sergip',
#  u'civil',
#  u'class',
#  u'classific',
#  u'client',
#  u'cl\xf3v',
#  u'cnpj',
#  u'cnpj n\xba',
#  u'cnpj/mf',
#  u'cnpj/mf n\xba',
#  u'cobertur',
#  u'cobr',
#  u'cofins',
#  u'coloc',
#  u'com-',
#  u'combin',
#  u'combin disposi\xe7\xf5',
#  u'combin disposi\xe7\xf5 leis',
#  u'comerc',
#  u'comercial',
#  u'comercializ',
#  u'comiss\xe3',
#  u'comit',
#  u'comit pronunc',
#  u'comit pronunc cont\xe1b',
#  u'companh',
#  u'companh abert',
#  u'companh n\xe3',
#  u'companh par',
#  u'compar',
#  u'compens',
#  u'compet',
#  u'competent',
#  u'complement',
#  u'complet',
#  u'composi\xe7\xe3',
#  u'compost',
#  u'compr',
#  u'compreend',
#  u'compromiss',
#  u'comprov',
#  u'comunic',
#  u'com\xe9rci',
#  u'con-',
#  u'conced',
#  u'concess\xe3',
#  u'condi\xe7\xf5',
#  u'conduz',
#  u'confer',
#  u'confer term',
#  u'confer term art',
#  u'conform',
#  u'conform lei',
#  u'conhec',
#  u'conjunt',
#  u'conselh',
#  u'conselh administr',
#  u'conselheir',
#  u'consequent',
#  u'consid',
#  u'consider',
#  u'consign',
#  u'consolid',
#  u'const',
#  u'constant',
#  u'constitu',
#  u'constitui\xe7\xe3',
#  u'constitui\xe7\xe3 estadual',
#  u'constitui\xe7\xe3 estadual acord',
#  u'constitu\xedd',
#  u'constru\xe7\xe3',
#  u'consultor',
#  u'consum',
#  u'cont',
#  u'cont pag',
#  u'cont receb',
#  u'cont receb client',
#  u'contabil',
#  u'contabiliz',
#  u'contador',
#  u'contador crc',
#  u'context',
#  u'context operacional',
#  u'contingent',
#  u'continu',
#  u'contr',
#  u'contrat',
#  u'contratu',
#  u'contribui\xe7\xe3',
#  u'contribui\xe7\xe3 social',
#  u'contribui\xe7\xe3 social difer',
#  u'contribui\xe7\xe3 social impost',
#  u'contribui\xe7\xf5',
#  u'control',
#  u'control intern',
#  u'contr\xe1ri',
#  u'contr\xe1ri aracaju',
#  u'contr\xe1ri aracaju independent',
#  u'cont\xe1b',
#  u'cont\xe1b adot',
#  u'cont\xe1b adot brasil',
#  u'cont\xe1bil',
#  u'convoc',
#  u'conv\xeani',
#  u'coorden',
#  u'corr',
#  u'corr falc\xe3',
#  u'corr falc\xe3 secret\xe1ri',
#  u'correlat',
#  u'correlat govern',
#  u'correlat govern estad',
#  u'corrent',
#  u'correspond',
#  u'correspondent',
#  u'cost',
#  u'cot',
#  u'cpc',
#  u'crc',
#  u'cri',
#  u'cria\xe7\xe3',
#  u'crit\xe9ri',
#  u'cr\xe9dit',
#  u'cuj',
#  u'cumpr',
#  u'cumpriment',
#  u'curs',
#  u'curt',
#  u'curt praz',
#  u'cust',
#  u'cust aquisi\xe7\xe3',
#  u'cvm',
#  u'c\xe1lcul',
#  u'd',
#  u'd c',
#  u'd c r',
#  u'dad',
#  u'dat',
#  u'dat balanc',
#  u'dat public',
#  u'dat public art',
#  u'dat public produz',
#  u'de-',
#  u'decid',
#  u'decis\xe3',
#  u'declar',
#  u'decorr',
#  u'decorrent',
#  u'decret',
#  u'decret art',
#  u'decret entra',
#  u'decret entra vigor',
#  u'decret n.\xba',
#  u'decret n\xba',
#  u'deduz',
#  u'defin',
#  u'deliber',
#  u'deliber sobr',
#  u'dem',
#  u'demonstr',
#  u'demonstr cont\xe1b',
#  u'demonstr financeir',
#  u'demonstr flux',
#  u'demonstr flux caix',
#  u'demonstr muta\xe7\xf5',
#  u'demonstr muta\xe7\xf5 patrim\xf4ni',
#  u'demonstr result',
#  u'denomin',
#  u'dentr',
#  u'depart',
#  u'depend',
#  u'deprec',
#  u'deprec amortiz',
#  u'dep\xf3sit',
#  u'dep\xf3sit judic',
#  u'deriv',
#  u'descont',
#  u'descrit',
#  u'descri\xe7\xe3',
#  u'desd',
#  u'desempenh',
#  u'desenvolv',
#  u'design',
#  u'despes',
#  u'despes administr',
#  u'despes financeir',
#  u'despes operacion',
#  u'dess',
#  u'dest',
#  u'dest artig',
#  u'dest decret',
#  u'dest lei',
#  u'destin',
#  u'destin lucr',
#  u'detalh',
#  u'determin',
#  u'dev',
#  u'dev ser',
#  u'devid',
#  u'dezembr',
#  u'dezembr disp\xf5',
#  u'dezembr milh',
#  u'dezembr milh rea',
#  u'dia',
#  u'dias',
#  u'difer',
#  u'diferenc',
#  u'direit',
#  u'diret',
#  u'diret indiret',
#  u'diretor',
#  u'diretor president',
#  u'discuss\xe3',
#  u'dispens',
#  u'dispon',
#  u'disponibil',
#  u'dispon\xedv',
#  u'disposit',
#  u'disposi\xe7\xe3',
#  u'disposi\xe7\xf5',
#  u'disposi\xe7\xf5 contr\xe1ri',
#  u'disposi\xe7\xf5 contr\xe1ri aracaju',
#  u'disposi\xe7\xf5 leg',
#  u'disposi\xe7\xf5 leis',
#  u'dispost',
#  u'dispost art',
#  u'dispost art lei',
#  u'dispost lei',
#  u'dispost lei n\xba',
#  u'disp\xf5',
#  u'disp\xf5 sobr',
#  u'distribui\xe7\xe3',
#  u'distribui\xe7\xe3 dividend',
#  u'distribu\xedd',
#  u'divers',
#  u'divid',
#  u'dividend',
#  u'divulg',
#  u'di\xe1ri',
#  u'di\xe1ri o\ufb01cial',
#  u'di\xe1ri o\ufb01cial empresarial',
#  u'document',
#  u'dois',
#  u'durant',
#  u'duvid',
#  u'd\xe1',
#  u'd\xe1 provident',
#  u'd\xe1 provident correlat',
#  u'd\xe9bit',
#  u'd\xedv',
#  u'e/ou',
#  u'econom',
#  u'econ\xf4m',
#  u'edital',
#  u'educ',
#  u'efeit',
#  u'efeit part',
#  u'efet',
#  u'efetiv',
#  u'efetu',
#  u'elabor',
#  u'elabor demonstr',
#  u'elei\xe7\xe3',
#  u'el\xe9tr',
#  u'emiss\xe3',
#  u'emit',
#  u'emit pel',
#  u'empreend',
#  u'empreg',
#  u'empres',
#  u'empresarial',
#  u'empresarial s\xe3',
#  u'empresarial s\xe3 paul',
#  u'empr\xe9st',
#  u'empr\xe9st financ',
#  u'encaminh',
#  u'encarg',
#  u'encerr',
#  u'encerr dezembr',
#  u'encontr',
#  u'enderec',
#  u'energ',
#  u'engenh',
#  u'entidad',
#  u'entra',
#  u'entra vigor',
#  u'entra vigor dat',
#  u'envi',
#  u'envolv',
#  u'equip',
#  u'equivalent',
#  u'equivalent caix',
#  u'equivalent patrimonial',
#  u'esclarec',
#  u'escolh',
#  u'espec',
#  u'especial',
#  u'espec\xedf',
#  u'esper',
#  u'estabelec',
#  u'estabelec pel',
#  u'estad',
#  u'estad administr',
#  u'estad aprov',
#  u'estad aprov sancion',
#  u'estad fazend',
#  u'estad govern',
#  u'estad par',
#  u'estad sergip',
#  u'estad sergip fac',
#  u'estad sergip uso',
#  u'estad s\xe3',
#  u'estad s\xe3 paul',
#  u'estadu',
#  u'estadual',
#  u'estadual acord',
#  u'estadual acord dispost',
#  u'estar',
#  u'estatut',
#  u'estatut funcion\xe1ri',
#  u'estatut funcion\xe1ri p\xfablic',
#  u'estatut social',
#  u'estatut\xe1r',
#  u'estej',
#  u'estim',
#  u'estim cont\xe1b',
#  u'estiv',
#  u'estoqu',
#  u'estrangeir',
#  u'estrat\xe9g',
#  u'estrutur',
#  u'estud',
#  u'est\xe3',
#  u'est\xe3 send',
#  u'event',
#  u'eventu',
#  u'evident',
#  u'examin',
#  u'exced',
#  u'excet',
#  u'excet quand',
#  u'exclus',
#  u'execu',
#  u'execut',
#  u'exerc',
#  u'exerc\xedci',
#  u'exerc\xedci anterior',
#  u'exerc\xedci find',
#  u'exerc\xedci find dezembr',
#  u'exerc\xedci social',
#  u'exig',
#  u'exigent',
#  u'exist',
#  u'existent',
#  u'exped',
#  u'explic',
#  u'explic demonstr',
#  u'explic demonstr financeir',
#  u'express',
#  u'exterior',
#  u'extern',
#  u'extraordin\xe1r',
#  u'f',
#  u'fac',
#  u'fac sab',
#  u'fac sab assembl',
#  u'falc\xe3',
#  u'falc\xe3 secret\xe1ri',
#  u'falc\xe3 secret\xe1ri estad',
#  u'far',
#  u'fat',
#  u'favor',
#  u'faz',
#  u'fazend',
#  u'feder',
#  u'federal',
#  u'federal n\xba',
#  u'feit',
#  u'fern',
#  u'fevereir',
#  u'fevereir abril',
#  u'fic',
#  u'filh',
#  u'filh govern',
#  u'filh govern estad',
#  u'fim',
#  u'final',
#  u'financ',
#  u'financeir',
#  u'financeir companh',
#  u'financeir receit',
#  u'find',
#  u'find dezembr',
#  u'fins',
#  u'firm',
#  u'fisc',
#  u'fiscal',
#  u'fiscaliz',
#  u'fix',
#  u'flux',
#  u'flux caix',
#  u'flux caix ativ',
#  u'font',
#  u'form',
#  u'fornec',
#  u'fornecedor',
#  u'franc',
#  u'funcion',
#  u'funcion\xe1ri',
#  u'funcion\xe1ri p\xfablic',
#  u'funcion\xe1ri p\xfablic civ',
#  u'fund',
#  u'fundament',
#  u'fun\xe7\xe3',
#  u'fun\xe7\xf5',
#  u'futur',
#  u'f\xedsic',
#  u'g',
#  u'ganh',
#  u'ganh perd',
#  u'garant',
#  u'gast',
#  u'ger',
#  u'geral',
#  u'geral extraordin\xe1r',
#  u'geral ordin\xe1r',
#  u'gerenc',
#  u'gest\xe3',
#  u'global',
#  u'govern',
#  u'govern estad',
#  u'govern estad sergip',
#  u'govern sergip',
#  u'govern sergip decret',
#  u'govern sergip projet',
#  u'grand',
#  u'grup',
#  u'h',
#  u'hav',
#  u'hip\xf3tes',
#  u'hist\xf3r',
#  u'homolog',
#  u'hor',
#  u'houv',
#  u'i',
#  u'icms',
#  u'identific',
#  u'ifrs',
#  u'igual',
#  u'ii',
#  u'iii',
#  u'imediat',
#  u'imobiliz',
#  u'impact',
#  u'implant',
#  u'implement',
#  u'import',
#  u'impost',
#  u'impost contribui\xe7\xf5',
#  u'impost recuper',
#  u'impost rend',
#  u'impost rend contribui\xe7\xe3',
#  u'impost sobr',
#  u'im\xf3v',
#  u'im\xf3vel',
#  u'incident',
#  u'incis',
#  u'incis i',
#  u'incis v',
#  u'incis v vii',
#  u'inclu',
#  u'inclusiv',
#  u'inclu\xedd',
#  u'incorpor',
#  u'incorr',
#  u'independent',
#  u'independent rep\xfabl',
#  u'independent rep\xfabl jo\xe3',
#  u'indic',
#  u'indiret',
#  u'individu',
#  u'individual',
#  u'industrial',
#  u'ind\xfastr',
#  u'ind\xfastr com\xe9rci',
#  u'inerent',
#  u'inferior',
#  u'inform',
#  u'inic',
#  u'inicial',
#  u'instal',
#  u'institui\xe7\xe3',
#  u'institui\xe7\xf5',
#  u'institut',
#  u'institu\xedd',
#  u'instrument',
#  u'instrument financeir',
#  u'instru\xe7\xe3',
#  u'instru\xe7\xf5',
#  u'intang',
#  u'integr',
#  u'integral',
#  u'integraliz',
#  u'inter',
#  u'intern',
#  u'internacion',
#  u'interpret',
#  u'invest',
#  u'in\xedci',
#  u'in\xedci exerc\xedci',
#  u'item',
#  u'itens',
#  u'iv',
#  u'ix',
#  u'janeir',
#  u'janeir combin',
#  u'janeir combin disposi\xe7\xf5',
#  u'jos',
#  u'jo\xe3',
#  u'jo\xe3 alves',
#  u'jo\xe3 alves filh',
#  u'judic',
#  u'judicial',
#  u'julgament',
#  u'julh',
#  u'junh',
#  u'junt',
#  u'jur',
#  u'jur sobr',
#  u'jur sobr capital',
#  u'jur\xedd',
#  u'just',
#  u'lavr',
#  u'leg',
#  u'legal',
#  u'legisl',
#  u'legisl estad',
#  u'legisl estad aprov',
#  u'lei',
#  u'lei art',
#  u'lei complement',
#  u'lei entra',
#  u'lei entra vigor',
#  u'lei n.\xba',
#  u'lei n\xba',
#  u'lei n\xba dezembr',
#  u'lei n\xba janeir',
#  u'lei sociedad',
#  u'lei sociedad a\xe7\xf5',
#  u'leis',
#  u'leis n\xbas',
#  u'lev',
#  u'levant',
#  u'licenc',
#  u'lim',
#  u'limit',
#  u'lin',
#  u'linh',
#  u'liquid',
#  u'liquidez',
#  u'livr',
#  u'local',
#  u'localiz',
#  u'long',
#  u'long praz',
#  u'lot',
#  u'ltda',
#  u'ltda.',
#  u'lucr',
#  u'lucr acumul',
#  u'lucr brut',
#  u'lucr l\xedqu',
#  u'lucr l\xedqu exerc\xedci',
#  u'lucr preju\xedz',
#  u'luiz',
#  u'l\xedqu',
#  u'l\xedqu capital',
#  u'l\xedqu capital social',
#  u'l\xedqu cust',
#  u'l\xedqu exerc\xedci',
#  u'mach',
#  u'mai',
#  u'maior',
#  u'mandat',
#  u'mant',
#  u'manuten\xe7\xe3',
#  u'mar',
#  u'marc',
#  u'marcel',
#  u'materi',
#  u'material',
#  u'mat\xe9r',
#  u'med',
#  u'mediant',
#  u'mei',
#  u'mel',
#  u'mel secret\xe1ri',
#  u'mel secret\xe1ri estad',
#  u'melhor',
#  u'membr',
#  u'membr conselh',
#  u'men',
#  u'mencion',
#  u'menor',
#  u'mensal',
#  u'mensur',
#  u'ment',
#  u'merc',
#  u'mercador',
#  u'mes',
#  u'mesm',
#  u'mil',
#  u'milh',
#  u'milh rea',
#  u'milh\xf5',
#  u'mobili\xe1ri',
#  u'modific',
#  u'moed',
#  u'moment',
#  u'monet\xe1r',
#  u'montant',
#  u'montant r',
#  u'moviment',
#  u'mudanc',
#  u'munic\xedpi',
#  u'muta\xe7\xf5',
#  u'muta\xe7\xf5 patrim\xf4ni',
#  u'muta\xe7\xf5 patrim\xf4ni l\xedqu',
#  u'm\xe1quin',
#  u'm\xe1xim',
#  u'm\xe9d',
#  u'm\xe9di',
#  u'm\xe9tod',
#  u'm\xe9tod lin',
#  u'm\xeas',
#  u'm\xednim',
#  u'm\xf3v',
#  u'n.\xba',
#  u'n.\xba dezembr',
#  u'nacional',
#  u'nad',
#  u'natur',
#  u'necess',
#  u'necess\xe1r',
#  u'necess\xe1r par',
#  u'necess\xe1ri',
#  u'necess\xe1ri par',
#  u'negat',
#  u'negoc',
#  u'neg\xf3ci',
#  u'nenhum',
#  u'ness',
#  u'nest',
#  u'nicod',
#  u'nicod corr',
#  u'nicod corr falc\xe3',
#  u'nir',
#  u'nom',
#  u'nomin',
#  u'nomin valor',
#  u'nomin valor nominal',
#  u'nominal',
#  u'norm',
#  u'normal',
#  u'noss',
#  u'not',
#  u'not explic',
#  u'not explic demonstr',
#  u'nov',
#  u'novembr',
#  u'n\xb0',
#  u'n\xba',
#  u'n\xba abril',
#  u'n\xba dezembr',
#  u'n\xba janeir',
#  u'n\xba janeir combin',
#  u'n\xbas',
#  u'n\xe3',
#  u'n\xe3 circul',
#  u'n\xe3 pod',
#  u'n\xe3 s\xe3',
#  u'n\xedvel',
#  u'n\xfamer',
#  u'objet',
#  u'objet social',
#  u'obras',
#  u'obrig',
#  u'obrigat\xf3ri',
#  u'observ',
#  u'observ dispost',
#  u'obten\xe7\xe3',
#  u'obter',
#  u'obtid',
#  u'ocorr',
#  u'ocup',
#  u'oficial',
#  u'oliveir',
#  u'onde',
#  u'oper',
#  u'operacion',
#  u'operacional',
#  u'opini\xe3',
#  u'ordem',
#  u'ordem dia',
#  u'ordin\xe1r',
#  u'ordin\xe1r nomin',
#  u'organiz',
#  u'orient',
#  u'original',
#  u'or\xe7ament',
#  u'outr',
#  u'outr ativ',
#  u'outr cont',
#  u'outr cr\xe9dit',
#  u'outr despes',
#  u'outr form',
#  u'outr receit',
#  u'outubr',
#  u'o\ufb01cial',
#  u'o\ufb01cial empresarial',
#  u'o\ufb01cial empresarial s\xe3',
#  u'p/',
#  u'padr\xe3',
#  u'pag',
#  u'pagament',
#  u'par',
#  u'par ativ',
#  u'par contingent',
#  u'par efeit',
#  u'par elabor',
#  u'par exerc\xedci',
#  u'par exerc\xedci find',
#  u'par fins',
#  u'par realiz',
#  u'parcel',
#  u'parec',
#  u'part',
#  u'part integr',
#  u'part janeir',
#  u'part relacion',
#  u'particip',
#  u'particip s.a.',
#  u'par\xe1graf',
#  u'par\xe1graf \xfanic',
#  u'pass',
#  u'pass ser',
#  u'pass vigor',
#  u'pass vigor seguint',
#  u'passiv',
#  u'passiv circul',
#  u'passiv n\xe3',
#  u'passiv n\xe3 circul',
#  u'passiv patrim\xf4ni',
#  u'patrimoni',
#  u'patrimonial',
#  u'patrim\xf4ni',
#  u'patrim\xf4ni l\xedqu',
#  u'patrim\xf4ni l\xedqu capital',
#  u'paul',
#  u'paul di\xe1ri',
#  u'paul di\xe1ri o\ufb01cial',
#  u'paul sp',
#  u'ped',
#  u'pel',
#  u'pel administr',
#  u'pel comit',
#  u'pel companh',
#  u'pel conselh',
#  u'pel control',
#  u'pel cust',
#  u'pel decret',
#  u'pel lei',
#  u'pel lei n\xba',
#  u'pel m\xe9tod',
#  u'pel valor',
#  u'pel valor just',
#  u'percentual',
#  ...]

# %%
tfidf_vectorizer_text.vocabulary_
# Out:
# {u'igual': 671,
#  u'fix': 621,
#  u'fic': 604,
#  u'fim': 608,
#  u'correlat': 332,
#  u'estad aprov': 526,
#  u'operacion': 922,
#  u'cont receb client': 300,
#  u'aprov': 72,
#  u'm\xf3v': 859,
#  u'servic prest': 1239,
#  u'norm': 885,
#  u'document': 464,
#  u'ativ': 119,
#  u'descri\xe7\xe3': 401,
#  u'ado\xe7\xe3': 32,
#  u'solicit': 1270,
#  u'presta\xe7\xe3 servic': 1039,
#  u'reda\xe7\xe3': 1126,
#  u'qualqu': 1093,
#  u'govern sergip decret': 656,
#  u'lei art': 762,
#  u'outr ativ': 934,
#  u'august': 142,
#  u'integr': 723,
#  u'houv': 666,
#  u'estad sergip fac': 532,
#  u'\xfaltim': 1399,
#  u'circul': 214,
#  u'fern': 601,
#  u'acess': 10,
#  u'trabalh': 1330,
#  u'a\xe7\xe3': 151,
#  u'a\xe7\xf5': 152,
#  u'dest lei': 414,
#  u'resum': 1170,
#  u'ment': 829,
#  u'contingent': 307,
#  u'av': 147,
#  u'a.': 0,
#  u'fund': 634,
#  u'contr\xe1ri': 319,
#  u'jo\xe3 alves': 742,
#  u'\ufb01nanceir': 1407,
#  u'cvm': 354,
#  u'princip pr\xe1tic cont\xe1b': 1045,
#  u'flux caix ativ': 624,
#  u'inerent': 708,
#  u'contador': 303,
#  u'individual': 704,
#  u'indiret': 702,
#  u'de-': 365,
#  u'cnpj': 230,
#  u'r': 1103,
#  u'exped': 577,
#  u'respect': 1164,
#  u'necess\xe1ri': 868,
#  u'revogam-s disposi\xe7\xf5 contr\xe1ri': 1181,
#  u'find dezembr': 615,
#  u'tip': 1317,
#  u'carl': 198,
#  u'carg': 197,
#  u'capital pr\xf3pri': 190,
#  u'long praz': 787,
#  u'valor r': 1360,
#  u'incis v vii': 692,
#  u'atua\xe7\xe3': 139,
#  u'luiz': 797,
#  u'iii': 673,
#  u'declar': 368,
#  u'adiant': 24,
#  u'item': 733,
#  u'lei n\xba janeir': 769,
#  u'praz': 1027,
#  u'operacional': 923,
#  u'ser realiz': 1228,
#  u'aument': 143,
#  u'secret\xe1ri estad': 1206,
#  u'empresarial s\xe3 paul': 495,
#  u'pagament': 947,
#  u'materi': 812,
#  u'atos': 130,
#  u'legal': 757,
#  u'consultor': 295,
#  u'estad fazend': 528,
#  u'tes': 1316,
#  u'administr': 27,
#  u'h': 660,
#  u'quarta-feir abril': 1099,
#  u'produz efeit': 1053,
#  u'comunic': 265,
#  u'elabor': 483,
#  u'segu': 1212,
#  u'ordem': 925,
#  u'aracaju independent': 83,
#  u'impost recuper': 682,
#  u'\u201ccompanhia\u201d': 1406,
#  u'encerr': 500,
#  u'd\xedv': 472,
#  u's.a. cnpj/mf': 1188,
#  u'maior': 805,
#  u'nomin valor': 882,
#  u'engenh': 505,
#  u'nicod': 876,
#  u'term art incis': 1313,
#  u'junh': 748,
#  u'junt': 749,
#  u'valor nominal': 1358,
#  u'milh\xf5': 837,
#  u'promov': 1059,
#  u'mandat': 806,
#  u'chag': 210,
#  u'process': 1050,
#  u'possu': 1022,
#  u'entra vigor': 508,
#  u'l\xedqu cust': 801,
#  u'imediat': 674,
#  u'tribut': 1337,
#  u'acord pr\xe1tic': 18,
#  u'imobiliz': 675,
#  u'equip': 512,
#  u'atend': 118,
#  u'cuj': 346,
#  u'conselh administr': 280,
#  u'to': 1320,
#  u'itens': 734,
#  u'empresarial': 493,
#  u'fornecedor': 628,
#  u'exerc': 567,
#  u'esclarec': 516,
#  u'govern estad': 653,
#  u'determin': 418,
#  u'pr\xe1tic cont\xe1b': 1075,
#  u'muta\xe7\xf5 patrim\xf4ni': 849,
#  u'leg': 756,
#  u'lev': 774,
#  u'sistem': 1249,
#  u'benef\xedci': 166,
#  u'manuten\xe7\xe3': 808,
#  u'pr\xf3pr': 1078,
#  u'sergip': 1229,
#  u'prov\xe1vel': 1073,
#  u'm\xednim': 858,
#  u'cancel': 187,
#  u'possibil': 1021,
#  u'estatut funcion\xe1ri': 542,
#  u'cust aquisi\xe7\xe3': 353,
#  u'acord dispost': 15,
#  u'demonstr flux caix': 386,
#  u'corr': 329,
#  u'antes impost': 57,
#  u'dispost art lei': 449,
#  u'bas c\xe1lcul': 164,
#  u'p/': 944,
#  u'refer': 1129,
#  u'artig': 98,
#  u'r r': 1104,
#  u't': 1292,
#  u'd\xe1 provident correlat': 470,
#  u'provis\xe3 par contingent': 1071,
#  u'govern': 652,
#  u'o\ufb01cial': 941,
#  u'lei complement': 763,
#  u'\xfatil': 1401,
#  u'disponibil': 438,
#  u'jo\xe3 alves filh': 743,
#  u'existent': 576,
#  u'dezembr milh': 424,
#  u'mil': 834,
#  u'subsequent': 1277,
#  u'nest': 875,
#  u'ness': 874,
#  u'caracter\xedst': 196,
#  u'ser': 1226,
#  u'julh': 747,
#  u'class': 226,
#  u'ata': 117,
#  u'ato': 129,
#  u'atu': 136,
#  u'context operacional': 306,
#  u'curt praz': 351,
#  u'public art revogam-s': 1082,
#  u'l\xedqu capital social': 800,
#  u'event': 557,
#  u'artig dev': 99,
#  u'apresent demonstr': 69,
#  u'classific': 227,
#  u'pel conselh': 990,
#  u'estiv': 549,
#  u'estim': 547,
#  u'cap\xedtul': 195,
#  u'estabelec pel': 523,
#  u'abril di\xe1ri': 8,
#  u'jur sobr': 751,
#  u'inic': 711,
#  u'transa\xe7\xe3': 1331,
#  u'transa\xe7\xf5': 1332,
#  u'rio': 1182,
#  u'ocup': 917,
#  u'estad s\xe3 paul': 535,
#  u'ii': 672,
#  u'circul mercador': 216,
#  u'grand': 658,
#  u'pass vigor seguint': 970,
#  u'cent': 204,
#  u'descont': 399,
#  u'assinatur': 112,
#  u'assoc': 114,
#  u'utiliz': 1349,
#  u'constant': 288,
#  u'encontr': 502,
#  u'implant': 677,
#  u'nicod corr': 877,
#  u'prec': 1028,
#  u'estadual acord dispost': 539,
#  u's/a': 1189,
#  u'compar': 253,
#  u'superior': 1282,
#  u'm\xe9d': 853,
#  u'term': 1311,
#  u'falc\xe3 secret\xe1ri': 590,
#  u'cont\xe1bil': 325,
#  u'ser\xe3': 1242,
#  u'consign': 285,
#  u'acord': 14,
#  u'a\xe7\xf5 ordin\xe1r': 153,
#  u'provenient': 1065,
#  u'm\xe9di': 854,
#  u'iv': 735,
#  u'janeir': 737,
#  u'suficient': 1279,
#  u'nicod corr falc\xe3': 878,
#  u'independent rep\xfabl jo\xe3': 700,
#  u'n\xba janeir': 897,
#  u'noss': 887,
#  u'art incis v': 92,
#  u'combin': 239,
#  u'coloc': 237,
#  u'nom': 880,
#  u'program': 1056,
#  u'design': 405,
#  u'pronunc': 1060,
#  u'econom': 474,
#  u'valor present': 1359,
#  u'abert': 2,
#  u'comercializ': 244,
#  u'qualidad': 1092,
#  u'regim': 1134,
#  u'inter': 726,
#  u'n\xfamer': 905,
#  u'd\xe1 provident': 469,
#  u'lucr l\xedqu': 794,
#  u'certific': 209,
#  u'ativ invest': 124,
#  u'd\xe9bit': 471,
#  u'terceir': 1310,
#  u'correlat govern estad': 334,
#  u'passiv n\xe3': 973,
#  u'legisl estad': 759,
#  u'social capital': 1261,
#  u'jur sobr capital': 752,
#  u'obras': 908,
#  u'deriv': 398,
#  u'companh abert': 250,
#  u'execut': 566,
#  u'incorpor': 696,
#  u'liquid': 781,
#  u'conform': 275,
#  u'v': 1350,
#  u'assembl geral ordin\xe1r': 106,
#  u'identific': 669,
#  u'social': 1260,
#  u'paul': 981,
#  u'nacional': 862,
#  u'diret': 431,
#  u'art lei n\xba': 95,
#  u'extraordin\xe1r': 584,
#  u'mel secret\xe1ri estad': 820,
#  u'valor cont\xe1bil': 1354,
#  u'\u201ccaput\u201d': 1403,
#  u'conform lei': 276,
#  u'varia\xe7\xe3': 1362,
#  u'total sald': 1329,
#  u'fiscaliz': 620,
#  u'fevereir abril': 603,
#  u'antoni': 59,
#  u'fins': 616,
#  u'desempenh': 403,
#  u'descrit': 400,
#  u'remanescent': 1145,
#  u'decret n\xba': 376,
#  u'faz': 595,
#  u'far': 592,
#  u'fat': 593,
#  u'fac': 586,
#  u'vigor': 1375,
#  u'hip\xf3tes': 662,
#  u'l\xedqu exerc\xedci': 802,
#  u'sa\xfad': 1201,
#  u'valor merc': 1356,
#  u'circul n\xe3 circul': 218,
#  u'projet lei': 1058,
#  u'antes': 56,
#  u'particip': 963,
#  u'servic': 1238,
#  u'montant r': 844,
#  u'institui\xe7\xf5': 715,
#  u'institui\xe7\xe3': 714,
#  u'dispost art': 448,
#  u'respons': 1166,
#  u'd': 356,
#  u'exerc\xedci': 568,
#  u'disposi\xe7\xf5': 442,
#  u'disposi\xe7\xe3': 441,
#  u'tempor\xe1r': 1304,
#  u'outubr': 940,
#  u'lucr brut': 793,
#  u'al\xedquot': 46,
#  u'central': 206,
#  u'milh': 835,
#  u'estej': 546,
#  u'l\xedqu capital': 799,
#  u'perd': 1000,
#  u'constru\xe7\xe3': 294,
#  u'financeir companh': 612,
#  u'membr': 822,
#  u'ter\xe7a-feir': 1315,
#  u'pronunc cont\xe1b': 1061,
#  u'ser pag': 1227,
#  u's\xe3 paul': 1287,
#  u'defin': 378,
#  u'mesm': 833,
#  u'in\xedci exerc\xedci': 732,
#  u'n\xe3': 900,
#  u'n\xba': 894,
#  u'n\xb0': 893,
#  u'impost': 680,
#  u'pol\xedt': 1015,
#  u'garant': 643,
#  u'financ': 610,
#  u'vig\xeanc': 1379,
#  u'aplic': 64,
#  u'muta\xe7\xf5': 848,
#  u'diretor': 433,
#  u'r t art': 1106,
#  u'consequent': 282,
#  u'par\xe1graf \xfanic': 966,
#  u'total': 1325,
#  u'emit': 488,
#  u'receb client': 1115,
#  u'explic demonstr': 579,
#  u'estad sergip uso': 533,
#  u'segund': 1216,
#  u'impost rend contribui\xe7\xe3': 684,
#  u'vincul': 1383,
#  u'raz\xe3': 1107,
#  u'balanc': 157,
#  u'recuper ativ': 1124,
#  u'amortiz': 48,
#  u'n\xe3 s\xe3': 903,
#  u'aprec': 67,
#  u'cinc': 213,
#  u'incorr': 697,
#  u'obtid': 915,
#  u'atribui\xe7\xf5 s\xe3': 133,
#  u'com-': 238,
#  u'tenh sid': 1308,
#  u'cobertur': 234,
#  u'vist': 1386,
#  u'autor': 145,
#  u's\xe3 apresent': 1284,
#  u'acim': 11,
#  u'x': 1388,
#  u'andament': 49,
#  u'control': 317,
#  u'e/ou': 473,
#  u'financeir': 611,
#  u'total passiv': 1328,
#  u'empres': 492,
#  u'empreg': 491,
#  u'cofins': 236,
#  u'contribui\xe7\xf5': 316,
#  u'contribui\xe7\xe3': 312,
#  u'encaminh': 498,
#  u'industrial': 705,
#  u'gest\xe3': 650,
#  u'art': 85,
#  u'ativ operacion': 127,
#  u'secret\xe1r': 1204,
#  u'quaisqu': 1091,
#  u'silv': 1248,
#  u'regul': 1136,
#  u'energ': 504,
#  u'leis': 772,
#  u'xxi constitui\xe7\xe3': 1390,
#  u'art revogam-s disposi\xe7\xf5': 97,
#  u'art dest decret': 89,
#  u'poss\xedvel': 1023,
#  u'par efeit': 951,
#  u'continu': 308,
#  u'percentual': 999,
#  u's\xe3 registr': 1291,
#  u'respeit': 1165,
#  u'part relacion': 962,
#  u'exigent': 574,
#  u'govern sergip': 655,
#  u'i': 667,
#  u'long': 786,
#  u'lei n\xba': 767,
#  u'pesquis': 1006,
#  u'exerc\xedci anterior': 569,
#  u'munic\xedpi': 847,
#  u'exist': 575,
#  u'ind\xfastr com\xe9rci': 707,
#  u'dispost lei n\xba': 451,
#  u'art decret entra': 87,
#  u'\xfanic': 1400,
#  u'deliber': 379,
#  u'tant': 1299,
#  u'global': 651,
#  u'estatut': 541,
#  u'divid': 458,
#  u'real': 1110,
#  u'diret indiret': 432,
#  u'seguint': 1213,
#  u'estadual acord': 538,
#  u'assin': 111,
#  u'previst': 1041,
#  u'outr despes': 937,
#  u'provis\xe3 par': 1070,
#  u'permanent': 1002,
#  u'pass ser': 968,
#  u'contrat': 310,
#  u'onde': 920,
#  u'permanec': 1001,
#  u'sab assembl legisl': 1192,
#  u'localiz': 785,
#  u'tr\xeas': 1341,
#  u'mar': 809,
#  u'mai': 804,
#  u'respons pel': 1167,
#  u'unidad': 1345,
#  u'circul n\xe3': 217,
#  u'venciment': 1366,
#  u'estatut social': 544,
#  u'sociedad a\xe7\xf5': 1268,
#  u'temp': 1303,
#  u'mel': 818,
#  u'feit': 600,
#  u'contribui\xe7\xe3 social': 313,
#  u'revis\xe3': 1177,
#  u'const': 287,
#  u'abril conform': 7,
#  u'comit': 246,
#  u'compreend': 262,
#  u'relat\xf3ri administr': 1142,
#  u'estar': 540,
#  u'assessor': 109,
#  u'capitaliz': 194,
#  u'vigor dat public': 1377,
#  u'nominal': 884,
#  u'bas': 163,
#  u'cria\xe7\xe3': 343,
#  u'dias': 427,
#  u'mediant': 816,
#  u'pel valor just': 998,
#  u'caix par': 183,
#  u'risc': 1183,
#  u'independent': 698,
#  u'sergip decret n\xba': 1231,
#  u'disp\xf5 sobr': 453,
#  u'reserv': 1159,
#  u'adquir': 33,
#  u'homolog': 664,
#  u'curs': 349,
#  u'grup': 659,
#  u'pass': 967,
#  u'lei n\xba dezembr': 768,
#  u'implement': 678,
#  u'n\xba dezembr': 896,
#  u'subscrit': 1276,
#  u'futur': 638,
#  u'negoc': 871,
#  u'tribut\xe1ri': 1339,
#  u'comercial': 243,
#  u'aument capital': 144,
#  u'aproxim': 76,
#  u'outr': 933,
#  u'pel lei': 994,
#  u'princip pr\xe1tic': 1044,
#  u'cumpr': 347,
#  u'receb\xedv': 1116,
#  u'ordin\xe1r nomin': 928,
#  u'parcel': 957,
#  u'dispost lei': 450,
#  u'ganh': 641,
#  u'recolh': 1121,
#  u'local': 784,
#  u'correspondent': 337,
#  u'transfer': 1333,
#  u'relat': 1139,
#  u'transport': 1335,
#  u'estatut\xe1r': 545,
#  u'sul': 1281,
#  u'realiz long praz': 1113,
#  u'despes financeir': 408,
#  u'discuss\xe3': 435,
#  u'marc': 810,
#  u'emit pel': 489,
#  u'pel cust': 992,
#  u'passiv': 971,
#  u'disposi\xe7\xf5 leg': 445,
#  u'elabor demonstr': 484,
#  u'or\xe7ament': 932,
#  u'ano': 52,
#  u'anu': 60,
#  u'eventu': 558,
#  u'contabil': 301,
#  u'ativ n\xe3': 125,
#  u'receit operacional': 1120,
#  u'internacion': 728,
#  u'agost': 35,
#  u'projet': 1057,
#  u'art fic': 90,
#  u'sald dezembr': 1195,
#  u'acumul total': 22,
#  u't\xe9cnic': 1342,
#  u'tend vist': 1306,
#  u'banc': 160,
#  u'an\xe1lis': 62,
#  u'patrimonial': 977,
#  u'total ativ': 1326,
#  u'obrig': 909,
#  u'marcel': 811,
#  u'inclusiv': 694,
#  u'fisc': 618,
#  u'distribui\xe7\xe3 dividend': 455,
#  u'caix equivalent caix': 181,
#  u'flux': 622,
#  u'cidad': 212,
#  u'lei entra vigor': 765,
#  u'capac': 188,
#  u'dat public art': 363,
#  u'decret n.\xba': 375,
#  u'quand': 1094,
#  u'quant': 1096,
#  u'aspect': 101,
#  u'princip': 1043,
#  u'\xe2mbit': 1393,
#  u'filh': 605,
#  u'despes': 406,
#  u'quadr': 1090,
#  u'caix': 177,
#  u'combin disposi\xe7\xf5': 240,
#  u'corrent': 335,
#  u'rep\xfabl jo\xe3 alves': 1155,
#  u'detalh': 417,
#  u'antecip': 54,
#  u'assegur': 102,
#  u'gast': 644,
#  u'm\xe9tod': 855,
#  u'alves filh': 43,
#  u'med': 815,
#  u'men': 824,
#  u'mei': 817,
#  u'mes': 832,
#  u'falc\xe3': 589,
#  u'est\xe3 send': 556,
#  u'conced': 268,
#  u'n\xba janeir combin': 898,
#  u'curt': 350,
#  u'comprov': 264,
#  u'paul sp': 984,
#  u'revogam-s disposi\xe7\xf5': 1180,
#  u'estrat\xe9g': 552,
#  u'observ dispost': 912,
#  u'jo\xe3': 741,
#  u'jos': 740,
#  u'observ': 911,
#  u'assistent': 113,
#  u'despes operacion': 409,
#  u'destin': 415,
#  u'separ': 1225,
#  u'send': 1221,
#  u'sent': 1224,
#  u'especial': 519,
#  u'compet': 255,
#  u'livr': 783,
#  u'preju\xedz acumul': 1030,
#  u'm\xe1xim': 852,
#  u'varia\xe7\xf5 monet\xe1r': 1364,
#  u'anos': 53,
#  u'bem': 165,
#  u'conhec': 277,
#  u'revis': 1176,
#  u'limit': 778,
#  u'seguint reda\xe7\xe3': 1215,
#  u'estad par': 530,
#  u'res': 1158,
#  u'ret': 1171,
#  u'rea': 1109,
#  u'franc': 629,
#  u're-': 1108,
#  u'janeir combin disposi\xe7\xf5': 739,
#  u'dispon\xedv': 439,
#  u'diretor president': 434,
#  u'avis': 150,
#  u'servidor': 1241,
#  u'membr conselh': 823,
#  u'decid': 366,
#  u'destin lucr': 416,
#  u'not explic': 889,
#  u'torn': 1323,
#  u'referent': 1132,
#  u'comit pronunc cont\xe1b': 248,
#  u'exerc\xedci social': 572,
#  u'artig lei': 100,
#  u'necess\xe1r': 866,
#  u'recurs': 1125,
#  u'pesso': 1007,
#  u'consum': 296,
#  u'receit financeir': 1119,
#  u'apropri': 71,
#  u'patrim\xf4ni l\xedqu capital': 980,
#  u'empr\xe9st': 496,
#  u'combin disposi\xe7\xf5 leis': 241,
#  u'\xedndic': 1396,
#  u'lei entra': 764,
#  u'abril di\xe1ri o\ufb01cial': 9,
#  u'receit despes': 1118,
#  u'judic': 744,
#  u'part integr': 960,
#  u'civ estad sergip': 224,
#  u'reuni\xe3': 1173,
#  u'reuni\xf5': 1174,
#  u'dep\xf3sit judic': 397,
#  u'relev': 1144,
#  u'provident correlat': 1067,
#  u'contador crc': 304,
#  u'patrimoni': 976,
#  u'result': 1168,
#  u'l\xedqu': 798,
#  u'rend contribui\xe7\xe3': 1148,
#  u'consider': 284,
#  u'difer': 428,
#  u'devid': 421,
#  u'licenc': 776,
#  u'o\ufb01cial empresarial': 942,
#  u'equivalent patrimonial': 515,
#  u'reten\xe7\xe3': 1172,
#  u'reduz': 1127,
#  u'nad': 863,
#  u'demonstr muta\xe7\xf5': 387,
#  u'social impost rend': 1265,
#  u'constitu\xedd': 293,
#  u'f\xedsic': 639,
#  u'vend': 1367,
#  u'venc': 1365,
#  u'venh': 1368,
#  u'quinta-feir abril': 1102,
#  u'funcion\xe1ri': 631,
#  u'cont\xe1b adot': 323,
#  u'caix caix': 179,
#  u'uso atribui\xe7\xf5 s\xe3': 1348,
#  u's\xe3 paul sp': 1289,
#  u'rela\xe7\xe3': 1143,
#  u'modific': 839,
#  u'brasil': 168,
#  u'funcion': 630,
#  u'vot': 1387,
#  u'oficial': 918,
#  u'patrim\xf4ni l\xedqu': 979,
#  u'acumul': 21,
#  u'coorden': 328,
#  u'demonstr cont\xe1b': 383,
#  u'revog': 1178,
#  u't\xeam': 1343,
#  u'exclus': 564,
#  u'funcion\xe1ri p\xfablic': 632,
#  u'necess': 865,
#  u'planej': 1011,
#  u'sempr': 1220,
#  u'estrutur': 553,
#  u'qua': 1089,
#  u'dat public produz': 364,
#  u'el\xe9tr': 486,
#  u'\xf3rg\xe3 entidad': 1398,
#  u'xxi': 1389,
#  u'port': 1017,
#  u'inform': 710,
#  u'incis i': 690,
#  u'incis v': 691,
#  u'confer term art': 274,
#  u'titul': 1318,
#  u'prest': 1037,
#  u'passiv n\xe3 circul': 974,
#  u'dois': 465,
#  u'legisl': 758,
#  u'vez': 1369,
#  u'impact': 676,
#  u'levant': 775,
#  u'deprec amortiz': 395,
#  u'par exerc\xedci': 953,
#  u'social reserv': 1266,
#  u'assembl geral': 104,
#  u'refere-s': 1130,
#  u'envi': 510,
#  u'mensur': 828,
#  u'efet': 480,
#  u'term art': 1312,
#  u'sobr': 1254,
#  u'valor': 1353,
#  u'caus': 202,
#  u'monet\xe1r': 842,
#  u'uso': 1346,
#  u'art lei': 93,
#  u'reserv capital': 1160,
#  u'deliber sobr': 380,
#  u'impost sobr': 685,
#  u'par exerc\xedci find': 954,
#  u'contribui\xe7\xe3 social impost': 315,
#  u'ordem dia': 926,
#  u'assembl legisl estad': 108,
#  u'dezembr milh rea': 425,
#  u'inclu': 693,
#  u'patrim\xf4ni': 978,
#  u'senhor': 1222,
#  u'civil': 225,
#  u'assembl': 103,
#  u'ltda.': 790,
#  u'cont\xe1b adot brasil': 324,
#  u'competent': 256,
#  u'n\xe3 pod': 902,
#  u'fevereir': 602,
#  u'linh': 780,
#  u'ativ passiv': 128,
#  u'vid': 1372,
#  u'impost rend': 683,
#  u'pel comit': 988,
#  u'referent exerc\xedci': 1133,
#  u'regulament': 1137,
#  u'setor': 1245,
#  u'distribu\xedd': 456,
#  u'estad aprov sancion': 527,
#  u'just': 754,
#  u'recuper': 1123,
#  u'andar': 50,
#  u'aplic financeir': 65,
#  u'conv\xeani': 327,
#  u'\xe1re': 1392,
#  u'font': 625,
#  u'trat': 1336,
#  u'sergip uso': 1236,
#  u'estrangeir': 551,
#  u'nomin valor nominal': 883,
#  u'atribui\xe7\xf5': 132,
#  u'sant': 1200,
#  u'companh': 249,
#  u'acord pr\xe1tic cont\xe1b': 19,
#  u'emiss\xe3': 487,
#  u'sergip fac': 1232,
#  u'capital': 189,
#  u'par\xe1graf': 965,
#  u'par ativ': 949,
#  u'president conselh': 1036,
#  u'elei\xe7\xe3': 485,
#  u'ger': 645,
#  u'integraliz': 725,
#  u'avali': 148,
#  u'vigent': 1374,
#  u'antes impost rend': 58,
#  u'opini\xe3': 924,
#  u'econ\xf4m': 475,
#  u'produz efeit part': 1054,
#  u'inclu\xedd': 695,
#  u'dezembr': 422,
#  u'\u201cart': 1402,
#  u'obrigat\xf3ri': 910,
#  u'pr\xf3pri': 1079,
#  u'geral ordin\xe1r': 648,
#  u'ambient': 47,
#  u'categor': 201,
#  u'pod execut': 1013,
#  u'aprov sancion': 74,
#  u'seg': 1211,
#  u'sed': 1209,
#  u'sej': 1219,
#  u'judicial': 745,
#  u'efeit': 478,
#  u'par realiz': 956,
#  u'part janeir': 961,
#  u'm\xe1quin': 851,
#  u'rend contribui\xe7\xe3 social': 1149,
#  u'evident': 559,
#  u'decret': 371,
#  u'ix': 736,
#  u'adequ': 23,
#  u'jur\xedd': 753,
#  u'anual': 61,
#  u'paul di\xe1ri o\ufb01cial': 983,
#  u'independent rep\xfabl': 699,
#  u'jur': 750,
#  u't art': 1293,
#  u'pr\xe1tic': 1074,
#  u'c r': 173,
#  u'mudanc': 846,
#  u'oper': 921,
#  u'efetiv': 481,
#  u'moviment': 845,
#  u'atrav\xe9s': 131,
#  u'contribui\xe7\xe3 social difer': 314,
#  u'efetu': 482,
#  u'anex': 51,
#  u'cas': 200,
#  u'cab': 175,
#  u'cad': 176,
#  u'resolu': 1163,
#  u'caix l\xedqu': 182,
#  u'ifrs': 670,
#  u'intern': 727,
#  u'sancion seguint lei': 1199,
#  u'corr falc\xe3 secret\xe1ri': 331,
#  u'servic transport': 1240,
#  u'rep\xfabl jo\xe3': 1154,
#  u'pod': 1012,
#  u'constitui\xe7\xe3 estadual': 291,
#  u'administr demonstr': 29,
#  u'assembl geral extraordin\xe1r': 105,
#  u'sald': 1194,
#  u'janeir combin': 738,
#  u'desenvolv': 404,
#  u'ativ circul': 120,
#  u'julgament': 746,
#  u'exerc\xedci find dezembr': 571,
#  u'acion': 12,
#  u'preju\xedz': 1029,
#  u'autoriz': 146,
#  u'ativ imobiliz': 123,
#  u'pel companh': 989,
#  u'ganh perd': 642,
#  u'estad govern': 529,
#  u'intang': 722,
#  u'apresent': 68,
#  u'menor': 826,
#  u'vii xxi': 1381,
#  u'total ativ passiv': 1327,
#  u't\xedtul': 1344,
#  u'correspond': 336,
#  u'realiz': 1111,
#  u'ordin\xe1r': 927,
#  u'icms': 668,
#  u'sancion seguint': 1198,
#  u'moed': 840,
#  u'premiss': 1031,
#  u'sergip fac sab': 1233,
#  u'tad': 1296,
#  u'assembl legisl': 107,
#  u'fornec': 627,
#  u'capital social': 192,
#  u'cost': 338,
#  u'not': 888,
#  u'nov': 891,
#  u'provident correlat govern': 1068,
#  u'confer': 272,
#  u'filh govern': 606,
#  u'presta\xe7\xf5': 1040,
#  u'compost': 260,
#  u'tais': 1297,
#  u'fun\xe7\xe3': 636,
#  u'fun\xe7\xf5': 637,
#  u'\xf3rg\xe3': 1397,
#  u'cont receb': 299,
#  u'original': 931,
#  u'dat public': 362,
#  u'plan': 1010,
#  u'circul realiz': 219,
#  u'relat exerc\xedci': 1140,
#  u'vid \xfatil': 1373,
#  u'souz': 1272,
#  u'cumpriment': 348,
#  u'calcul': 185,
#  u'parec': 958,
#  u'equivalent caix': 514,
#  u'import': 679,
#  u'alter': 41,
#  u'comiss\xe3': 245,
#  u'crc': 341,
#  u'cri': 342,
#  u'dispens': 436,
#  u'quatr': 1100,
#  u'hist\xf3r': 663,
#  u'equivalent': 513,
#  u'fiscal': 619,
#  u'obten\xe7\xe3': 913,
#  u'depend': 393,
#  u'orient': 930,
#  u'complement': 257,
#  u'f': 585,
#  u'cnpj/mf n\xba': 233,
#  u'cnpj n\xba': 231,
#  u'fac sab assembl': 588,
#  u'distribui\xe7\xe3': 454,
#  u'deprec': 394,
#  u'durant': 466,
#  u'presenc': 1033,
#  u'present': 1034,
#  u'constitui\xe7\xe3 estadual acord': 292,
#  u'compens': 254,
#  u'sal': 1193,
#  u'sab': 1190,
#  u'legisl estad aprov': 760,
#  u'instrument': 718,
#  u'gerenc': 649,
#  u'vii xxi constitui\xe7\xe3': 1382,
#  u'educ': 477,
#  u'art decret': 86,
#  u'transferent': 1334,
#  u'nir': 879,
#  u'crit\xe9ri': 344,
#  u'liquidez': 782,
#  u'propriedad': 1063,
#  u'receit': 1117,
#  u'normal': 886,
#  u'necess\xe1ri par': 869,
#  u'contabiliz': 302,
#  u'im\xf3vel': 687,
#  u'pr\xe1tic cont\xe1b adot': 1076,
#  u'sal\xe1ri': 1196,
#  u'requer': 1157,
#  u'necess\xe1r par': 867,
#  u'condi\xe7\xf5': 270,
#  u'decret entra': 373,
#  u'art revogam-s': 96,
#  u's\xe3 confer term': 1286,
#  u'revers\xe3': 1175,
#  u'divers': 457,
#  u'assum': 115,
#  u'hav': 661,
#  u'balanc patrimonial': 159,
#  u'assunt': 116,
#  u'ltda': 789,
#  u'capital reserv': 191,
#  u'conselh': 279,
#  u'estoqu': 550,
#  u'alves': 42,
#  u'r t': 1105,
#  u'tax jur': 1301,
#  u'estadu': 536,
#  u'institu\xedd': 717,
#  u'situa\xe7\xe3': 1252,
#  u'setembr': 1244,
#  u'neg\xf3ci': 872,
#  u'atualiz': 138,
#  u'ag\xeanc': 36,
#  u'melhor': 821,
#  u'organiz': 929,
#  u'requ': 1156,
#  u'lucr': 791,
#  u'cpc': 340,
#  u'integral': 724,
#  u'assim': 110,
#  u'relat\xf3ri': 1141,
#  u'\u201ccaput\u201d dest artig': 1405,
#  u's.a. cnpj': 1187,
#  u'explic': 578,
#  u'revogam-s': 1179,
#  u'lucr preju\xedz': 796,
#  u'geral': 646,
#  u'composi\xe7\xe3': 259,
#  u'adicion': 25,
#  u'n.\xba': 860,
#  u'demonstr muta\xe7\xf5 patrim\xf4ni': 388,
#  u'con-': 267,
#  u'produz': 1052,
#  u'produt': 1051,
#  u'aprov sancion seguint': 75,
#  u'dispon': 437,
#  u'quand aplic': 1095,
#  u'outr form': 938,
#  u'moment': 841,
#  u'banc\xe1ri': 161,
#  u'soc': 1259,
#  u'sob': 1253,
#  u'extern': 583,
#  u'xxi constitui\xe7\xe3 estadual': 1391,
#  u'cep': 207,
#  u'tribut\xe1r': 1338,
#  u'mach': 803,
#  u'v vii xxi': 1352,
#  u'm\xeas': 857,
#  u'atual': 137,
#  u'par fins': 955,
#  u'rep\xfabl': 1153,
#  u'encerr dezembr': 501,
#  u'fundament': 635,
#  u'apresent demonstr financeir': 70,
#  u'terren': 1314,
#  u'apoi': 66,
#  u'sobr capital': 1255,
#  u'hor': 665,
#  ...}

# %%
def given_id_give_index(arquivo_id, arquivos):
    return arquivos[arquivos['ctr_id']==arquivo_id].index[0]
#
def given_index_give_id(index, arquivos):
    return arquivos.iloc[index]['ctr_id']
#
def top_tfidf_feats(row, terms, top_n=25):
    topn_ids = np.argsort(row)[::-1][:top_n]
    top_feats = [(terms[i], row[i]) for i in topn_ids]
    df = pd.DataFrame(top_feats)
    df.columns = ['feature', 'tfidf']
    return df['feature']
#
def given_id_give_keywords(arquivos, tfidfMatrix, terms, arquivo_id, top_n=20):
    row_id = given_id_give_index(arquivo_id, arquivos)
    row = np.squeeze(tfidfMatrix[row_id].toarray())
    return top_tfidf_feats(row, terms, top_n)

# %%
Ex_arquivo_id = '5c2e5b8110d0bdc001e97e9b5cae09e3d38a66dc'
Ex_arquivo_index = given_id_give_index(Ex_arquivo_id, arquivos)
arquivos.iloc[Ex_arquivo_index]['arquivo_clean'][0:1000]
# Out:
# u'quarta-feira, 20 de abril de 2011 di\xe1rio o\ufb01cial empresarial s\xe3o paulo, 121 (73) \u2013 29 fademac s.a. cnpj/mf n\xba 61.452.199/0001-83 relat\xf3rio da diretoria senhores acionistas: atendendo \xe0s disposi\xe7\xf5es legais e estatut\xe1rias, submetemos \xe0 sua aprecia\xe7\xe3o as demonstra\xe7\xf5es financeiras correspondentes ao exerc\xedcio findo em 31 de dezembro de 2010, ficando esta diretoria ao inteiro dispor para quaisquer esclarecimentos que se fizerem necess\xe1rios. jacare\xed-sp, 21 de mar\xe7o de 2011. a diretoria 1. contexto operacional \u2013 a fademac s.a. \xe9 uma sociedade an\xf4nima de capital fechado, com sede na cidade de jacare\xed, localizada no estado de s\xe3o paulo e tem como objeto social e atividade preponderante a produ\xe7\xe3o e a comercializa\xe7\xe3o de pisos e revestimentos vin\xedlicos. em 27 de fevereiro de 2009, a controladora direta anterior, a nefiboum b.v., pertencente ao grupo etex, vendeu a totalidade de suas a\xe7\xf5es da fademac s.a. para a tarkett gdl sa., pertencente ao grupo tarkett, passando este a ser o seu principal cont'

# %%
arquivo_id_example = '5c2e5b8110d0bdc001e97e9b5cae09e3d38a66dc'
print ("Keywords based on id:")
print (given_id_give_keywords(arquivos, tfidf_matrix_text,
                                  terms_text, arquivo_id_example, top_n = 10))
# Out:
# Keywords based on id:
# 0         financeir
# 1              ativ
# 2             valor
# 3          reconhec
# 4           companh
# 5              risc
# 6            impost
# 7              caix
# 8    ativ financeir
# 9                sã
# Name: feature, dtype: object

# %%
from sklearn.neighbors import NearestNeighbors
num_neighbors = 4
# Based on text
nbrs_text = NearestNeighbors(n_neighbors=num_neighbors,
                                  algorithm='auto').fit(tfidf_matrix_text)
distances_text, indices_text = nbrs_text.kneighbors(tfidf_matrix_text)

# %%
def assign_clusters(data, centroids):
    
    # Compute distances between each data point and the set of centroids:
    # Fill in the blank (RHS only)
    distances_from_centroids = pairwise_distances(data, centroids, metric='euclidean')
    
    # Compute cluster assignments for each data point:
    # Fill in the blank (RHS only)
    cluster_assignment = np.argmin(distances_from_centroids, 1)
    
    return cluster_assignment

# %%
def revise_centroids(data, k, cluster_assignment):
    new_centroids = []
    for i in xrange(k):
        # Select all data points that belong to cluster i. Fill in the blank (RHS only)
        member_data_points = data[cluster_assignment==i]
        # Compute the mean of the data points. Fill in the blank (RHS only)
        centroid = member_data_points.mean(axis=0)
        
        # Convert numpy.matrix type to numpy.ndarray type
        centroid = centroid.A1
        new_centroids.append(centroid)
    new_centroids = np.array(new_centroids)
    
    return new_centroids

# %%
def compute_heterogeneity(data, k, centroids, cluster_assignment):
    
    heterogeneity = 0.0
    for i in xrange(k):
        
        # Select all data points that belong to cluster i. Fill in the blank (RHS only)
        member_data_points = data[cluster_assignment==i, :]
        
        if member_data_points.shape[0] > 0: # check if i-th cluster is non-empty
            # Compute distances from centroid to data points (RHS only)
            distances = pairwise_distances(member_data_points, [centroids[i]], metric='euclidean')
            squared_distances = distances**2
            heterogeneity += np.sum(squared_distances)
        
    return heterogeneity

# %%
# Fill in the blanks
def kmeans(data, k, initial_centroids, maxiter, record_heterogeneity=None, verbose=False):
    '''This function runs k-means on given data and initial set of centroids.
       maxiter: maximum number of iterations to run.
       record_heterogeneity: (optional) a list, to store the history of heterogeneity as function of iterations
                             if None, do not store the history.
       verbose: if True, print how many data points changed their cluster labels in each iteration'''
    centroids = initial_centroids[:]
    prev_cluster_assignment = None
    
    for itr in xrange(maxiter):        
        if verbose:
            print(itr)
        
        # 1. Make cluster assignments using nearest centroids
        # YOUR CODE HERE
        cluster_assignment = assign_clusters(data, centroids)
            
        # 2. Compute a new centroid for each of the k clusters, averaging all data points assigned to that cluster.
        # YOUR CODE HERE
        centroids = revise_centroids(data, k, cluster_assignment)
            
        # Check for convergence: if none of the assignments changed, stop
        if prev_cluster_assignment is not None and \
          (prev_cluster_assignment==cluster_assignment).all():
            break
        
        # Print number of new assignments 
        if prev_cluster_assignment is not None:
            num_changed = np.sum(prev_cluster_assignment!=cluster_assignment)
            if verbose:
                print('    {0:5d} elements changed their cluster assignment.'.format(num_changed))   
        
        # Record heterogeneity convergence metric
        if record_heterogeneity is not None:
            # YOUR CODE HERE
            score = compute_heterogeneity(data, k, centroids, cluster_assignment)
            record_heterogeneity.append(score)
        
        prev_cluster_assignment = cluster_assignment[:]
        
    return centroids, cluster_assignment

# %%
def smart_initialize(data, k, seed=None):
    '''Use k-means++ to initialize a good set of centroids'''
    if seed is not None: # useful for obtaining consistent results
        np.random.seed(seed)
    centroids = np.zeros((k, data.shape[1]))
    
    # Randomly choose the first centroid.
    # Since we have no prior knowledge, choose uniformly at random
    idx = np.random.randint(data.shape[0])
    centroids[0] = data[idx,:].toarray()
    # Compute distances from the first centroid chosen to all the other data points
    squared_distances = pairwise_distances(data, centroids[0:1], metric='euclidean').flatten()**2
    
    for i in xrange(1, k):
        # Choose the next centroid randomly, so that the probability for each data point to be chosen
        # is directly proportional to its squared distance from the nearest centroid.
        # Roughtly speaking, a new centroid should be as far as from ohter centroids as possible.
        idx = np.random.choice(data.shape[0], 1, p=squared_distances/sum(squared_distances))
        centroids[i] = data[idx,:].toarray()
        # Now compute distances from the centroids to all data points
        squared_distances = np.min(pairwise_distances(data, centroids[0:i+1], metric='euclidean')**2,axis=1)
    
    return centroids

# %%
def get_key_by_value(dictionary, value):
    for key, value in dictionary.iteritems():
        if value == value:
            return key
    return None

# %%
def visualize_document_clusters(arquivos, tf_idf, centroids, cluster_assignment, k, vocabulary, display_content=True):
    '''wiki: original dataframe
       tf_idf: data matrix, sparse matrix format
       vocabulary: dict specifying the mapping betweeen words and column indices
       display_content: if True, display 8 nearest neighbors of each centroid'''
    
    print('==========================================================')

    # Visualize each cluster c
    for c in xrange(k):
        # Cluster heading
        print('Cluster {0:d}    '.format(c)),
        # Print top 5 words with largest TF-IDF weights in the cluster
        idx = centroids[c].argsort()[::-1]
        for i in xrange(5): # Print each word along with the TF-IDF weight
            print('{0:s}:{1:.3f}'.format(get_key_by_value(vocabulary, [idx[i]]), centroids[c,idx[i]])),
        print('')
        
        if display_content:
            # Compute distances from the centroid to all data points in the cluster,
            # and compute nearest neighbors of the centroids within the cluster.
            distances = pairwise_distances(tf_idf, centroids[c].reshape(1, -1), metric='euclidean').flatten()
            distances[cluster_assignment!=c] = float('inf') # remove non-members from consideration
            nearest_neighbors = distances.argsort()
            # For 8 nearest neighbors, print the title as well as first 180 characters of text.
            # Wrap the text at 80-character mark.
            for i in xrange(8):
                text = ' '.join(arquivos[nearest_neighbors[i]]['arquivo_clean'].split(None, 25)[0:25])
                print('\n* {0:50s} {1:.5f}\n  {2:s}\n  {3:s}'.format(arquivos[nearest_neighbors[i]]['ctr_id'],
                    distances[nearest_neighbors[i]], text[:90], text[90:180] if len(text) > 90 else ''))
        print('==========================================================')

# %%
k = 4
seed = 120000
maxiter = 400
# Use k-means++ initialization
initial_centroids = smart_initialize(tfidf_matrix_text, k, seed)
# Run k-means
centroids, cluster_assignment = kmeans(tfidf_matrix_text, k, initial_centroids, maxiter=maxiter,
                                   record_heterogeneity=None, verbose=True)
visualize_document_clusters(arquivos, tfidf_matrix_text, centroids, cluster_assignment, k, tfidf_vectorizer_text.vocabulary_)
# Out:
# 0
# 1
#       103 elements changed their cluster assignment.
# 2
#        28 elements changed their cluster assignment.
# 3
#        11 elements changed their cluster assignment.
# 4
#         2 elements changed their cluster assignment.
# 5
# ==========================================================
# Cluster 0     igual:0.137 igual:0.137 igual:0.135 igual:0.123 igual:0.116
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-5898076d5f53> in <module>()
#       7 centroids, cluster_assignment = kmeans(tfidf_matrix_text, k, initial_centroids, maxiter=maxiter,
#       8                                    record_heterogeneity=None, verbose=True)
# ----> 9 visualize_document_clusters(arquivos, tfidf_matrix_text, centroids, cluster_assignment, k, tfidf_vectorizer_text.vocabulary_)
#
# <ipython-input-39-a8709da12601> in visualize_document_clusters(arquivos, tf_idf, centroids, cluster_assignment, k, vocabulary, display_content)
#      26             # Wrap the text at 80-character mark.
#      27             for i in xrange(8):
# ---> 28                 text = ' '.join(arquivos[nearest_neighbors[i]]['arquivo_clean'].split(None, 25)[0:25])
#      29                 print('\n* {0:50s} {1:.5f}\n  {2:s}\n  {3:s}'.format(arquivos[nearest_neighbors[i]]['ctr_id'],
#      30                     distances[nearest_neighbors[i]], text[:90], text[90:180] if len(text) > 90 else ''))
#
# /home/pedro.castro/anaconda2/envs/dato-env/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1967             return self._getitem_multilevel(key)
#    1968         else:
# -> 1969             return self._getitem_column(key)
#    1970
#    1971     def _getitem_column(self, key):
#
# /home/pedro.castro/anaconda2/envs/dato-env/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1974         # get column
#    1975         if self.columns.is_unique:
# -> 1976             return self._get_item_cache(key)
#    1977
#    1978         # duplicate columns & possible reduce dimensionality
#
# /home/pedro.castro/anaconda2/envs/dato-env/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1089         res = cache.get(item)
#    1090         if res is None:
# -> 1091             values = self._data.get(item)
#    1092             res = self._box_item_values(item, values)
#    1093             cache[item] = res
#
# /home/pedro.castro/anaconda2/envs/dato-env/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3209
#    3210             if not isnull(item):
# -> 3211                 loc = self.items.get_loc(item)
#    3212             else:
#    3213                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /home/pedro.castro/anaconda2/envs/dato-env/lib/python2.7/site-packages/pandas/core/index.pyc in get_loc(self, key, method, tolerance)
#    1757                                  'backfill or nearest lookups')
#    1758             key = _values_from_object(key)
# -> 1759             return self._engine.get_loc(key)
#    1760
#    1761         indexer = self.get_indexer([key], method=method,
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3979)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3843)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12265)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12216)()
#
# KeyError: 380
